# %%
# %%bash
# rm -r sample_data

# %% [markdown]
# # **Extract all the GSM links based in the give GSE accession IDs**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

def extract_all_GSM_links(GSE_url):
    response = requests.get(GSE_url)
    content = response.content
    soup = BeautifulSoup(content, "html.parser")
    tr_elems = soup.find_all('tr')

    GSM_links = []
    for tr_elem in tr_elems:
        if tr_elem.get('valign') == 'top' and 'GSM' in tr_elem.text:
            links = tr_elem.find_all('a')
            for link in links:
                href = link.get('href')
                if href and href.startswith("/geo/query/acc.cgi?acc="):
                    https = f"https://www.ncbi.nlm.nih.gov{href}"
                    GSM_links.append(https)
    return GSM_links

def process_row(row):
    accession = row['accession_found']
    GSE_url = f'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc={accession}'
    return extract_all_GSM_links(GSE_url)

# Read the DataFrame
df = pd.read_csv("/content/srr_dates.csv")

# Prepare a dictionary to hold our results
results = {}

# Use ThreadPoolExecutor to parallelize the extraction
with ThreadPoolExecutor(max_workers=12) as executor:
    # Submit tasks to the executor
    future_to_row = {executor.submit(process_row, row): index for index, row in df.iterrows()}

    # Collect the results as they are completed
    for future in as_completed(future_to_row):
        index = future_to_row[future]
        try:
            results[index] = future.result()
        except Exception as exc:
            print(f'Generated an exception: {exc}')
        else:
            print(f'Row {index} done')

    # Update the DataFrame with the results
for index, GSM_links in results.items():
    # Convert the list of links to a string representation if you want to store it in a single cell
    # You can choose a separator that suits your needs; here, I use a comma.
    links_str = ','.join(GSM_links)
    df.at[index, 'GSM_links'] = links_str
df
# Out:
# Row 5 done
# Row 8 done
# Row 2 done
# Row 1 done
# Row 10 done
# Row 0 done
# Row 11 done
# Row 4 done
# Row 3 done
# Row 9 done
# Row 14 done
# Row 7 done
# Row 6 done
# Row 12 done
# Row 13 done
# Row 17 done
# Row 16 done
# Row 15 done
# Row 18 done
# Row 21 done
# Row 19 done
# Row 23 done
# Row 25 done
# Row 26 done
# Row 24 done
# Row 22 done
# Row 28 done
# Row 27 done
# Row 31 done
# Row 30 done
# Row 29 done
# Row 32 done
# Row 20 done
# Row 33 done
# Row 37 done
# Row 38 done
# Row 34 done
# Row 36 done
# Row 39 done
# Row 35 done
# Row 40 done
# Row 41 done
# Row 44 done
# Row 42 done
# Row 43 done
# Row 45 done
# Row 47 done
# Row 50 done
# Row 46 done
# Row 51 done
# Row 49 done
# Row 48 done
# Row 52 done
# Row 54 done
# Row 53 done
# Row 56 done
# Row 55 done
# Row 57 done
# Row 58 done
# Row 59 done
# Row 60 done
# Row 62 done
# Row 64 done
# Row 63 done
# Row 61 done
# Row 65 done
# Row 66 done
# Row 67 done
# Row 71 done
# Row 70 done
# Row 69 done
# Row 68 done
# Row 72 done
# Row 74 done
# Row 75 done
# Row 77 done
# Row 76 done
# Row 79 done
# Row 78 done
# Row 73 done
# Row 81 done
# Row 80 done
# Row 82 done
# Row 83 done
# Row 86 done
# Row 84 done
# Row 88 done
# Row 87 done
# Row 89 done
# Row 85 done
# Row 92 done
# Row 94 done
# Row 95 done
# Row 90 done
# Row 93 done
# Row 98 done
# Row 96 done
# Row 99 done
# Row 100 done
# Row 102 done
# Row 101 done
# Row 97 done
# Row 91 done
# Row 103 done
# Row 105 done
# Row 106 done
# Row 107 done
# Row 110 done
# Row 108 done
# Row 111 done
# Row 112 done
# Row 104 done
# Row 113 done
# Row 114 done
# Row 115 done
# Row 109 done
# Row 116 done
# Row 118 done
# Row 117 done
# Row 120 done
# Row 119 done
# Row 123 done
# Row 129 done
# Row 121 done
# Row 122 done
# Row 127 done
# Row 125 done
# Row 124 done
# Row 126 done
# Row 131 done
# Row 130 done
# Row 128 done
# Row 132 done
# Row 138 done
# Row 134 done
# Row 139 done
# Row 140 done
# Row 135 done
# Row 137 done
# Row 136 done
# Row 141 done
# Row 142 done
# Row 133 done
# Row 144 done
# Row 143 done
# Row 145 done
# Row 146 done
# Row 147 done
# Row 148 done
# Row 151 done
# Row 155 done
# Row 154 done
# Row 152 done
# Row 153 done
# Row 149 done
# Row 157 done
# Row 156 done
# Row 158 done
# Row 150 done
# Row 159 done
# Row 163 done
# Row 165 done
# Row 166 done
# Row 164 done
# Row 161 done
# Row 168 done
# Row 160 done
# Row 169 done
# Row 170 done
# Row 172 done
# Row 162 done
# Row 167 done
# Row 174 done
# Row 173 done
# Row 171 done
# Row 176 done
# Row 175 done
# Row 178 done
# Row 179 done
# Row 177 done
# Row 183 done
# Row 184 done
# Row 185 done
# Row 181 done
# Row 180 done
# Row 186 done
# Row 182 done
# Row 189 done
# Row 188 done
# Row 190 done
# Row 187 done
# Row 191 done
# Row 194 done
# Row 192 done
# Row 196 done
# Row 193 done
# Row 195 done
# Row 197 done
# Row 198 done
# Row 199 done
# Row 200 done
# Row 202 done
# Row 201 done
# Row 203 done
# Row 204 done
# Row 206 done
# Row 207 done
# Row 209 done
# Row 208 done
# Row 210 done
# Row 205 done
# Row 212 done
# Row 211 done
# Row 213 done
# Row 214 done
# Row 215 done
# Row 217 done
# Row 218 done
# Row 216 done
# Row 219 done
# Row 221 done
# Row 224 done
# Row 225 done
# Row 226 done
# Row 223 done
# Row 227 done
# Row 229 done
# Row 230 done
# Row 228 done
# Row 233 done
# Row 235 done
# Row 237 done
# Row 236 done
# Row 239 done
# Row 238 done
# Row 240 done
# Row 242 done
# Row 245 done
# Row 244 done
# Row 247 done
# Row 243 done
# Row 248 done
# Row 246 done
# Row 222 done
# Row 220 done
# Row 234 done
# Row 231 done
# Row 241 done
# Row 232 done
# Row 251 done
# Row 249 done
# Row 252 done
# Row 258 done
# Row 250 done
# Row 253 done
# Row 254 done
# Row 257 done
# Row 259 done
# Row 256 done
# Row 260 done
# Row 255 done
# Row 261 done
# Row 263 done
# Row 262 done
# Row 264 done
# Row 266 done
# Row 268 done
# Row 270 done
# Row 267 done
# Row 269 done
# Row 265 done
# Row 272 done
# Row 271 done
# Row 274 done
# Row 273 done
# Row 276 done
# Row 275 done
# Row 279 done
# Row 278 done
# Row 277 done
# Row 284 done
# Row 283 done
# Row 281 done
# Row 280 done
# Row 285 done
# Row 286 done
# Row 288 done
# Row 289 done
# Row 287 done
# Row 290 done
# Row 282 done
# Row 291 done
# Row 292 done
# Row 293 done
# Row 294 done
# Row 298 done
# Row 295 done
# Row 297 done
# Row 300 done
# Row 299 done
# Row 303 done
# Row 302 done
# Row 301 done
# Row 304 done
# Row 307 done
# Row 296 done
# Row 309 done
# Row 306 done
# Row 308 done
# Row 305 done
# Row 310 done
# Row 311 done
# Row 312 done
# Row 313 done
# Row 314 done
# Row 315 done
# Row 319 done
# Row 318 done
# Row 316 done
# Row 317 done
# Row 322 done
# Row 320 done
# Row 321 done
# Row 323 done
# Row 325 done
# Row 327 done
# Row 326 done
# Row 329 done
# Row 330 done
# Row 324 done
# Row 328 done
# Row 331 done
# Row 335 done
# Row 332 done
# Row 334 done
# Row 337 done
# Row 338 done
# Row 333 done
# Row 336 done
# Row 339 done
# Row 341 done
# Row 342 done
# Row 343 done
# Row 340 done
# Row 344 done
# Row 346 done
# Row 345 done
# Row 347 done
# Row 353 done
# Row 354 done
# Row 348 done
# Row 352 done
# Row 350 done
# Row 349 done
# Row 356 done
# Row 359 done
# Row 355 done
# Row 357 done
# Row 351 done
# Row 360 done
# Row 358 done
# Row 362 done
# Row 363 done
# Row 365 done
# Row 361 done
# Row 364 done
# Row 366 done
# Row 367 done
# Row 368 done
# Row 369 done
# Row 374 done
# Row 371 done
# Row 370 done
# Row 376 done
# Row 377 done
# Row 375 done
# Row 372 done
# Row 379 done
# Row 373 done
# Row 378 done
# Row 381 done
# Row 382 done
# Row 380 done
# Row 383 done
# Row 384 done
# Row 385 done
# Row 388 done
# Row 386 done
# Row 390 done
# Row 387 done
# Row 389 done
# Row 392 done
# Row 393 done
# Row 395 done
# Row 396 done
# Row 391 done
# Row 394 done
# Row 398 done
# Row 402 done
# Row 403 done
# Row 400 done
# Row 399 done
# Row 404 done
# Row 397 done
# Row 401 done
# Row 407 done
# Row 408 done
# Row 405 done
# Row 406 done
# Row 410 done
# Row 411 done
# Row 409 done
# Row 412 done
# Row 413 done
# Row 417 done
# Row 416 done
# Row 418 done
# Row 420 done
# Row 419 done
# Row 415 done
# Row 414 done
# Row 421 done
# Row 424 done
# Row 425 done
# Row 428 done
# Row 426 done
# Row 423 done
# Row 429 done
# Row 430 done
# Row 433 done
# Row 434 done
# Row 431 done
# Row 436 done
# Row 435 done
# Row 427 done
# Row 439 done
# Row 438 done
# Row 437 done
# Row 432 done
# Row 440 done
# Row 422 done
# Row 441 done
# Row 442 done
# Row 444 done
# Row 446 done
# Row 447 done
# Row 450 done
# Row 443 done
# Row 445 done
# Row 448 done
# Row 451 done
# Row 453 done
# Row 452 done
# Row 454 done
# Row 449 done
# Row 455 done
# Row 457 done
# Row 456 done
# Row 459 done
# Row 458 done
# Row 460 done
# Row 464 done
# Row 461 done
# Row 465 done
# Row 462 done
# Row 463 done
# Row 466 done
# Row 467 done
# Row 468 done
# Row 469 done
# Row 470 done
# Row 472 done
# Row 471 done
# Row 473 done
# Row 477 done
# Row 476 done
# Row 475 done
# Row 478 done
# Row 479 done
# Row 474 done
# Row 480 done
# Row 481 done
# Row 482 done
# Row 484 done
# Row 485 done
# Row 490 done
# Row 486 done
# Row 491 done
# Row 488 done
# Row 492 done
# Row 487 done
# Row 483 done
# Row 494 done
# Row 495 done
# Row 497 done
# Row 496 done
# Row 498 done
# Row 499 done
# Row 489 done
# Row 501 done
# Row 493 done
# Row 504 done
# Row 503 done
# Row 505 done
# Row 506 done
# Row 507 done
# Row 502 done
# Row 500 done
# Row 509 done
# Row 515 done
# Row 512 done
# Row 511 done
# Row 510 done
# Row 508 done
# Row 519 done
# Row 517 done
# Row 516 done
# Row 514 done
# Row 513 done
# Row 518 done
# Row 520 done
# Row 522 done
# Row 524 done
# Row 525 done
# Row 521 done
# Row 523 done
# Row 528 done
# Row 526 done
# Row 529 done
# Row 530 done
# Row 527 done
# Row 532 done
# Row 531 done
# Row 533 done
# Row 535 done
# Row 536 done
# Row 534 done
# Row 538 done
# Row 537 done
# Row 543 done
# Row 539 done
# Row 540 done
# Row 542 done
# Row 545 done
# Row 541 done
# Row 547 done
# Row 544 done
# Row 549 done
# Row 546 done
# Row 550 done
# Row 548 done
# Row 551 done
# Row 552 done
# Row 556 done
# Row 554 done
# Row 555 done
# Row 557 done
# Row 553 done
# Row 558 done
# Row 561 done
# Row 560 done
# Row 562 done
# Row 559 done
# Row 563 done
# Row 564 done
# Row 565 done
# Row 566 done
# Row 569 done
# Row 568 done
# Row 570 done
# Row 573 done
# Row 572 done
# Row 567 done
# Row 574 done
# Row 576 done
# Row 571 done
# Row 578 done
# Row 575 done
# Row 579 done
# Row 577 done
# Row 581 done
# Row 580 done
# Row 585 done
# Row 583 done
# Row 584 done
# Row 582 done
# Row 587 done
# Row 590 done
# Row 586 done
# Row 588 done
# Row 591 done
# Row 589 done
# Row 592 done
# Row 593 done
# Row 594 done
# Row 595 done
# Row 597 done
# Row 596 done
# Row 599 done
# Row 601 done
# Row 600 done
# Row 598 done
# Row 602 done
# Row 604 done
# Row 605 done
# Row 607 done
# Row 606 done
# Row 603 done
# Row 608 done
# Row 614 done
# Row 611 done
# Row 610 done
# Row 612 done
# Row 613 done
# Row 615 done
# Row 609 done
# Row 619 done
# Row 616 done
# Row 620 done
# Row 618 done
# Row 617 done
# Row 626 done
# Row 625 done
# Row 622 done
# Row 624 done
# Row 621 done
# Row 628 done
# Row 623 done
# Row 627 done
# Row 632 done
# Row 630 done
# Row 631 done
# Row 629 done
# Row 633 done
# Row 635 done
# Row 634 done
# Row 639 done
# Row 637 done
# Row 640 done
# Row 641 done
# Row 643 done
# Row 638 done
# Row 642 done
# Row 645 done
# Row 636 done
# Row 647 done
# Row 644 done
# Row 646 done
# Row 648 done
# Row 653 done
# Row 655 done
# Row 656 done
# Row 654 done
# Row 659 done
# Row 650 done
# Row 652 done
# Row 651 done
# Row 649 done
# Row 660 done
# Row 657 done
# Row 658 done
# Row 661 done
# Row 663 done
# Row 662 done
# Row 664 done
# Row 666 done
# Row 667 done
# Row 665 done
# Row 672 done
# Row 669 done
# Row 673 done
# Row 670 done
# Row 675 done
# Row 674 done
# Row 671 done
# Row 668 done
# Row 682 done
# Row 676 done
# Row 681 done
# Row 683 done
# Row 678 done
# Row 679 done
# Row 680 done
# Row 684 done
# Row 686 done
# Row 685 done
# Row 677 done
# Row 688 done
# Row 687 done
# Row 691 done
# Row 690 done
# Row 692 done
# Row 693 done
# Row 694 done
# Row 698 done
# Row 696 done
# Row 700 done
# Row 697 done
# Row 695 done
# Row 699 done
# Row 689 done
# Row 705 done
# Row 704 done
# Row 703 done
# Row 706 done
# Row 701 done
# Row 702 done
# Row 712 done
# Row 708 done
# Row 707 done
# Row 709 done
# Row 710 done
# Row 711 done
# Row 715 done
# Row 713 done
# Row 717 done
# Row 716 done
# Row 718 done
# Row 714 done
# Row 721 done
# Row 723 done
# Row 719 done
# Row 722 done
# Row 720 done
# Row 724 done
# Row 725 done
# Row 727 done
# Row 730 done
# Row 729 done
# Row 728 done
# Row 734 done
# Row 732 done
# Row 736 done
# Row 735 done
# Row 733 done
# Row 738 done
# Row 739 done
# Row 741 done
# Row 740 done
# Row 743 done
# Row 745 done
# Row 731 done
# Row 726 done
# Row 744 done
# Row 742 done
# Row 737 done
# Row 749 done
# Row 748 done
# Row 746 done
# Row 747 done
# Row 750 done
# Row 752 done
# Row 753 done
# Row 754 done
# Row 756 done
# Row 751 done
# Row 755 done
# Row 760 done
# Row 759 done
# Row 758 done
# Row 757 done
# Row 762 done
# Row 763 done
# Row 761 done
# Row 764 done
# Row 765 done
# Row 768 done
# Row 766 done
# Row 767 done
# Row 769 done
# Row 771 done
# Row 772 done
# Row 773 done
# Row 770 done
# Row 775 done
# Row 776 done
# Row 774 done
# Row 777 done
# Row 779 done
# Row 778 done
# Row 780 done
# Row 783 done
# Row 782 done
# Row 785 done
# Row 784 done
# Row 789 done
# Row 787 done
# Row 781 done
# Row 788 done
# Row 791 done
# Row 786 done
# Row 790 done
# Row 792 done
# Row 794 done
# Row 803 done
# Row 798 done
# Row 801 done
# Row 800 done
# Row 804 done
# Row 793 done
# Row 796 done
# Row 805 done
# Row 797 done
# Row 795 done
# Row 802 done
# Row 799 done
# Row 806 done
# Row 807 done
# Row 809 done
# Row 808 done
# Row 812 done
# Row 815 done
# Row 810 done
# Row 817 done
# Row 819 done
# Row 816 done
# Row 811 done
# Row 814 done
# Row 818 done
# Row 813 done
# Row 821 done
# Row 820 done
# Row 824 done
# Row 823 done
# Row 822 done
# Row 825 done
# Row 828 done
# Row 827 done
# Row 831 done
# Row 829 done
# Row 830 done
# Row 826 done
# Row 835 done
# Row 833 done
# Row 832 done
# Row 834 done
# Row 837 done
# Row 836 done
# Row 839 done
# Row 838 done
# Row 840 done
# Row 842 done
# Row 848 done
# Row 844 done
# Row 841 done
# Row 846 done
# Row 847 done
# Row 850 done
# Row 843 done
# Row 845 done
# Row 851 done
# Row 849 done
# Row 852 done
# Row 853 done
# Row 857 done
# Row 855 done
# Row 854 done
# Row 860 done
# Row 859 done
# Row 858 done
# Row 856 done
# Row 862 done
# Row 861 done
# Row 863 done
# Row 864 done
# Row 867 done
# Row 865 done
# Row 868 done
# Row 866 done
# Row 871 done
# Row 870 done
# Row 869 done
# Row 872 done
# Row 874 done
# Row 875 done
# Row 873 done
# Row 877 done
# Row 878 done
# Row 882 done
# Row 876 done
# Row 879 done
# Row 880 done
# Row 883 done
# Row 881 done
# Row 887 done
# Row 886 done
# Row 888 done
# Row 884 done
# Row 889 done
# Row 885 done
# Row 890 done
# Row 892 done
# Row 891 done
# Row 894 done
# Row 893 done
# Row 897 done
# Row 895 done
# Row 898 done
# Row 896 done
# Row 901 done
# Row 899 done
# Row 900 done
# Row 902 done
# Row 904 done
# Row 903 done
# Row 905 done
# Row 908 done
# Row 910 done
# Row 907 done
# Row 909 done
# Row 912 done
# Row 906 done
# Row 911 done
# Row 913 done
# Row 915 done
# Row 914 done
# Row 916 done
# Row 917 done
# Row 919 done
# Row 920 done
# Row 918 done
# Row 921 done
# Row 922 done
# Row 923 done
# Row 925 done
# Row 927 done
# Row 924 done
# Row 928 done
# Row 926 done
# Row 931 done
# Row 930 done
# Row 929 done
# Row 932 done
# Row 939 done
# Row 940 done
# Row 934 done
# Row 936 done
# Row 938 done
# Row 935 done
# Row 933 done
# Row 942 done
# Row 943 done
# Row 937 done
# Row 945 done
# Row 944 done
# Row 941 done
# Row 946 done
# Row 948 done
# Row 953 done
# Row 952 done
# Row 958 done
# Row 947 done
# Row 955 done
# Row 951 done
# Row 954 done
# Row 950 done
# Row 957 done
# Row 959 done
# Row 949 done
# Row 960 done
# Row 956 done
# Row 962 done
# Row 961 done
# Row 963 done
# Row 965 done
# Row 964 done
# Row 966 done
# Row 969 done
# Row 967 done
# Row 968 done
# Row 972 done
# Row 975 done
# Row 973 done
# Row 970 done
# Row 980 done
# Row 976 done
# Row 979 done
# Row 977 done
# Row 974 done
# Row 971 done
# Row 982 done
# Row 978 done
# Row 981 done
# Row 983 done
# Row 985 done
# Row 984 done
# Row 987 done
# Row 989 done
# Row 990 done
# Row 991 done
# Row 988 done
# Row 995 done
# Row 992 done
# Row 993 done
# Row 996 done
# Row 994 done
# Row 997 done
# Row 986 done
# Row 998 done
# Row 999 done
# Row 1001 done
# Row 1000 done
# Row 1002 done
# Row 1006 done
# Row 1009 done
# Row 1008 done
# Row 1004 done
# Row 1003 done
# Row 1010 done
# Row 1007 done
# Row 1013 done
# Row 1012 done
# Row 1005 done
# Row 1011 done
# Row 1014 done
# Row 1015 done
# Row 1016 done
# Row 1017 done
# Row 1019 done
# Row 1024 done
# Row 1025 done
# Row 1018 done
# Row 1022 done
# Row 1021 done
# Row 1023 done
# Row 1026 done
# Row 1020 done
# Row 1029 done
# Row 1027 done
# Row 1028 done
# Row 1030 done
# Row 1031 done
# Row 1032 done
# Row 1034 done
# Row 1035 done
# Row 1033 done
# Row 1036 done
# Row 1040 done
# Row 1039 done
# Row 1038 done
# Row 1041 done
# Row 1037 done
# Row 1043 done
# Row 1042 done
# Row 1044 done
# Row 1045 done
# Row 1048 done
# Row 1046 done
# Row 1047 done
# Row 1049 done
# Row 1050 done
# Row 1051 done
# Row 1052 done
# Row 1057 done
# Row 1053 done
# Row 1056 done
# Row 1055 done
# Row 1058 done
# Row 1054 done
# Row 1059 done
# Row 1060 done
# Row 1061 done
# Row 1062 done
# Row 1063 done
# Row 1065 done
# Row 1067 done
# Row 1064 done
# Row 1068 done
# Row 1066 done
# Row 1069 done
# Row 1070 done
# Row 1072 done
# Row 1074 done
# Row 1073 done
# Row 1071 done
# Row 1075 done
# Row 1076 done
# Row 1080 done
# Row 1077 done
# Row 1079 done
# Row 1081 done
# Row 1084 done
# Row 1082 done
# Row 1078 done
# Row 1086 done
# Row 1083 done
# Row 1085 done
# Row 1087 done
# Row 1088 done
# Row 1090 done
# Row 1094 done
# Row 1091 done
# Row 1093 done
# Row 1098 done
# Row 1095 done
# Row 1096 done
# Row 1097 done
# Row 1092 done
# Row 1099 done
# Row 1100 done
# Row 1101 done
# Row 1102 done
# Row 1104 done
# Row 1103 done
# Row 1105 done
# Row 1089 done
# Row 1106 done
# Row 1109 done
# Row 1108 done
# Row 1110 done
# Row 1107 done
# Row 1113 done
# Row 1114 done
# Row 1112 done
# Row 1111 done
# Row 1116 done
# Row 1115 done
# Row 1117 done
# Row 1118 done
# Row 1123 done
# Row 1119 done
# Row 1124 done
# Row 1121 done
# Row 1125 done
# Row 1126 done
# Row 1122 done
# Row 1120 done
# Row 1127 done
# Row 1128 done
# Row 1129 done
# Row 1130 done
# Row 1134 done
# Row 1135 done
# Row 1133 done
# Row 1131 done
# Row 1136 done
# Row 1138 done
# Row 1141 done
# Row 1137 done
# Row 1140 done
# Row 1132 done
# Row 1143 done
# Row 1142 done
# Row 1144 done
# Row 1145 done
# Row 1139 done
# Row 1146 done
# Row 1147 done
# Row 1148 done
# Row 1151 done
# Row 1149 done
# Row 1150 done
# Row 1153 done
# Row 1152 done
# Row 1156 done
# Row 1157 done
# Row 1158 done
# Row 1154 done
# Row 1159 done
# Row 1161 done
# Row 1160 done
# Row 1162 done
# Row 1163 done
# Row 1166 done
# Row 1164 done
# Row 1155 done
# Row 1168 done
# Row 1169 done
# Row 1170 done
# Row 1173 done
# Row 1172 done
# Row 1174 done
# Row 1171 done
# Row 1167 done
# Row 1175 done
# Row 1165 done
# Row 1177 done
# Row 1176 done
# Row 1180 done
# Row 1179 done
# Row 1178 done
# Row 1181 done
# Row 1182 done
# Row 1183 done
# Row 1187 done
# Row 1184 done
# Row 1186 done
# Row 1189 done
# Row 1190 done
# Row 1192 done
# Row 1191 done
# Row 1188 done
# Row 1185 done
# Row 1195 done
# Row 1193 done
# Row 1197 done
# Row 1194 done
# Row 1196 done
# Row 1198 done
# Row 1199 done
# Row 1200 done
# Row 1201 done
# Row 1203 done
# Row 1202 done
# Row 1205 done
# Row 1204 done
# Row 1206 done
# Row 1207 done
# Row 1208 done
# Row 1210 done
# Row 1211 done
# Row 1213 done
# Row 1214 done
# Row 1216 done
# Row 1212 done
# Row 1215 done
# Row 1217 done
# Row 1209 done
# Row 1219 done
# Row 1218 done
# Row 1222 done
# Row 1220 done
# Row 1221 done
# Row 1223 done
# Row 1224 done
# Row 1225 done
# Row 1227 done
# Row 1229 done
# Row 1228 done
# Row 1233 done
# Row 1231 done
# Row 1235 done
# Row 1234 done
# Row 1230 done
# Row 1226 done
# Row 1232 done
# Row 1236 done
# Row 1237 done
# Row 1238 done
# Row 1239 done
# Row 1241 done
# Row 1243 done
# Row 1244 done
# Row 1247 done
# Row 1245 done
# Row 1240 done
# Row 1246 done
# Row 1242 done
# Row 1249 done
# Row 1248 done
# Row 1250 done
# Row 1251 done
# Row 1253 done
# Row 1254 done
# Row 1260 done
# Row 1258 done
# Row 1262 done
# Row 1261 done
# Row 1252 done
# Row 1256 done
# Row 1257 done
# Row 1259 done
# Row 1264 done
# Row 1263 done
# Row 1255 done
# Row 1265 done
# Row 1267 done
# Row 1266 done
# Row 1269 done
# Row 1270 done
# Row 1268 done
# Row 1276 done
# Row 1273 done
# Row 1272 done
# Row 1275 done
# Row 1277 done
# Row 1271 done
# Row 1278 done
# Row 1274 done
# Row 1279 done
# Row 1280 done
# Row 1281 done
# Row 1282 done
# Row 1283 done
# Row 1284 done
# Row 1285 done
# Row 1286 done
# Row 1287 done
# Row 1289 done
# Row 1290 done
# Row 1288 done
# Row 1291 done
# Row 1292 done
# Row 1293 done
# Row 1296 done
# Row 1294 done
# Row 1297 done
# Row 1295 done
# Row 1302 done
# Row 1298 done
# Row 1299 done
# Row 1301 done
# Row 1300 done
# Row 1304 done
# Row 1309 done
# Row 1308 done
# Row 1306 done
# Row 1305 done
# Row 1307 done
# Row 1303 done
# Row 1310 done
# Row 1313 done
# Row 1311 done
# Row 1315 done
# Row 1312 done
# Row 1320 done
# Row 1319 done
# Row 1318 done
# Row 1321 done
# Row 1316 done
# Row 1322 done
# Row 1314 done
# Row 1317 done
# Row 1327 done
# Row 1326 done
# Row 1325 done
# Row 1323 done
# Row 1324 done
# Row 1328 done
# Row 1331 done
# Row 1329 done
# Row 1330 done
# Row 1332 done
# Row 1333 done
# Row 1337 done
# Row 1335 done
# Row 1334 done
# Row 1339 done
# Row 1336 done
# Row 1338 done
# Row 1340 done
# Row 1341 done
# Row 1344 done
# Row 1345 done
# Row 1342 done
# Row 1346 done
# Row 1352 done
# Row 1349 done
# Row 1347 done
# Row 1351 done
# Row 1350 done
# Row 1343 done
# Row 1348 done
# Row 1353 done
# Row 1354 done
# Row 1355 done
# Row 1356 done
# Row 1360 done
# Row 1361 done
# Row 1364 done
# Row 1362 done
# Row 1365 done
# Row 1357 done
# Row 1363 done
# Row 1358 done
# Row 1366 done
# Row 1368 done
# Row 1367 done
# Row 1369 done
# Row 1359 done
# Row 1370 done
# Row 1371 done
# Row 1372 done
# Row 1374 done
# Row 1373 done
# Row 1376 done
# Row 1380 done
# Row 1375 done
# Row 1379 done
# Row 1383 done
# Row 1377 done
# Row 1378 done
# Row 1384 done
# Row 1382 done
# Row 1385 done
# Row 1386 done
# Row 1387 done
# Row 1381 done
# Row 1391 done
# Row 1392 done
# Row 1389 done
# Row 1390 done
# Row 1396 done
# Row 1393 done
# Row 1388 done
# Row 1394 done
# Row 1395 done
#                    preprint_doi               published_doi_x accession_found  \
# 0                10.1101/001107         10.1101/gr.181016.114        GSE58871
# 1                10.1101/002006      10.1186/1471-2164-15-962        GSE54119
# 2                10.1101/004853  10.1371/journal.pgen.1004402        GSE50759
# 3                10.1101/006171  10.1371/journal.pgen.1004663        GSE57483
# 4                10.1101/006270           10.7554/eLife.03915        GSE58423
# ...                         ...                           ...             ...
# 1392  10.1101/2020.12.28.424586    10.1172/jci.insight.147280       GSE163649
# 1393  10.1101/2020.12.29.424680     10.3389/fnins.2021.671249       GSE160992
# 1394  10.1101/2020.12.30.424365           10.7554/eLife.70514       GSE163775
# 1395  10.1101/2020.12.30.424776        10.15252/msb.202110207       GSE158319
# 1396  10.1101/2020.12.30.424817    10.1186/s13059-021-02453-5       GSE163896
#
#                                               GSM_links
# 0     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# ...                                                 ...
# 1392  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1393  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1394  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1395  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1396  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
# [1397 rows x 4 columns]

# %%
# Save the modified DataFrame back to the CSV file
df.to_csv("/content/srr_dates_final.csv", index=False)

# %% [markdown]
# For every GSM links separated by "," and within a cell, let's create a new row for every GSM link

# %%
import pandas as pd
df=pd.read_csv('/content/srr_dates_final.csv')
df['GSM_links'] = df['GSM_links'].astype(str)
df['GSM_links'] = df['GSM_links'].str.replace(' ', '')
df['GSM_links'] = df['GSM_links'].str.split(',')
df = df.explode('GSM_links')
df

# %%
df.to_csv('/content/srr_dates_exploded.csv')

# %% [markdown]
# # **Extract all the SRX links based in the give GSM links**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

def extract_all_SRX_links(GSM_url):
    # Send an HTTP GET request to the URL
    response = requests.get(GSM_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Get the content of the response
        content = response.content

        # Create a BeautifulSoup object and specify the parser
        soup = BeautifulSoup(content, "html.parser")

        # Find all the <strong> elements in the HTML
        strong_elems = soup.find_all('strong')

        # Variable to track if 'Relations' was found
        relations_found = False

        # Iterate over the <strong> elements
        for strong_elem in strong_elems:
            # Check if 'Relations' is present in the text of the <strong> element
            if 'Relations' in strong_elem.text:
                relations_found = True
                break
        href_found = []
        # If 'Relations' was found, proceed with extracting the links
        if relations_found:
            tr_elems = soup.find_all('tr')
            for tr_elem in tr_elems:
                # Check if the <tr> element has 'valign' attribute set to 'top' and contains 'SRA' in its text
                if tr_elem.get('valign') == 'top' and 'SRA' in tr_elem.text:
                    links = tr_elem.find_all('a')
                    href_found = None
                    for link in links:
                        href_found = link.get('href')
                        if 'SRX' in href_found:
                            return href_found
        # If 'Relations' was not found
        else:
            return "SRX not found"

    else:
        return "Request failed. Status code:", response.status_code

def process_row(row):
    GSM_url = row['GSM_links']
    return extract_all_SRX_links(GSM_url)

df1 = pd.read_csv("/content/srr_dates_exploded.csv")

# Prepare a dictionary to hold our results
results = {}

# Use ThreadPoolExecutor to parallelize the extraction
with ThreadPoolExecutor(max_workers=12) as executor:
    # Submit tasks to the executor
    future_to_row = {executor.submit(process_row, row): index for index, row in df1.iterrows()}

    # Collect the results as they are completed
    for future in as_completed(future_to_row):
        index = future_to_row[future]
        try:
            results[index] = future.result()
        except Exception as exc:
            print(f'Generated an exception: {exc}')
        else:
            print(f'Row {index} done')

    # Update the DataFrame with the results
for index, href_found in results.items():
    # Convert the list of links to a string representation if you want to store it in a single cell
    # You can choose a separator that suits your needs; here, I use a comma.
    df1.at[index, 'SRX_links'] = href_found
df1
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Row 60179 done
# Row 60178 done
# Row 60180 done
# Row 60181 done
# Row 60182 done
# Row 60183 done
# Row 60184 done
# Row 60166 done
# Row 60177 done
# Row 60172 done
# Row 60186 done
# Row 60187 done
# Row 60190 done
# Row 60189 done
# Row 60185 done
# Row 60188 done
# Row 60191 done
# Row 60192 done
# Row 60193 done
# Row 60195 done
# Row 60194 done
# Row 60196 done
# Row 60197 done
# Row 60200 done
# Row 60199 done
# Row 60202 done
# Row 60203 done
# Row 60201 done
# Row 60198 done
# Row 60207 done
# Row 60204 done
# Row 60205 done
# Row 60208 done
# Row 60206 done
# Row 60209 done
# Row 60210 done
# Row 60211 done
# Row 60212 done
# Row 60219 done
# Row 60220 done
# Row 60214 done
# Row 60218 done
# Row 60213 done
# Row 60221 done
# Row 60222 done
# Row 60223 done
# Row 60217 done
# Row 60215 done
# Row 60216 done
# Row 60224 done
# Row 60225 done
# Row 60226 done
# Row 60227 done
# Row 60228 done
# Row 60229 done
# Row 60233 done
# Row 60232 done
# Row 60234 done
# Row 60235 done
# Row 60230 done
# Row 60231 done
# Row 60236 done
# Row 60237 done
# Row 60238 done
# Row 60240 done
# Row 60239 done
# Row 60241 done
# Row 60244 done
# Row 60243 done
# Row 60246 done
# Row 60245 done
# Row 60242 done
# Row 60248 done
# Row 60247 done
# Row 60249 done
# Row 60250 done
# Row 60253 done
# Row 60251 done
# Row 60252 done
# Row 60254 done
# Row 60258 done
# Row 60255 done
# Row 60257 done
# Row 60259 done
# Row 60261 done
# Row 60260 done
# Row 60265 done
# Row 60256 done
# Row 60263 done
# Row 60262 done
# Row 60266 done
# Row 60264 done
# Row 60267 done
# Row 60268 done
# Row 60269 done
# Row 60270 done
# Row 60272 done
# Row 60276 done
# Row 60273 done
# Row 60271 done
# Row 60275 done
# Row 60277 done
# Row 60274 done
# Row 60278 done
# Row 60279 done
# Row 60281 done
# Row 60282 done
# Row 60280 done
# Row 60283 done
# Row 60286 done
# Row 60285 done
# Row 60284 done
# Row 60289 done
# Row 60290 done
# Row 60288 done
# Row 60287 done
# Row 60291 done
# Row 60292 done
# Row 60293 done
# Row 60295 done
# Row 60294 done
# Row 60296 done
# Row 60297 done
# Row 60298 done
# Row 60301 done
# Row 60299 done
# Row 60300 done
# Row 60304 done
# Row 60303 done
# Row 60305 done
# Row 60302 done
# Row 60306 done
# Row 60307 done
# Row 60308 done
# Row 60310 done
# Row 60309 done
# Row 60311 done
# Row 60314 done
# Row 60315 done
# Row 60316 done
# Row 60312 done
# Row 60313 done
# Row 60318 done
# Row 60319 done
# Row 60321 done
# Row 60317 done
# Row 60320 done
# Row 60322 done
# Row 60323 done
# Row 60326 done
# Row 60325 done
# Row 60324 done
# Row 60328 done
# Row 60330 done
# Row 60335 done
# Row 60334 done
# Row 60332 done
# Row 60329 done
# Row 60331 done
# Row 60327 done
# Row 60333 done
# Row 60336 done
# Row 60337 done
# Row 60338 done
# Row 60340 done
# Row 60339 done
# Row 60342 done
# Row 60345 done
# Row 60341 done
# Row 60343 done
# Row 60344 done
# Row 60347 done
# Row 60346 done
# Row 60348 done
# Row 60349 done
# Row 60352 done
# Row 60351 done
# Row 60350 done
# Row 60354 done
# Row 60358 done
# Row 60355 done
# Row 60357 done
# Row 60359 done
# Row 60360 done
# Row 60353 done
# Row 60356 done
# Row 60361 done
# Row 60362 done
# Row 60364 done
# Row 60363 done
# Row 60366 done
# Row 60368 done
# Row 60372 done
# Row 60370 done
# Row 60373 done
# Row 60367 done
# Row 60369 done
# Row 60365 done
# Row 60374 done
# Row 60371 done
# Row 60375 done
# Row 60376 done
# Row 60377 done
# Row 60378 done
# Row 60379 done
# Row 60380 done
# Row 60381 done
# Row 60385 done
# Row 60382 done
# Row 60388 done
# Row 60387 done
# Row 60386 done
# Row 60389 done
# Row 60383 done
# Row 60393 done
# Row 60392 done
# Row 60384 done
# Row 60390 done
# Row 60391 done
# Row 60394 done
# Row 60395 done
# Row 60396 done
# Row 60397 done
# Row 60399 done
# Row 60398 done
# Row 60401 done
# Row 60403 done
# Row 60405 done
# Row 60404 done
# Row 60400 done
# Row 60409 done
# Row 60406 done
# Row 60402 done
# Row 60408 done
# Row 60407 done
# Row 60410 done
# Row 60411 done
# Row 60412 done
# Row 60413 done
# Row 60414 done
# Row 60415 done
# Row 60421 done
# Row 60417 done
# Row 60423 done
# Row 60422 done
# Row 60420 done
# Row 60419 done
# Row 60418 done
# Row 60416 done
# Row 60424 done
# Row 60426 done
# Row 60425 done
# Row 60427 done
# Row 60428 done
# Row 60433 done
# Row 60430 done
# Row 60429 done
# Row 60435 done
# Row 60431 done
# Row 60432 done
# Row 60438 done
# Row 60434 done
# Row 60436 done
# Row 60437 done
# Row 60440 done
# Row 60441 done
# Row 60439 done
# Row 60442 done
# Row 60443 done
# Row 60445 done
# Row 60447 done
# Row 60448 done
# Row 60446 done
# Row 60451 done
# Row 60444 done
# Row 60452 done
# Row 60450 done
# Row 60453 done
# Row 60449 done
# Row 60454 done
# Row 60455 done
# Row 60456 done
# Row 60457 done
# Row 60458 done
# Row 60463 done
# Row 60460 done
# Row 60459 done
# Row 60462 done
# Row 60465 done
# Row 60461 done
# Row 60464 done
# Row 60466 done
# Row 60468 done
# Row 60467 done
# Row 60469 done
# Row 60470 done
# Row 60472 done
# Row 60475 done
# Row 60471 done
# Row 60476 done
# Row 60474 done
# Row 60477 done
# Row 60473 done
# Row 60479 done
# Row 60478 done
# Row 60481 done
# Row 60480 done
# Row 60482 done
# Row 60483 done
# Row 60484 done
# Row 60485 done
# Row 60488 done
# Row 60490 done
# Row 60489 done
# Row 60487 done
# Row 60492 done
# Row 60486 done
# Row 60494 done
# Row 60491 done
# Row 60495 done
# Row 60493 done
# Row 60497 done
# Row 60496 done
# Row 60501 done
# Row 60498 done
# Row 60500 done
# Row 60504 done
# Row 60502 done
# Row 60503 done
# Row 60499 done
# Row 60505 done
# Row 60507 done
# Row 60508 done
# Row 60509 done
# Row 60506 done
# Row 60511 done
# Row 60510 done
# Row 60512 done
# Row 60517 done
# Row 60519 done
# Row 60518 done
# Row 60514 done
# Row 60522 done
# Row 60516 done
# Row 60520 done
# Row 60521 done
# Row 60513 done
# Row 60515 done
# Row 60523 done
# Row 60525 done
# Row 60528 done
# Row 60527 done
# Row 60524 done
# Row 60526 done
# Row 60529 done
# Row 60533 done
# Row 60532 done
# Row 60536 done
# Row 60535 done
# Row 60534 done
# Row 60530 done
# Row 60531 done
# Row 60537 done
# Row 60538 done
# Row 60539 done
# Row 60540 done
# Row 60541 done
# Row 60543 done
# Row 60544 done
# Row 60547 done
# Row 60542 done
# Row 60545 done
# Row 60548 done
# Row 60546 done
# Row 60549 done
# Row 60550 done
# Row 60551 done
# Row 60552 done
# Row 60553 done
# Row 60554 done
# Row 60556 done
# Row 60555 done
# Row 60557 done
# Row 60560 done
# Row 60561 done
# Row 60559 done
# Row 60562 done
# Row 60558 done
# Row 60563 done
# Row 60564 done
# Row 60565 done
# Row 60566 done
# Row 60567 done
# Row 60568 done
# Row 60569 done
# Row 60571 done
# Row 60573 done
# Row 60572 done
# Row 60574 done
# Row 60576 done
# Row 60575 done
# Row 60577 done
# Row 60579 done
# Row 60580 done
# Row 60581 done
# Row 60582 done
# Row 60578 done
# Row 60570 done
# Row 60583 done
# Row 60587 done
# Row 60585 done
# Row 60584 done
# Row 60586 done
# Row 60588 done
# Row 60589 done
# Row 60590 done
# Row 60591 done
# Row 60592 done
# Row 60593 done
# Row 60595 done
# Row 60594 done
# Row 60596 done
# Row 60600 done
# Row 60599 done
# Row 60597 done
# Row 60601 done
# Row 60598 done
# Row 60602 done
# Row 60603 done
# Row 60604 done
# Row 60605 done
# Row 60606 done
# Row 60607 done
# Row 60608 done
# Row 60610 done
# Row 60612 done
# Row 60614 done
# Row 60611 done
# Row 60613 done
# Row 60615 done
# Row 60616 done
# Row 60618 done
# Row 60609 done
# Row 60617 done
# Row 60620 done
# Row 60619 done
# Row 60621 done
# Row 60622 done
# Row 60623 done
# Row 60624 done
# Row 60626 done
# Row 60625 done
# Row 60627 done
# Row 60628 done
# Row 60629 done
# Row 60631 done
# Row 60630 done
# Row 60632 done
# Row 60633 done
# Row 60634 done
# Row 60635 done
# Row 60637 done
# Row 60639 done
# Row 60636 done
# Row 60638 done
# Row 60641 done
# Row 60640 done
# Row 60643 done
# Row 60644 done
# Row 60642 done
# Row 60645 done
# Row 60646 done
# Row 60647 done
# Row 60648 done
# Row 60649 done
# Row 60650 done
# Row 60651 done
# Row 60653 done
# Row 60656 done
# Row 60652 done
# Row 60654 done
# Row 60658 done
# Row 60657 done
# Row 60660 done
# Row 60655 done
# Row 60659 done
# Row 60661 done
# Row 60662 done
# Row 60663 done
# Row 60664 done
# Row 60665 done
# Row 60666 done
# Row 60667 done
# Row 60668 done
# Row 60671 done
# Row 60672 done
# Row 60673 done
# Row 60669 done
# Row 60670 done
# Row 60674 done
# Row 60675 done
# Row 60676 done
# Row 60677 done
# Row 60678 done
# Row 60680 done
# Row 60679 done
# Row 60685 done
# Row 60684 done
# Row 60683 done
# Row 60682 done
# Row 60686 done
# Row 60681 done
# Row 60687 done
# Row 60688 done
# Row 60689 done
# Row 60691 done
# Row 60690 done
# Row 60692 done
# Row 60693 done
# Row 60694 done
# Row 60697 done
# Row 60699 done
# Row 60696 done
# Row 60695 done
# Row 60700 done
# Row 60698 done
# Row 60701 done
# Row 60703 done
# Row 60702 done
# Row 60704 done
# Row 60705 done
# Row 60706 done
# Row 60709 done
# Row 60708 done
# Row 60714 done
# Row 60710 done
# Row 60713 done
# Row 60712 done
# Row 60711 done
# Row 60707 done
# Row 60715 done
# Row 60717 done
# Row 60716 done
# Row 60718 done
# Row 60719 done
# Row 60720 done
# Row 60722 done
# Row 60721 done
# Row 60726 done
# Row 60725 done
# Row 60729 done
# Row 60730 done
# Row 60728 done
# Row 60723 done
# Row 60731 done
# Row 60727 done
# Row 60724 done
# Row 60732 done
# Row 60733 done
# Row 60734 done
# Row 60735 done
# Row 60736 done
# Row 60740 done
# Row 60739 done
# Row 60737 done
# Row 60738 done
# Row 60741 done
# Row 60742 done
# Row 60745 done
# Row 60743 done
# Row 60744 done
# Row 60746 done
# Row 60748 done
# Row 60747 done
# Row 60750 done
# Row 60751 done
# Row 60749 done
# Row 60757 done
# Row 60752 done
# Row 60753 done
# Row 60756 done
# Row 60754 done
# Row 60758 done
# Row 60755 done
# Row 60759 done
# Row 60760 done
# Row 60761 done
# Row 60762 done
# Row 60769 done
# Row 60766 done
# Row 60767 done
# Row 60765 done
# Row 60764 done
# Row 60771 done
# Row 60773 done
# Row 60763 done
# Row 60772 done
# Row 60770 done
# Row 60774 done
# Row 60768 done
# Row 60777 done
# Row 60775 done
# Row 60784 done
# Row 60779 done
# Row 60776 done
# Row 60780 done
# Row 60778 done
# Row 60783 done
# Row 60785 done
# Row 60781 done
# Row 60786 done
# Row 60782 done
# Row 60788 done
# Row 60787 done
# Row 60789 done
# Row 60790 done
# Row 60791 done
# Row 60792 done
# Row 60797 done
# Row 60793 done
# Row 60795 done
# Row 60794 done
# Row 60796 done
# Row 60798 done
# Row 60799 done
# Row 60800 done
# Row 60801 done
# Row 60802 done
# Row 60803 done
# Row 60807 done
# Row 60804 done
# Row 60805 done
# Row 60811 done
# Row 60810 done
# Row 60808 done
# Row 60806 done
# Row 60809 done
# Row 60812 done
# Row 60813 done
# Row 60814 done
# Row 60815 done
# Row 60817 done
# Row 60816 done
# Row 60818 done
# Row 60820 done
# Row 60827 done
# Row 60822 done
# Row 60819 done
# Row 60821 done
# Row 60825 done
# Row 60826 done
# Row 60824 done
# Row 60823 done
# Row 60828 done
# Row 60829 done
# Row 60830 done
# Row 60832 done
# Row 60831 done
# Row 60833 done
# Row 60835 done
# Row 60834 done
# Row 60836 done
# Row 60839 done
# Row 60837 done
# Row 60840 done
# Row 60838 done
# Row 60842 done
# Row 60843 done
# Row 60844 done
# Row 60846 done
# Row 60845 done
# Row 60850 done
# Row 60847 done
# Row 60848 done
# Row 60851 done
# Row 60849 done
# Row 60853 done
# Row 60854 done
# Row 60855 done
# Row 60857 done
# Row 60856 done
# Row 60858 done
# Row 60841 done
# Row 60860 done
# Row 60859 done
# Row 60861 done
# Row 60863 done
# Row 60862 done
# Row 60865 done
# Row 60866 done
# Row 60864 done
# Row 60867 done
# Row 60868 done
# Row 60870 done
# Row 60871 done
# Row 60869 done
# Row 60872 done
# Row 60873 done
# Row 60874 done
# Row 60875 done
# Row 60876 done
# Row 60878 done
# Row 60852 done
# Row 60881 done
# Row 60882 done
# Row 60883 done
# Row 60880 done
# Row 60884 done
# Row 60885 done
# Row 60886 done
# Row 60887 done
# Row 60888 done
# Row 60877 done
# Row 60879 done
# Row 60891 done
# Row 60894 done
# Row 60896 done
# Row 60889 done
# Row 60890 done
# Row 60895 done
# Row 60892 done
# Row 60893 done
# Row 60897 done
# Row 60899 done
# Row 60901 done
# Row 60898 done
# Row 60900 done
# Row 60907 done
# Row 60902 done
# Row 60903 done
# Row 60905 done
# Row 60908 done
# Row 60906 done
# Row 60909 done
# Row 60904 done
# Row 60910 done
# Row 60911 done
# Row 60912 done
# Row 60916 done
# Row 60918 done
# Row 60914 done
# Row 60913 done
# Row 60915 done
# Row 60917 done
# Row 60923 done
# Row 60919 done
# Row 60921 done
# Row 60924 done
# Row 60920 done
# Row 60922 done
# Row 60925 done
# Row 60926 done
# Row 60927 done
# Row 60928 done
# Row 60929 done
# Row 60930 done
# Row 60931 done
# Row 60932 done
# Row 60936 done
# Row 60935 done
# Row 60933 done
# Row 60937 done
# Row 60934 done
# Row 60938 done
# Row 60941 done
# Row 60939 done
# Row 60942 done
# Row 60940 done
# Row 60943 done
# Row 60946 done
# Row 60945 done
# Row 60944 done
# Row 60948 done
# Row 60949 done
# Row 60947 done
# Row 60950 done
# Row 60954 done
# Row 60953 done
# Row 60951 done
# Row 60952 done
# Row 60955 done
# Row 60957 done
# Row 60956 done
# Row 60960 done
# Row 60959 done
# Row 60958 done
# Row 60961 done
# Row 60962 done
# Row 60964 done
# Row 60963 done
# Row 60966 done
# Row 60965 done
# Row 60967 done
# Row 60968 done
# Row 60971 done
# Row 60972 done
# Row 60975 done
# Row 60976 done
# Row 60974 done
# Row 60973 done
# Row 60979 done
# Row 60969 done
# Row 60970 done
# Row 60977 done
# Row 60978 done
# Row 60980 done
# Row 60981 done
# Row 60982 done
# Row 60983 done
# Row 60985 done
# Row 60984 done
# Row 60990 done
# Row 60987 done
# Row 60988 done
# Row 60986 done
# Row 60992 done
# Row 60993 done
# Row 60994 done
# Row 60995 done
# Row 60989 done
# Row 60991 done
# Row 60996 done
# Row 60997 done
# Row 60998 done
# Row 60999 done
# Row 61000 done
# Row 61002 done
# Row 61005 done
# Row 61003 done
# Row 61001 done
# Row 61004 done
# Row 61006 done
# Row 61007 done
# Row 61009 done
# Row 61008 done
# Row 61010 done
# Row 61011 done
# Row 61012 done
# Row 61013 done
# Row 61014 done
# Row 61017 done
# Row 61020 done
# Row 61016 done
# Row 61015 done
# Row 61018 done
# Row 61023 done
# Row 61026 done
# Row 61021 done
# Row 61025 done
# Row 61022 done
# Row 61019 done
# Row 61027 done
# Row 61024 done
# Row 61028 done
# Row 61031 done
# Row 61029 done
# Row 61030 done
# Row 61032 done
# Row 61033 done
# Row 61034 done
# Row 61035 done
# Row 61039 done
# Row 61036 done
# Row 61037 done
# Row 61042 done
# Row 61038 done
# Row 61040 done
# Row 61041 done
# Row 61043 done
# Row 61044 done
# Row 61046 done
# Row 61045 done
# Row 61048 done
# Row 61047 done
# Row 61050 done
# Row 61049 done
# Row 61052 done
# Row 61053 done
# Row 61055 done
# Row 61056 done
# Row 61054 done
# Row 61058 done
# Row 61051 done
# Row 61057 done
# Row 61060 done
# Row 61059 done
# Row 61061 done
# Row 61062 done
# Row 61063 done
# Row 61065 done
# Row 61064 done
# Row 61067 done
# Row 61066 done
# Row 61068 done
# Row 61069 done
# Row 61070 done
# Row 61071 done
# Row 61072 done
# Row 61073 done
# Row 61074 done
# Row 61075 done
# Row 61076 done
# Row 61077 done
# Row 61078 done
# Row 61080 done
# Row 61079 done
# Row 61084 done
# Row 61082 done
# Row 61081 done
# Row 61085 done
# Row 61083 done
# Row 61086 done
# Row 61087 done
# Row 61089 done
# Row 61088 done
# Row 61090 done
# Row 61091 done
# Row 61092 done
# Row 61093 done
# Row 61096 done
# Row 61094 done
# Row 61097 done
# Row 61095 done
# Row 61100 done
# Row 61098 done
# Row 61101 done
# Row 61102 done
# Row 61104 done
# Row 61103 done
# Row 61105 done
# Row 61106 done
# Row 61099 done
# Row 61107 done
# Row 61108 done
# Row 61110 done
# Row 61109 done
# Row 61113 done
# Row 61112 done
# Row 61114 done
# Row 61115 done
# Row 61117 done
# Row 61111 done
# Row 61118 done
# Row 61120 done
# Row 61121 done
# Row 61119 done
# Row 61122 done
# Row 61125 done
# Row 61123 done
# Row 61126 done
# Row 61116 done
# Row 61124 done
# Row 61127 done
# Row 61128 done
# Row 61129 done
# Row 61137 done
# Row 61133 done
# Row 61130 done
# Row 61135 done
# Row 61136 done
# Row 61132 done
# Row 61134 done
# Row 61131 done
# Row 61139 done
# Row 61138 done
# Row 61140 done
# Row 61142 done
# Row 61141 done
# Row 61148 done
# Row 61145 done
# Row 61144 done
# Row 61147 done
# Row 61146 done
# Row 61149 done
# Row 61151 done
# Row 61152 done
# Row 61150 done
# Row 61143 done
# Row 61153 done
# Row 61154 done
# Row 61156 done
# Row 61158 done
# Row 61159 done
# Row 61161 done
# Row 61160 done
# Row 61157 done
# Row 61155 done
# Row 61165 done
# Row 61162 done
# Row 61163 done
# Row 61166 done
# Row 61164 done
# Row 61167 done
# Row 61168 done
# Row 61169 done
# Row 61176 done
# Row 61175 done
# Row 61173 done
# Row 61170 done
# Row 61171 done
# Row 61178 done
# Row 61174 done
# Row 61172 done
# Row 61179 done
# Row 61177 done
# Row 61180 done
# Row 61181 done
# Row 61182 done
# Row 61184 done
# Row 61185 done
# Row 61188 done
# Row 61191 done
# Row 61190 done
# Row 61189 done
# Row 61183 done
# Row 61187 done
# Row 61193 done
# Row 61192 done
# Row 61186 done
# Row 61194 done
# Row 61195 done
# Row 61196 done
# Row 61199 done
# Row 61197 done
# Row 61198 done
# Row 61200 done
# Row 61206 done
# Row 61201 done
# Row 61202 done
# Row 61204 done
# Row 61203 done
# Row 61205 done
# Row 61208 done
# Row 61207 done
# Row 61209 done
# Row 61211 done
# Row 61210 done
# Row 61213 done
# Row 61212 done
# Row 61214 done
# Row 61221 done
# Row 61218 done
# Row 61217 done
# Row 61220 done
# Row 61219 done
# Row 61216 done
# Row 61215 done
# Row 61222 done
# Row 61223 done
# Row 61224 done
# Row 61225 done
# Row 61226 done
# Row 61227 done
# Row 61231 done
# Row 61229 done
# Row 61228 done
# Row 61232 done
# Row 61233 done
# Row 61230 done
# Row 61235 done
# Row 61234 done
# Row 61237 done
# Row 61236 done
# Row 61238 done
# Row 61243 done
# Row 61241 done
# Row 61246 done
# Row 61245 done
# Row 61240 done
# Row 61249 done
# Row 61248 done
# Row 61239 done
# Row 61250 done
# Row 61247 done
# Row 61244 done
# Row 61242 done
# Row 61251 done
# Row 61252 done
# Row 61257 done
# Row 61259 done
# Row 61255 done
# Row 61253 done
# Row 61254 done
# Row 61258 done
# Row 61265 done
# Row 61260 done
# Row 61262 done
# Row 61256 done
# Row 61263 done
# Row 61264 done
# Row 61266 done
# Row 61268 done
# Row 61261 done
# Row 61269 done
# Row 61272 done
# Row 61276 done
# Row 61275 done
# Row 61274 done
# Row 61273 done
# Row 61271 done
# Row 61277 done
# Row 61267 done
# Row 61278 done
# Row 61279 done
# Row 61270 done
# Row 61280 done
# Row 61281 done
# Row 61285 done
# Row 61282 done
# Row 61283 done
# Row 61286 done
# Row 61284 done
# Row 61288 done
# Row 61290 done
# Row 61291 done
# Row 61287 done
# Row 61292 done
# Row 61289 done
# Row 61293 done
# Row 61298 done
# Row 61295 done
# Row 61294 done
# Row 61297 done
# Row 61296 done
# Row 61299 done
# Row 61302 done
# Row 61303 done
# Row 61304 done
# Row 61300 done
# Row 61301 done
# Row 61305 done
# Row 61306 done
# Row 61307 done
# Row 61308 done
# Row 61309 done
# Row 61310 done
# Row 61311 done
# Row 61312 done
# Row 61313 done
# Row 61316 done
# Row 61319 done
# Row 61318 done
# Row 61317 done
# Row 61314 done
# Row 61315 done
# Row 61324 done
# Row 61322 done
# Row 61325 done
# Row 61320 done
# Row 61326 done
# Row 61327 done
# Row 61330 done
# Row 61321 done
# Row 61328 done
# Row 61329 done
# Row 61323 done
# Row 61331 done
# Row 61333 done
# Row 61334 done
# Row 61332 done
# Row 61342 done
# Row 61337 done
# Row 61338 done
# Row 61340 done
# Row 61335 done
# Row 61339 done
# Row 61336 done
# Row 61341 done
# Row 61345 done
# Row 61346 done
# Row 61343 done
# Row 61344 done
# Row 61347 done
# Row 61352 done
# Row 61353 done
# Row 61356 done
# Row 61354 done
# Row 61357 done
# Row 61348 done
# Row 61358 done
# Row 61355 done
# Row 61351 done
# Row 61359 done
# Row 61349 done
# Row 61350 done
# Row 61360 done
# Row 61361 done
# Row 61362 done
# Row 61367 done
# Row 61368 done
# Row 61371 done
# Row 61365 done
# Row 61372 done
# Row 61364 done
# Row 61366 done
# Row 61370 done
# Row 61369 done
# Row 61363 done
# Row 61373 done
# Row 61374 done
# Row 61375 done
# Row 61376 done
# Row 61377 done
# Row 61379 done
# Row 61383 done
# Row 61385 done
# Row 61378 done
# Row 61384 done
# Row 61386 done
# Row 61381 done
# Row 61380 done
# Row 61382 done
# Row 61387 done
# Row 61388 done
# Row 61389 done
# Row 61390 done
# Row 61392 done
# Row 61393 done
# Row 61391 done
# Row 61400 done
# Row 61396 done
# Row 61394 done
# Row 61395 done
# Row 61398 done
# Row 61401 done
# Row 61397 done
# Row 61399 done
# Row 61403 done
# Row 61402 done
# Row 61405 done
# Row 61404 done
# Row 61406 done
# Row 61407 done
# Row 61409 done
# Row 61410 done
# Row 61413 done
# Row 61408 done
# Row 61411 done
# Row 61412 done
# Row 61414 done
# Row 61415 done
# Row 61417 done
# Row 61416 done
# Row 61419 done
# Row 61424 done
# Row 61422 done
# Row 61421 done
# Row 61423 done
# Row 61426 done
# Row 61425 done
# Row 61428 done
# Row 61427 done
# Row 61418 done
# Row 61429 done
# Row 61430 done
# Row 61420 done
# Row 61431 done
# Row 61432 done
# Row 61433 done
# Row 61434 done
# Row 61438 done
# Row 61437 done
# Row 61440 done
# Row 61435 done
# Row 61436 done
# Row 61439 done
# Row 61441 done
# Row 61442 done
# Row 61443 done
# Row 61445 done
# Row 61444 done
# Row 61446 done
# Row 61447 done
# Row 61450 done
# Row 61448 done
# Row 61454 done
# Row 61449 done
# Row 61453 done
# Row 61452 done
# Row 61456 done
# Row 61451 done
# Row 61458 done
# Row 61455 done
# Row 61459 done
# Row 61457 done
# Row 61462 done
# Row 61466 done
# Row 61468 done
# Row 61469 done
# Row 61460 done
# Row 61461 done
# Row 61472 done
# Row 61464 done
# Row 61465 done
# Row 61463 done
# Row 61467 done
# Row 61471 done
# Row 61470 done
# Row 61474 done
# Row 61473 done
# Row 61477 done
# Row 61478 done
# Row 61475 done
# Row 61479 done
# Row 61481 done
# Row 61480 done
# Row 61482 done
# Row 61476 done
# Row 61483 done
# Row 61484 done
# Row 61485 done
# Row 61486 done
# Row 61488 done
# Row 61487 done
# Row 61489 done
# Row 61495 done
# Row 61490 done
# Row 61492 done
# Row 61493 done
# Row 61491 done
# Row 61494 done
# Row 61496 done
# Row 61497 done
# Row 61498 done
# Row 61500 done
# Row 61501 done
# Row 61499 done
# Row 61506 done
# Row 61503 done
# Row 61507 done
# Row 61508 done
# Row 61502 done
# Row 61504 done
# Row 61505 done
# Row 61511 done
# Row 61513 done
# Row 61510 done
# Row 61509 done
# Row 61512 done
# Row 61514 done
# Row 61517 done
# Row 61515 done
# Row 61520 done
# Row 61523 done
# Row 61522 done
# Row 61516 done
# Row 61518 done
# Row 61521 done
# Row 61519 done
# Row 61524 done
# Row 61525 done
# Row 61527 done
# Row 61526 done
# Row 61528 done
# Row 61529 done
# Row 61530 done
# Row 61532 done
# Row 61533 done
# Row 61531 done
# Row 61535 done
# Row 61534 done
# Row 61539 done
# Row 61536 done
# Row 61538 done
# Row 61537 done
# Row 61540 done
# Row 61541 done
# Row 61542 done
# Row 61543 done
# Row 61545 done
# Row 61546 done
# Row 61544 done
# Row 61549 done
# Row 61548 done
# Row 61552 done
# Row 61547 done
# Row 61550 done
# Row 61551 done
# Row 61553 done
# Row 61554 done
# Row 61555 done
# Row 61556 done
# Row 61557 done
# Row 61558 done
# Row 61560 done
# Row 61559 done
# Row 61562 done
# Row 61561 done
# Row 61563 done
# Row 61566 done
# Row 61564 done
# Row 61565 done
# Row 61567 done
# Row 61568 done
# Row 61570 done
# Row 61569 done
# Row 61571 done
# Row 61572 done
# Row 61576 done
# Row 61573 done
# Row 61574 done
# Row 61577 done
# Row 61578 done
# Row 61575 done
# Row 61579 done
# Row 61581 done
# Row 61580 done
# Row 61582 done
# Row 61583 done
# Row 61584 done
# Row 61587 done
# Row 61586 done
# Row 61588 done
# Row 61585 done
# Row 61590 done
# Row 61589 done
# Row 61591 done
# Row 61593 done
# Row 61592 done
# Row 61594 done
# Row 61596 done
# Row 61595 done
# Row 61597 done
# Row 61598 done
# Row 61599 done
# Row 61601 done
# Row 61600 done
# Row 61603 done
# Row 61602 done
# Row 61606 done
# Row 61604 done
# Row 61605 done
# Row 61607 done
# Row 61608 done
# Row 61609 done
# Row 61610 done
# Row 61613 done
# Row 61617 done
# Row 61620 done
# Row 61619 done
# Row 61621 done
# Row 61612 done
# Row 61611 done
# Row 61614 done
# Row 61615 done
# Row 61618 done
# Row 61624 done
# Row 61626 done
# Row 61616 done
# Row 61622 done
# Row 61625 done
# Row 61630 done
# Row 61623 done
# Row 61627 done
# Row 61632 done
# Row 61631 done
# Row 61629 done
# Row 61633 done
# Row 61636 done
# Row 61635 done
# Row 61634 done
# Row 61628 done
# Row 61638 done
# Row 61640 done
# Row 61639 done
# Row 61643 done
# Row 61641 done
# Row 61646 done
# Row 61642 done
# Row 61637 done
# Row 61645 done
# Row 61644 done
# Row 61647 done
# Row 61648 done
# Row 61649 done
# Row 61654 done
# Row 61656 done
# Row 61657 done
# Row 61659 done
# Row 61655 done
# Row 61653 done
# Row 61652 done
# Row 61650 done
# Row 61651 done
# Row 61658 done
# Row 61660 done
# Row 61661 done
# Row 61662 done
# Row 61665 done
# Row 61664 done
# Row 61663 done
# Row 61668 done
# Row 61670 done
# Row 61667 done
# Row 61669 done
# Row 61672 done
# Row 61671 done
# Row 61666 done
# Row 61673 done
# Row 61674 done
# Row 61675 done
# Row 61677 done
# Row 61680 done
# Row 61681 done
# Row 61678 done
# Row 61685 done
# Row 61684 done
# Row 61686 done
# Row 61679 done
# Row 61682 done
# Row 61676 done
# Row 61683 done
# Row 61687 done
# Row 61688 done
# Row 61689 done
# Row 61692 done
# Row 61691 done
# Row 61696 done
# Row 61694 done
# Row 61695 done
# Row 61690 done
# Row 61698 done
# Row 61697 done
# Row 61699 done
# Row 61700 done
# Row 61693 done
# Row 61701 done
# Row 61702 done
# Row 61703 done
# Row 61704 done
# Row 61706 done
# Row 61705 done
# Row 61708 done
# Row 61707 done
# Row 61710 done
# Row 61709 done
# Row 61711 done
# Row 61712 done
# Row 61714 done
# Row 61715 done
# Row 61716 done
# Row 61713 done
# Row 61717 done
# Row 61719 done
# Row 61721 done
# Row 61722 done
# Row 61724 done
# Row 61723 done
# Row 61725 done
# Row 61720 done
# Row 61718 done
# Row 61726 done
# Row 61728 done
# Row 61727 done
# Row 61729 done
# Row 61730 done
# Row 61732 done
# Row 61731 done
# Row 61734 done
# Row 61733 done
# Row 61737 done
# Row 61735 done
# Row 61736 done
# Row 61738 done
# Row 61739 done
# Row 61741 done
# Row 61740 done
# Row 61742 done
# Row 61744 done
# Row 61745 done
# Row 61743 done
# Row 61747 done
# Row 61749 done
# Row 61750 done
# Row 61748 done
# Row 61751 done
# Row 61746 done
# Row 61753 done
# Row 61752 done
# Row 61754 done
# Row 61756 done
# Row 61755 done
# Row 61757 done
# Row 61758 done
# Row 61759 done
# Row 61761 done
# Row 61764 done
# Row 61762 done
# Row 61765 done
# Row 61760 done
# Row 61763 done
# Row 61769 done
# Row 61766 done
# Row 61767 done
# Row 61770 done
# Row 61768 done
# Row 61771 done
# Row 61773 done
# Row 61775 done
# Row 61776 done
# Row 61772 done
# Row 61777 done
# Row 61774 done
# Row 61780 done
# Row 61779 done
# Row 61778 done
# Row 61781 done
# Row 61783 done
# Row 61782 done
# Row 61784 done
# Row 61785 done
# Row 61787 done
# Row 61786 done
# Row 61790 done
# Row 61788 done
# Row 61789 done
# Row 61794 done
# Row 61791 done
# Row 61792 done
# Row 61793 done
# Row 61795 done
# Row 61796 done
# Row 61797 done
# Row 61799 done
# Row 61798 done
# Row 61802 done
# Row 61800 done
# Row 61801 done
# Row 61803 done
# Row 61805 done
# Row 61804 done
# Row 61807 done
# Row 61808 done
# Row 61806 done
# Row 61809 done
# Row 61810 done
# Row 61811 done
# Row 61812 done
# Row 61813 done
# Row 61814 done
# Row 61815 done
# Row 61817 done
# Row 61818 done
# Row 61821 done
# Row 61820 done
# Row 61819 done
# Row 61822 done
# Row 61823 done
# Row 61816 done
# Row 61824 done
# Row 61825 done
# Row 61828 done
# Row 61826 done
# Row 61827 done
# Row 61829 done
# Row 61833 done
# Row 61832 done
# Row 61830 done
# Row 61831 done
# Row 61836 done
# Row 61834 done
# Row 61835 done
# Row 61837 done
# Row 61838 done
# Row 61840 done
# Row 61839 done
# Row 61841 done
# Row 61842 done
# Row 61843 done
# Row 61847 done
# Row 61844 done
# Row 61848 done
# Row 61849 done
# Row 61845 done
# Row 61846 done
# Row 61850 done
# Row 61851 done
# Row 61852 done
# Row 61854 done
# Row 61853 done
# Row 61857 done
# Row 61855 done
# Row 61856 done
# Row 61858 done
# Row 61860 done
# Row 61861 done
# Row 61862 done
# Row 61859 done
# Row 61863 done
# Row 61866 done
# Row 61864 done
# Row 61865 done
# Row 61869 done
# Row 61872 done
# Row 61875 done
# Row 61873 done
# Row 61868 done
# Row 61870 done
# Row 61874 done
# Row 61867 done
# Row 61871 done
# Row 61876 done
# Row 61878 done
# Row 61877 done
# Row 61882 done
# Row 61879 done
# Row 61881 done
# Row 61880 done
# Row 61887 done
# Row 61884 done
# Row 61888 done
# Row 61885 done
# Row 61886 done
# Row 61883 done
# Row 61889 done
# Row 61890 done
# Row 61891 done
# Row 61892 done
# Row 61893 done
# Row 61896 done
# Row 61894 done
# Row 61901 done
# Row 61897 done
# Row 61900 done
# Row 61895 done
# Row 61899 done
# Row 61898 done
# Row 61902 done
# Row 61903 done
# Row 61904 done
# Row 61905 done
# Row 61906 done
# Row 61909 done
# Row 61911 done
# Row 61907 done
# Row 61912 done
# Row 61913 done
# Row 61910 done
# Row 61908 done
# Row 61916 done
# Row 61917 done
# Row 61915 done
# Row 61914 done
# Row 61918 done
# Row 61919 done
# Row 61920 done
# Row 61921 done
# Row 61924 done
# Row 61927 done
# Row 61925 done
# Row 61926 done
# Row 61930 done
# Row 61928 done
# Row 61931 done
# Row 61922 done
# Row 61923 done
# Row 61932 done
# Row 61929 done
# Row 61933 done
# Row 61934 done
# Row 61935 done
# Row 61938 done
# Row 61943 done
# Row 61939 done
# Row 61942 done
# Row 61941 done
# Row 61940 done
# Row 61944 done
# Row 61937 done
# Row 61945 done
# Row 61946 done
# Row 61936 done
# Row 61947 done
# Row 61948 done
# Row 61949 done
# Row 61951 done
# Row 61950 done
# Row 61953 done
# Row 61954 done
# Row 61952 done
# Row 61955 done
# Row 61956 done
# Row 61958 done
# Row 61957 done
# Row 61959 done
# Row 61960 done
# Row 61961 done
# Row 61962 done
# Row 61963 done
# Row 61964 done
# Row 61969 done
# Row 61967 done
# Row 61966 done
# Row 61972 done
# Row 61968 done
# Row 61965 done
# Row 61974 done
# Row 61971 done
# Row 61970 done
# Row 61973 done
# Row 61975 done
# Row 61976 done
# Row 61977 done
# Row 61978 done
# Row 61983 done
# Row 61979 done
# Row 61980 done
# Row 61981 done
# Row 61987 done
# Row 61985 done
# Row 61982 done
# Row 61984 done
# Row 61986 done
# Row 61988 done
# Row 61989 done
# Row 61990 done
# Row 61991 done
# Row 61992 done
# Row 61994 done
# Row 61993 done
# Row 61995 done
# Row 61996 done
# Row 61998 done
# Row 61999 done
# Row 61997 done
# Row 62000 done
# Row 62001 done
# Row 62002 done
# Row 62004 done
# Row 62003 done
# Row 62007 done
# Row 62005 done
# Row 62008 done
# Row 62006 done
# Row 62009 done
# Row 62015 done
# Row 62011 done
# Row 62016 done
# Row 62010 done
# Row 62014 done
# Row 62013 done
# Row 62017 done
# Row 62012 done
# Row 62019 done
# Row 62018 done
# Row 62021 done
# Row 62020 done
# Row 62022 done
# Row 62024 done
# Row 62028 done
# Row 62026 done
# Row 62027 done
# Row 62025 done
# Row 62029 done
# Row 62030 done
# Row 62031 done
# Row 62023 done
# Row 62033 done
# Row 62035 done
# Row 62032 done
# Row 62034 done
# Row 62039 done
# Row 62036 done
# Row 62042 done
# Row 62038 done
# Row 62037 done
# Row 62041 done
# Row 62040 done
# Row 62044 done
# Row 62045 done
# Row 62047 done
# Row 62046 done
# Row 62043 done
# Row 62048 done
# Row 62049 done
# Row 62052 done
# Row 62050 done
# Row 62053 done
# Row 62051 done
# Row 62054 done
# Row 62055 done
# Row 62058 done
# Row 62057 done
# Row 62059 done
# Row 62056 done
# Row 62060 done
# Row 62061 done
# Row 62062 done
# Row 62065 done
# Row 62067 done
# Row 62066 done
# Row 62071 done
# Row 62064 done
# Row 62063 done
# Row 62068 done
# Row 62069 done
# Row 62070 done
# Row 62072 done
# Row 62073 done
# Row 62074 done
# Row 62075 done
# Row 62076 done
# Row 62077 done
# Row 62078 done
# Row 62079 done
# Row 62080 done
# Row 62082 done
# Row 62084 done
# Row 62085 done
# Row 62083 done
# Row 62086 done
# Row 62081 done
# Row 62087 done
# Row 62088 done
# Row 62090 done
# Row 62092 done
# Row 62093 done
# Row 62091 done
# Row 62094 done
# Row 62089 done
# Row 62096 done
# Row 62095 done
# Row 62098 done
# Row 62097 done
# Row 62099 done
# Row 62100 done
# Row 62101 done
# Row 62102 done
# Row 62104 done
# Row 62103 done
# Row 62106 done
# Row 62105 done
# Row 62109 done
# Row 62110 done
# Row 62108 done
# Row 62111 done
# Row 62107 done
# Row 62113 done
# Row 62112 done
# Row 62114 done
# Row 62115 done
# Row 62116 done
# Row 62118 done
# Row 62117 done
# Row 62119 done
# Row 62122 done
# Row 62121 done
# Row 62123 done
# Row 62124 done
# Row 62120 done
# Row 62126 done
# Row 62127 done
# Row 62125 done
# Row 62128 done
# Row 62129 done
# Row 62130 done
# Row 62131 done
# Row 62132 done
# Row 62133 done
# Row 62136 done
# Row 62138 done
# Row 62139 done
# Row 62137 done
# Row 62135 done
# Row 62140 done
# Row 62134 done
# Row 62142 done
# Row 62141 done
# Row 62143 done
# Row 62144 done
# Row 62145 done
# Row 62146 done
# Row 62147 done
# Row 62148 done
# Row 62154 done
# Row 62150 done
# Row 62149 done
# Row 62153 done
# Row 62152 done
# Row 62151 done
# Row 62155 done
# Row 62156 done
# Row 62157 done
# Row 62158 done
# Row 62159 done
# Row 62166 done
# Row 62161 done
# Row 62160 done
# Row 62163 done
# Row 62162 done
# Row 62169 done
# Row 62164 done
# Row 62167 done
# Row 62168 done
# Row 62165 done
# Row 62170 done
# Row 62171 done
# Row 62172 done
# Row 62173 done
# Row 62174 done
# Row 62176 done
# Row 62175 done
# Row 62177 done
# Row 62179 done
# Row 62180 done
# Row 62182 done
# Row 62178 done
# Row 62181 done
# Row 62183 done
# Row 62184 done
# Row 62185 done
# Row 62186 done
# Row 62187 done
# Row 62196 done
# Row 62192 done
# Row 62194 done
# Row 62189 done
# Row 62188 done
# Row 62193 done
# Row 62195 done
# Row 62191 done
# Row 62197 done
# Row 62199 done
# Row 62190 done
# Row 62198 done
# Row 62207 done
# Row 62206 done
# Row 62204 done
# Row 62208 done
# Row 62205 done
# Row 62200 done
# Row 62203 done
# Row 62201 done
# Row 62202 done
# Row 62209 done
# Row 62211 done
# Row 62210 done
# Row 62212 done
# Row 62213 done
# Row 62215 done
# Row 62219 done
# Row 62217 done
# Row 62218 done
# Row 62223 done
# Row 62214 done
# Row 62216 done
# Row 62220 done
# Row 62222 done
# Row 62221 done
# Row 62225 done
# Row 62226 done
# Row 62224 done
# Row 62229 done
# Row 62227 done
# Row 62228 done
# Row 62230 done
# Row 62231 done
# Row 62234 done
# Row 62233 done
# Row 62235 done
# Row 62232 done
# Row 62237 done
# Row 62236 done
# Row 62238 done
# Row 62239 done
# Row 62240 done
# Row 62241 done
# Row 62242 done
# Row 62243 done
# Row 62244 done
# Row 62245 done
# Row 62249 done
# Row 62251 done
# Row 62248 done
# Row 62250 done
# Row 62252 done
# Row 62253 done
# Row 62246 done
# Row 62247 done
# Row 62254 done
# Row 62255 done
# Row 62256 done
# Row 62258 done
# Row 62257 done
# Row 62259 done
# Row 62260 done
# Row 62262 done
# Row 62261 done
# Row 62265 done
# Row 62264 done
# Row 62267 done
# Row 62263 done
# Row 62266 done
# Row 62268 done
# Row 62269 done
# Row 62271 done
# Row 62272 done
# Row 62270 done
# Row 62273 done
# Row 62275 done
# Row 62277 done
# Row 62274 done
# Row 62279 done
# Row 62278 done
# Row 62276 done
# Row 62280 done
# Row 62281 done
# Row 62283 done
# Row 62282 done
# Row 62285 done
# Row 62284 done
# Row 62286 done
# Row 62287 done
# Row 62289 done
# Row 62291 done
# Row 62293 done
# Row 62290 done
# Row 62288 done
# Row 62292 done
# Row 62294 done
# Row 62295 done
# Row 62296 done
# Row 62297 done
# Row 62298 done
# Row 62299 done
# Row 62301 done
# Row 62305 done
# Row 62303 done
# Row 62300 done
# Row 62304 done
# Row 62306 done
# Row 62302 done
# Row 62308 done
# Row 62307 done
# Row 62310 done
# Row 62309 done
# Row 62312 done
# Row 62311 done
# Row 62313 done
# Row 62314 done
# Row 62316 done
# Row 62318 done
# Row 62317 done
# Row 62315 done
# Row 62321 done
# Row 62319 done
# Row 62320 done
# Row 62322 done
# Row 62323 done
# Row 62324 done
# Row 62326 done
# Row 62325 done
# Row 62327 done
# Row 62328 done
# Row 62330 done
# Row 62331 done
# Row 62329 done
# Row 62332 done
# Row 62333 done
# Row 62334 done
# Row 62335 done
# Row 62340 done
# Row 62336 done
# Row 62338 done
# Row 62339 done
# Row 62337 done
# Row 62341 done
# Row 62343 done
# Row 62342 done
# Row 62344 done
# Row 62345 done
# Row 62348 done
# Row 62346 done
# Row 62349 done
# Row 62351 done
# Row 62347 done
# Row 62352 done
# Row 62350 done
# Row 62354 done
# Row 62356 done
# Row 62355 done
# Row 62353 done
# Row 62357 done
# Row 62358 done
# Row 62359 done
# Row 62360 done
# Row 62361 done
# Row 62362 done
# Row 62363 done
# Row 62364 done
# Row 62365 done
# Row 62368 done
# Row 62367 done
# Row 62369 done
# Row 62366 done
# Row 62376 done
# Row 62373 done
# Row 62375 done
# Row 62372 done
# Row 62370 done
# Row 62371 done
# Row 62374 done
# Row 62377 done
# Row 62378 done
# Row 62379 done
# Row 62381 done
# Row 62380 done
# Row 62384 done
# Row 62388 done
# Row 62382 done
# Row 62385 done
# Row 62383 done
# Row 62387 done
# Row 62390 done
# Row 62391 done
# Row 62393 done
# Row 62392 done
# Row 62389 done
# Row 62386 done
# Row 62398 done
# Row 62395 done
# Row 62394 done
# Row 62396 done
# Row 62397 done
# Row 62399 done
# Row 62400 done
# Row 62401 done
# Row 62402 done
# Row 62403 done
# Row 62404 done
# Row 62405 done
# Row 62406 done
# Row 62407 done
# Row 62409 done
# Row 62408 done
# Row 62412 done
# Row 62410 done
# Row 62413 done
# Row 62411 done
# Row 62414 done
# Row 62415 done
# Row 62417 done
# Row 62416 done
# Row 62418 done
# Row 62419 done
# Row 62420 done
# Row 62422 done
# Row 62421 done
# Row 62423 done
# Row 62424 done
# Row 62425 done
# Row 62426 done
# Row 62427 done
# Row 62430 done
# Row 62428 done
# Row 62429 done
# Row 62432 done
# Row 62431 done
# Row 62434 done
# Row 62433 done
# Row 62436 done
# Row 62435 done
# Row 62438 done
# Row 62437 done
# Row 62439 done
# Row 62441 done
# Row 62440 done
# Row 62442 done
# Row 62443 done
# Row 62444 done
# Row 62445 done
# Row 62449 done
# Row 62447 done
# Row 62448 done
# Row 62446 done
# Row 62450 done
# Row 62451 done
# Row 62452 done
# Row 62455 done
# Row 62454 done
# Row 62453 done
# Row 62456 done
# Row 62457 done
# Row 62460 done
# Row 62461 done
# Row 62459 done
# Row 62458 done
# Row 62463 done
# Row 62462 done
# Row 62464 done
# Row 62465 done
# Row 62467 done
# Row 62469 done
# Row 62466 done
# Row 62468 done
# Row 62471 done
# Row 62472 done
# Row 62470 done
# Row 62473 done
# Row 62476 done
# Row 62475 done
# Row 62474 done
# Row 62478 done
# Row 62477 done
# Row 62480 done
# Row 62479 done
# Row 62481 done
# Row 62482 done
# Row 62483 done
# Row 62484 done
# Row 62485 done
# Row 62486 done
# Row 62489 done
# Row 62487 done
# Row 62491 done
# Row 62490 done
# Row 62492 done
# Row 62494 done
# Row 62497 done
# Row 62495 done
# Row 62496 done
# Row 62493 done
# Row 62498 done
# Row 62499 done
# Row 62500 done
# Row 62503 done
# Row 62502 done
# Row 62488 done
# Row 62506 done
# Row 62504 done
# Row 62508 done
# Row 62507 done
# Row 62505 done
# Row 62509 done
# Row 62510 done
# Row 62512 done
# Row 62513 done
# Row 62514 done
# Row 62501 done
# Row 62511 done
# Row 62515 done
# Row 62516 done
# Row 62517 done
# Row 62520 done
# Row 62519 done
# Row 62518 done
# Row 62521 done
# Row 62522 done
# Row 62524 done
# Row 62523 done
# Row 62525 done
# Row 62526 done
# Row 62527 done
# Row 62529 done
# Row 62528 done
# Row 62531 done
# Row 62533 done
# Row 62532 done
# Row 62535 done
# Row 62534 done
# Row 62530 done
# Row 62536 done
# Row 62537 done
# Row 62541 done
# Row 62539 done
# Row 62538 done
# Row 62540 done
# Row 62544 done
# Row 62542 done
# Row 62543 done
# Row 62545 done
# Row 62546 done
# Row 62547 done
# Row 62548 done
# Row 62549 done
# Row 62550 done
# Row 62551 done
# Row 62552 done
# Row 62556 done
# Row 62555 done
# Row 62558 done
# Row 62557 done
# Row 62554 done
# Row 62559 done
# Row 62560 done
# Row 62561 done
# Row 62562 done
# Row 62564 done
# Row 62568 done
# Row 62566 done
# Row 62570 done
# Row 62572 done
# Row 62569 done
# Row 62553 done
# Row 62573 done
# Row 62574 done
# Row 62571 done
# Row 62567 done
# Row 62563 done
# Row 62565 done
# Row 62576 done
# Row 62575 done
# Row 62577 done
# Row 62578 done
# Row 62580 done
# Row 62581 done
# Row 62584 done
# Row 62582 done
# Row 62585 done
# Row 62586 done
# Row 62590 done
# Row 62583 done
# Row 62579 done
# Row 62587 done
# Row 62589 done
# Row 62596 done
# Row 62595 done
# Row 62591 done
# Row 62592 done
# Row 62593 done
# Row 62594 done
# Row 62597 done
# Row 62599 done
# Row 62600 done
# Row 62601 done
# Row 62603 done
# Row 62605 done
# Row 62602 done
# Row 62606 done
# Row 62607 done
# Row 62608 done
# Row 62609 done
# Row 62611 done
# Row 62610 done
# Row 62612 done
# Row 62604 done
# Row 62613 done
# Row 62616 done
# Row 62588 done
# Row 62614 done
# Row 62617 done
# Row 62619 done
# Row 62598 done
# Row 62618 done
# Row 62620 done
# Row 62621 done
# Row 62622 done
# Row 62615 done
# Row 62623 done
# Row 62625 done
# Row 62627 done
# Row 62626 done
# Row 62624 done
# Row 62628 done
# Row 62630 done
# Row 62632 done
# Row 62629 done
# Row 62633 done
# Row 62635 done
# Row 62631 done
# Row 62634 done
# Row 62636 done
# Row 62637 done
# Row 62638 done
# Row 62639 done
# Row 62640 done
# Row 62643 done
# Row 62642 done
# Row 62641 done
# Row 62645 done
# Row 62646 done
# Row 62648 done
# Row 62647 done
# Row 62649 done
# Row 62652 done
# Row 62644 done
# Row 62650 done
# Row 62654 done
# Row 62651 done
# Row 62653 done
# Row 62656 done
# Row 62657 done
# Row 62655 done
# Row 62658 done
# Row 62659 done
# Row 62660 done
# Row 62661 done
# Row 62662 done
# Row 62663 done
# Row 62665 done
# Row 62666 done
# Row 62668 done
# Row 62664 done
# Row 62667 done
# Row 62670 done
# Row 62671 done
# Row 62672 done
# Row 62669 done
# Row 62674 done
# Row 62673 done
# Row 62677 done
# Row 62676 done
# Row 62679 done
# Row 62678 done
# Row 62675 done
# Row 62682 done
# Row 62681 done
# Row 62684 done
# Row 62685 done
# Row 62683 done
# Row 62680 done
# Row 62686 done
# Row 62687 done
# Row 62688 done
# Row 62690 done
# Row 62689 done
# Row 62691 done
# Row 62693 done
# Row 62694 done
# Row 62696 done
# Row 62698 done
# Row 62695 done
# Row 62697 done
# Row 62699 done
# Row 62692 done
# Row 62700 done
# Row 62701 done
# Row 62702 done
# Row 62703 done
# Row 62704 done
# Row 62706 done
# Row 62705 done
# Row 62707 done
# Row 62710 done
# Row 62711 done
# Row 62708 done
# Row 62714 done
# Row 62709 done
# Row 62713 done
# Row 62712 done
# Row 62716 done
# Row 62715 done
# Row 62717 done
# Row 62718 done
# Row 62719 done
# Row 62721 done
# Row 62720 done
# Row 62723 done
# Row 62725 done
# Row 62724 done
# Row 62722 done
# Row 62726 done
# Row 62727 done
# Row 62728 done
# Row 62729 done
# Row 62730 done
# Row 62731 done
# Row 62734 done
# Row 62732 done
# Row 62733 done
# Row 62735 done
# Row 62736 done
# Row 62737 done
# Row 62740 done
# Row 62739 done
# Row 62741 done
# Row 62738 done
# Row 62742 done
# Row 62743 done
# Row 62744 done
# Row 62747 done
# Row 62748 done
# Row 62746 done
# Row 62749 done
# Row 62752 done
# Row 62751 done
# Row 62753 done
# Row 62750 done
# Row 62754 done
# Row 62745 done
# Row 62755 done
# Row 62756 done
# Row 62758 done
# Row 62759 done
# Row 62761 done
# Row 62762 done
# Row 62757 done
# Row 62760 done
# Row 62766 done
# Row 62767 done
# Row 62768 done
# Row 62764 done
# Row 62763 done
# Row 62765 done
# Row 62769 done
# Row 62770 done
# Row 62771 done
# Row 62774 done
# Row 62772 done
# Row 62776 done
# Row 62777 done
# Row 62775 done
# Row 62773 done
# Row 62781 done
# Row 62778 done
# Row 62779 done
# Row 62780 done
# Row 62782 done
# Row 62783 done
# Row 62784 done
# Row 62786 done
# Row 62788 done
# Row 62787 done
# Row 62790 done
# Row 62791 done
# Row 62789 done
# Row 62785 done
# Row 62793 done
# Row 62792 done
# Row 62795 done
# Row 62796 done
# Row 62794 done
# Row 62797 done
# Row 62798 done
# Row 62799 done
# Row 62800 done
# Row 62802 done
# Row 62803 done
# Row 62801 done
# Row 62807 done
# Row 62809 done
# Row 62808 done
# Row 62804 done
# Row 62806 done
# Row 62805 done
# Row 62811 done
# Row 62810 done
# Row 62812 done
# Row 62813 done
# Row 62814 done
# Row 62816 done
# Row 62815 done
# Row 62817 done
# Row 62818 done
# Row 62822 done
# Row 62823 done
# Row 62819 done
# Row 62820 done
# Row 62821 done
# Row 62824 done
# Row 62825 done
# Row 62826 done
# Row 62827 done
# Row 62828 done
# Row 62829 done
# Row 62830 done
# Row 62837 done
# Row 62834 done
# Row 62833 done
# Row 62832 done
# Row 62831 done
# Row 62838 done
# Row 62835 done
# Row 62836 done
# Row 62840 done
# Row 62839 done
# Row 62843 done
# Row 62841 done
# Row 62842 done
# Row 62846 done
# Row 62850 done
# Row 62847 done
# Row 62844 done
# Row 62848 done
# Row 62845 done
# Row 62849 done
# Row 62851 done
# Row 62853 done
# Row 62852 done
# Row 62855 done
# Row 62854 done
# Row 62856 done
# Row 62857 done
# Row 62858 done
# Row 62859 done
# Row 62864 done
# Row 62861 done
# Row 62862 done
# Row 62860 done
# Row 62863 done
# Row 62867 done
# Row 62866 done
# Row 62865 done
# Row 62868 done
# Row 62869 done
# Row 62870 done
# Row 62871 done
# Row 62872 done
# Row 62873 done
# Row 62876 done
# Row 62875 done
# Row 62877 done
# Row 62879 done
# Row 62878 done
# Row 62874 done
# Row 62884 done
# Row 62880 done
# Row 62882 done
# Row 62881 done
# Row 62885 done
# Row 62883 done
# Row 62886 done
# Row 62890 done
# Row 62887 done
# Row 62891 done
# Row 62889 done
# Row 62888 done
# Row 62892 done
# Row 62893 done
# Row 62894 done
# Row 62895 done
# Row 62897 done
# Row 62896 done
# Row 62899 done
# Row 62898 done
# Row 62900 done
# Row 62904 done
# Row 62905 done
# Row 62909 done
# Row 62906 done
# Row 62907 done
# Row 62911 done
# Row 62914 done
# Row 62902 done
# Row 62917 done
# Row 62916 done
# Row 62918 done
# Row 62919 done
# Row 62920 done
# Row 62921 done
# Row 62903 done
# Row 62922 done
# Row 62901 done
# Row 62924 done
# Row 62912 done
# Row 62923 done
# Row 62930 done
# Row 62929 done
# Row 62908 done
# Row 62910 done
# Row 62932 done
# Row 62931 done
# Row 62913 done
# Row 62928 done
# Row 62925 done
# Row 62926 done
# Row 62915 done
# Row 62927 done
# Row 62935 done
# Row 62934 done
# Row 62933 done
# Row 62936 done
# Row 62938 done
# Row 62939 done
# Row 62943 done
# Row 62941 done
# Row 62942 done
# Row 62940 done
# Row 62937 done
# Row 62944 done
# Row 62947 done
# Row 62945 done
# Row 62946 done
# Row 62948 done
# Row 62949 done
# Row 62952 done
# Row 62950 done
# Row 62955 done
# Row 62956 done
# Row 62957 done
# Row 62959 done
# Row 62954 done
# Row 62953 done
# Row 62958 done
# Row 62951 done
# Row 62963 done
# Row 62961 done
# Row 62960 done
# Row 62962 done
# Row 62964 done
# Row 62966 done
# Row 62965 done
# Row 62968 done
# Row 62970 done
# Row 62967 done
# Row 62976 done
# Row 62977 done
# Row 62971 done
# Row 62969 done
# Row 62973 done
# Row 62972 done
# Row 62975 done
# Row 62974 done
# Row 62978 done
# Row 62979 done
# Row 62980 done
# Row 62984 done
# Row 62983 done
# Row 62988 done
# Row 62986 done
# Row 62985 done
# Row 62989 done
# Row 62990 done
# Row 62987 done
# Row 62982 done
# Row 62981 done
# Row 62991 done
# Row 62992 done
# Row 62993 done
# Row 62994 done
# Row 62995 done
# Row 63000 done
# Row 62996 done
# Row 63004 done
# Row 62998 done
# Row 63001 done
# Row 62997 done
# Row 63003 done
# Row 62999 done
# Row 63002 done
# Row 63005 done
# Row 63006 done
# Row 63007 done
# Row 63008 done
# Row 63009 done
# Row 63011 done
# Row 63010 done
# Row 63013 done
# Row 63012 done
# Row 63014 done
# Row 63015 done
# Row 63018 done
# Row 63017 done
# Row 63019 done
# Row 63016 done
# Row 63020 done
# Row 63022 done
# Row 63023 done
# Row 63021 done
# Row 63024 done
# Row 63026 done
# Row 63028 done
# Row 63025 done
# Row 63030 done
# Row 63029 done
# Row 63027 done
# Row 63032 done
# Row 63031 done
# Row 63033 done
# Row 63034 done
# Row 63035 done
# Row 63036 done
# Row 63038 done
# Row 63039 done
# Row 63037 done
# Row 63040 done
# Row 63042 done
# Row 63041 done
# Row 63045 done
# Row 63044 done
# Row 63046 done
# Row 63043 done
# Row 63047 done
# Row 63048 done
# Row 63049 done
# Row 63051 done
# Row 63052 done
# Row 63054 done
# Row 63055 done
# Row 63053 done
# Row 63050 done
# Row 63058 done
# Row 63060 done
# Row 63057 done
# Row 63056 done
# Row 63059 done
# Row 63061 done
# Row 63062 done
# Row 63063 done
# Row 63064 done
# Row 63065 done
# Row 63067 done
# Row 63066 done
# Row 63070 done
# Row 63069 done
# Row 63068 done
# Row 63071 done
# Row 63072 done
# Row 63073 done
# Row 63074 done
# Row 63075 done
# Row 63076 done
# Row 63077 done
# Row 63079 done
# Row 63078 done
# Row 63081 done
# Row 63082 done
# Row 63086 done
# Row 63080 done
# Row 63084 done
# Row 63088 done
# Row 63083 done
# Row 63087 done
# Row 63089 done
# Row 63090 done
# Row 63092 done
# Row 63085 done
# Row 63091 done
# Row 63096 done
# Row 63093 done
# Row 63097 done
# Row 63094 done
# Row 63095 done
# Row 63099 done
# Row 63100 done
# Row 63101 done
# Row 63098 done
# Row 63102 done
# Row 63103 done
# Row 63104 done
# Row 63105 done
# Row 63107 done
# Row 63106 done
# Row 63108 done
# Row 63109 done
# Row 63111 done
# Row 63110 done
# Row 63112 done
# Row 63114 done
# Row 63113 done
# Row 63115 done
# Row 63116 done
# Row 63118 done
# Row 63119 done
# Row 63121 done
# Row 63124 done
# Row 63128 done
# Row 63122 done
# Row 63117 done
# Row 63123 done
# Row 63125 done
# Row 63126 done
# Row 63120 done
# Row 63127 done
# Row 63129 done
# Row 63130 done
# Row 63137 done
# Row 63135 done
# Row 63134 done
# Row 63139 done
# Row 63133 done
# Row 63141 done
# Row 63143 done
# Row 63144 done
# Row 63145 done
# Row 63147 done
# Row 63146 done
# Row 63149 done
# Row 63150 done
# Row 63151 done
# Row 63153 done
# Row 63152 done
# Row 63155 done
# Row 63131 done
# Row 63132 done
# Row 63138 done
# Row 63136 done
# Row 63140 done
# Row 63142 done
# Row 63156 done
# Row 63154 done
# Row 63157 done
# Row 63148 done
# Row 63160 done
# Row 63164 done
# Row 63166 done
# Row 63159 done
# Row 63162 done
# Row 63158 done
# Row 63167 done
# Row 63165 done
# Row 63161 done
# Row 63163 done
# Row 63169 done
# Row 63168 done
# Row 63170 done
# Row 63171 done
# Row 63175 done
# Row 63179 done
# Row 63172 done
# Row 63181 done
# Row 63177 done
# Row 63176 done
# Row 63173 done
# Row 63174 done
# Row 63180 done
# Row 63182 done
# Row 63178 done
# Row 63183 done
# Row 63184 done
# Row 63185 done
# Row 63188 done
# Row 63190 done
# Row 63191 done
# Row 63186 done
# Row 63193 done
# Row 63196 done
# Row 63194 done
# Row 63189 done
# Row 63187 done
# Row 63195 done
# Row 63192 done
# Row 63204 done
# Row 63203 done
# Row 63202 done
# Row 63207 done
# Row 63205 done
# Row 63209 done
# Row 63198 done
# Row 63197 done
# Row 63210 done
# Row 63199 done
# Row 63201 done
# Row 63200 done
# Row 63206 done
# Row 63212 done
# Row 63208 done
# Row 63213 done
# Row 63214 done
# Row 63211 done
# Row 63216 done
# Row 63215 done
# Row 63218 done
# Row 63217 done
# Row 63219 done
# Row 63220 done
# Row 63226 done
# Row 63225 done
# Row 63223 done
# Row 63224 done
# Row 63222 done
# Row 63228 done
# Row 63227 done
# Row 63221 done
# Row 63230 done
# Row 63229 done
# Row 63231 done
# Row 63240 done
# Row 63237 done
# Row 63235 done
# Row 63236 done
# Row 63233 done
# Row 63238 done
# Row 63234 done
# Row 63239 done
# Row 63242 done
# Row 63232 done
# Row 63241 done
# Row 63243 done
# Row 63245 done
# Row 63244 done
# Row 63247 done
# Row 63246 done
# Row 63251 done
# Row 63250 done
# Row 63249 done
# Row 63248 done
# Row 63252 done
# Row 63255 done
# Row 63253 done
# Row 63254 done
# Row 63256 done
# Row 63257 done
# Row 63259 done
# Row 63258 done
# Row 63260 done
# Row 63264 done
# Row 63267 done
# Row 63261 done
# Row 63263 done
# Row 63265 done
# Row 63262 done
# Row 63266 done
# Row 63268 done
# Row 63269 done
# Row 63270 done
# Row 63271 done
# Row 63273 done
# Row 63272 done
# Row 63276 done
# Row 63280 done
# Row 63274 done
# Row 63278 done
# Row 63275 done
# Row 63281 done
# Row 63277 done
# Row 63279 done
# Row 63282 done
# Row 63283 done
# Row 63284 done
# Row 63285 done
# Row 63286 done
# Row 63287 done
# Row 63288 done
# Row 63291 done
# Row 63292 done
# Row 63289 done
# Row 63290 done
# Row 63298 done
# Row 63296 done
# Row 63294 done
# Row 63295 done
# Row 63293 done
# Row 63297 done
# Row 63300 done
# Row 63302 done
# Row 63301 done
# Row 63304 done
# Row 63303 done
# Row 63306 done
# Row 63305 done
# Row 63307 done
# Row 63309 done
# Row 63308 done
# Row 63310 done
# Row 63299 done
# Row 63313 done
# Row 63311 done
# Row 63312 done
# Row 63315 done
# Row 63314 done
# Row 63316 done
# Row 63318 done
# Row 63317 done
# Row 63320 done
# Row 63324 done
# Row 63319 done
# Row 63323 done
# Row 63321 done
# Row 63325 done
# Row 63327 done
# Row 63326 done
# Row 63322 done
# Row 63328 done
# Row 63329 done
# Row 63330 done
# Row 63331 done
# Row 63332 done
# Row 63334 done
# Row 63339 done
# Row 63337 done
# Row 63338 done
# Row 63336 done
# Row 63340 done
# Row 63333 done
# Row 63335 done
# Row 63341 done
# Row 63342 done
# Row 63343 done
# Row 63344 done
# Row 63345 done
# Row 63347 done
# Row 63346 done
# Row 63348 done
# Row 63353 done
# Row 63349 done
# Row 63350 done
# Row 63351 done
# Row 63352 done
# Row 63354 done
# Row 63356 done
# Row 63355 done
# Row 63357 done
# Row 63358 done
# Row 63360 done
# Row 63359 done
# Row 63366 done
# Row 63361 done
# Row 63364 done
# Row 63365 done
# Row 63362 done
# Row 63363 done
# Row 63370 done
# Row 63368 done
# Row 63367 done
# Row 63369 done
# Row 63371 done
# Row 63372 done
# ...
# Row 64267 done
# Row 64275 done
# Row 64277 done
# Row 64278 done
# Row 64279 done
# Row 64280 done
# Row 64284 done
# Row 64287 done
# Row 64281 done
# Row 64282 done
# Row 64290 done
# Row 64283 done
# Row 64285 done
# Row 64289 done
# Row 64288 done
# Row 64286 done
# Row 64291 done
# Row 64292 done
# Row 64295 done
# Row 64294 done
# Row 64302 done
# Row 64296 done
# Row 64300 done
# Row 64293 done
# Row 64299 done
# Row 64301 done
# Row 64297 done
# Row 64298 done
# Row 64304 done
# Row 64305 done
# Row 64306 done
# Row 64307 done
# Row 64303 done
# Row 64309 done
# Row 64308 done
# Row 64313 done
# Row 64312 done
# Row 64310 done
# Row 64314 done
# Row 64315 done
# Row 64311 done
# Row 64317 done
# Row 64316 done
# Row 64318 done
# Row 64319 done
# Row 64322 done
# Row 64321 done
# Row 64326 done
# Row 64324 done
# Row 64320 done
# Row 64323 done
# Row 64327 done
# Row 64329 done
# Row 64331 done
# Row 64330 done
# Row 64328 done
# Row 64325 done
# Row 64333 done
# Row 64332 done
# Row 64334 done
# Row 64339 done
# Row 64342 done
# Row 64340 done
# Row 64335 done
# Row 64343 done
# Row 64336 done
# Row 64337 done
# Row 64338 done
# Row 64345 done
# Row 64344 done
# Row 64346 done
# Row 64341 done
# Row 64347 done
# Row 64348 done
# Row 64350 done
# Row 64349 done
# Row 64351 done
# Row 64352 done
# Row 64354 done
# Row 64355 done
# Row 64353 done
# Row 64356 done
# Row 64357 done
# Row 64358 done
# Row 64359 done
# Row 64361 done
# Row 64360 done
# Row 64362 done
# Row 64364 done
# Row 64363 done
# Row 64367 done
# Row 64368 done
# Row 64365 done
# Row 64370 done
# Row 64366 done
# Row 64371 done
# Row 64372 done
# Row 64373 done
# Row 64369 done
# Row 64374 done
# Row 64375 done
# Row 64376 done
# Row 64377 done
# Row 64378 done
# Row 64383 done
# Row 64381 done
# Row 64380 done
# Row 64382 done
# Row 64384 done
# Row 64385 done
# Row 64387 done
# Row 64388 done
# Row 64389 done
# Row 64391 done
# Row 64392 done
# Row 64394 done
# Row 64386 done
# Row 64393 done
# Row 64395 done
# Row 64397 done
# Row 64396 done
# Row 64398 done
# Row 64400 done
# Row 64379 done
# Row 64401 done
# Row 64390 done
# Row 64399 done
# Row 64402 done
# Row 64403 done
# Row 64405 done
# Row 64404 done
# Row 64406 done
# Row 64410 done
# Row 64413 done
# Row 64408 done
# Row 64407 done
# Row 64412 done
# Row 64411 done
# Row 64409 done
# Row 64414 done
# Row 64415 done
# Row 64416 done
# Row 64417 done
# Row 64418 done
# Row 64420 done
# Row 64424 done
# Row 64419 done
# Row 64423 done
# Row 64426 done
# Row 64425 done
# Row 64422 done
# Row 64428 done
# Row 64427 done
# Row 64421 done
# Row 64429 done
# Row 64430 done
# Row 64431 done
# Row 64432 done
# Row 64433 done
# Row 64436 done
# Row 64434 done
# Row 64435 done
# Row 64439 done
# Row 64440 done
# Row 64441 done
# Row 64437 done
# Row 64442 done
# Row 64443 done
# Row 64444 done
# Row 64445 done
# Row 64446 done
# Row 64447 done
# Row 64448 done
# Row 64449 done
# Row 64452 done
# Row 64455 done
# Row 64451 done
# Row 64450 done
# Row 64453 done
# Row 64456 done
# Row 64457 done
# Row 64438 done
# Row 64454 done
# Row 64458 done
# Row 64460 done
# Row 64459 done
# Row 64463 done
# Row 64464 done
# Row 64462 done
# Row 64461 done
# Row 64469 done
# Row 64467 done
# Row 64466 done
# Row 64468 done
# Row 64465 done
# Row 64471 done
# Row 64470 done
# Row 64472 done
# Row 64475 done
# Row 64474 done
# Row 64473 done
# Row 64476 done
# Row 64480 done
# Row 64478 done
# Row 64479 done
# Row 64483 done
# Row 64477 done
# Row 64484 done
# Row 64482 done
# Row 64481 done
# Row 64485 done
# Row 64486 done
# Row 64487 done
# Row 64488 done
# Row 64489 done
# Row 64490 done
# Row 64492 done
# Row 64491 done
# Row 64494 done
# Row 64493 done
# Row 64495 done
# Row 64496 done
# Row 64498 done
# Row 64497 done
# Row 64499 done
# Row 64500 done
# Row 64501 done
# Row 64502 done
# Row 64504 done
# Row 64503 done
# Row 64505 done
# Row 64509 done
# Row 64506 done
# Row 64508 done
# Row 64511 done
# Row 64507 done
# Row 64510 done
# Row 64512 done
# Row 64513 done
# Row 64515 done
# Row 64514 done
# Row 64516 done
# Row 64517 done
# Row 64518 done
# Row 64519 done
# Row 64522 done
# Row 64524 done
# Row 64523 done
# Row 64526 done
# Row 64521 done
# Row 64520 done
# Row 64525 done
# Row 64527 done
# Row 64528 done
# Row 64529 done
# Row 64533 done
# Row 64530 done
# Row 64532 done
# Row 64531 done
# Row 64534 done
# Row 64536 done
# Row 64538 done
# Row 64535 done
# Row 64537 done
# Row 64539 done
# Row 64540 done
# Row 64541 done
# Row 64542 done
# Row 64543 done
# Row 64544 done
# Row 64546 done
# Row 64545 done
# Row 64547 done
# Row 64548 done
# Row 64550 done
# Row 64552 done
# Row 64549 done
# Row 64551 done
# Row 64553 done
# Row 64556 done
# Row 64555 done
# Row 64554 done
# Row 64557 done
# Row 64560 done
# Row 64559 done
# Row 64563 done
# Row 64558 done
# Row 64565 done
# Row 64561 done
# Row 64562 done
# Row 64567 done
# Row 64568 done
# Row 64566 done
# Row 64564 done
# Row 64569 done
# Row 64570 done
# Row 64572 done
# Row 64571 done
# Row 64574 done
# Row 64573 done
# Row 64575 done
# Row 64576 done
# Row 64577 done
# Row 64580 done
# Row 64578 done
# Row 64579 done
# Row 64581 done
# Row 64582 done
# Row 64583 done
# Row 64585 done
# Row 64587 done
# Row 64586 done
# Row 64584 done
# Row 64588 done
# Row 64590 done
# Row 64589 done
# Row 64591 done
# Row 64592 done
# Row 64593 done
# Row 64594 done
# Row 64596 done
# Row 64595 done
# Row 64597 done
# Row 64598 done
# Row 64599 done
# Row 64600 done
# Row 64602 done
# Row 64603 done
# Row 64604 done
# Row 64601 done
# Row 64605 done
# Row 64606 done
# Row 64607 done
# Row 64608 done
# Row 64609 done
# Row 64610 done
# Row 64612 done
# Row 64611 done
# Row 64613 done
# Row 64614 done
# Row 64616 done
# Row 64617 done
# Row 64615 done
# Row 64618 done
# Row 64620 done
# Row 64619 done
# Row 64622 done
# Row 64621 done
# Row 64623 done
# Row 64624 done
# Row 64626 done
# Row 64628 done
# Row 64629 done
# Row 64625 done
# Row 64627 done
# Row 64632 done
# Row 64630 done
# Row 64634 done
# Row 64631 done
# Row 64635 done
# Row 64633 done
# Row 64636 done
# Row 64637 done
# Row 64638 done
# Row 64640 done
# Row 64639 done
# Row 64643 done
# Row 64644 done
# Row 64641 done
# Row 64646 done
# Row 64645 done
# Row 64647 done
# Row 64649 done
# Row 64648 done
# Row 64651 done
# Row 64650 done
# Row 64652 done
# Row 64642 done
# Row 64653 done
# Row 64654 done
# Row 64655 done
# Row 64656 done
# Row 64657 done
# Row 64658 done
# Row 64661 done
# Row 64659 done
# Row 64660 done
# Row 64662 done
# Row 64665 done
# Row 64663 done
# Row 64666 done
# Row 64664 done
# Row 64667 done
# Row 64670 done
# Row 64668 done
# Row 64669 done
# Row 64671 done
# Row 64672 done
# Row 64674 done
# Row 64673 done
# Row 64676 done
# Row 64677 done
# Row 64675 done
# Row 64681 done
# Row 64679 done
# Row 64682 done
# Row 64678 done
# Row 64680 done
# Row 64683 done
# Row 64684 done
# Row 64687 done
# Row 64685 done
# Row 64686 done
# Row 64688 done
# Row 64689 done
# Row 64690 done
# Row 64692 done
# Row 64691 done
# Row 64694 done
# Row 64693 done
# Row 64695 done
# Row 64696 done
# Row 64697 done
# Row 64701 done
# Row 64698 done
# Row 64699 done
# Row 64700 done
# Row 64705 done
# Row 64702 done
# Row 64703 done
# Row 64704 done
# Row 64707 done
# Row 64709 done
# Row 64706 done
# Row 64710 done
# Row 64711 done
# Row 64712 done
# Row 64708 done
# Row 64713 done
# Row 64714 done
# Row 64715 done
# Row 64718 done
# Row 64717 done
# Row 64719 done
# Row 64721 done
# Row 64720 done
# Row 64727 done
# Row 64722 done
# Row 64716 done
# Row 64723 done
# Row 64725 done
# Row 64726 done
# Row 64724 done
# Row 64728 done
# Row 64730 done
# Row 64733 done
# Row 64729 done
# Row 64731 done
# Row 64732 done
# Row 64735 done
# Row 64734 done
# Row 64740 done
# Row 64738 done
# Row 64737 done
# Row 64741 done
# Row 64739 done
# Row 64736 done
# Row 64744 done
# Row 64743 done
# Row 64745 done
# Row 64742 done
# Row 64746 done
# Row 64747 done
# Row 64748 done
# Row 64749 done
# Row 64752 done
# Row 64750 done
# Row 64751 done
# Row 64754 done
# Row 64757 done
# Row 64756 done
# Row 64753 done
# Row 64758 done
# Row 64759 done
# Row 64760 done
# Row 64761 done
# Row 64762 done
# Row 64763 done
# Row 64765 done
# Row 64766 done
# Row 64764 done
# Row 64767 done
# Row 64770 done
# Row 64769 done
# Row 64755 done
# Row 64768 done
# Row 64774 done
# Row 64771 done
# Row 64772 done
# Row 64773 done
# Row 64775 done
# Row 64778 done
# Row 64777 done
# Row 64776 done
# Row 64782 done
# Row 64781 done
# Row 64780 done
# Row 64785 done
# Row 64786 done
# Row 64784 done
# Row 64787 done
# Row 64788 done
# Row 64789 done
# Row 64792 done
# Row 64793 done
# Row 64791 done
# Row 64795 done
# Row 64794 done
# Row 64796 done
# Row 64779 done
# Row 64783 done
# Row 64790 done
# Row 64797 done
# Row 64798 done
# Row 64799 done
# Row 64800 done
# Row 64805 done
# Row 64803 done
# Row 64807 done
# Row 64804 done
# Row 64809 done
# Row 64808 done
# Row 64802 done
# Row 64811 done
# Row 64810 done
# Row 64806 done
# Row 64801 done
# Row 64813 done
# Row 64812 done
# Row 64814 done
# Row 64815 done
# Row 64816 done
# Row 64818 done
# Row 64821 done
# Row 64822 done
# Row 64819 done
# Row 64823 done
# Row 64820 done
# Row 64824 done
# Row 64817 done
# Row 64826 done
# Row 64825 done
# Row 64827 done
# Row 64829 done
# Row 64831 done
# Row 64834 done
# Row 64828 done
# Row 64830 done
# Row 64837 done
# Row 64832 done
# Row 64835 done
# Row 64833 done
# Row 64836 done
# Row 64839 done
# Row 64838 done
# Row 64840 done
# Row 64841 done
# Row 64845 done
# Row 64843 done
# Row 64844 done
# Row 64842 done
# Row 64851 done
# Row 64848 done
# Row 64850 done
# Row 64852 done
# Row 64847 done
# Row 64849 done
# Row 64846 done
# Row 64853 done
# Row 64854 done
# Row 64855 done
# Row 64856 done
# Row 64859 done
# Row 64858 done
# Row 64861 done
# Row 64860 done
# Row 64863 done
# Row 64865 done
# Row 64862 done
# Row 64857 done
# Row 64864 done
# Row 64867 done
# Row 64866 done
# Row 64872 done
# Row 64868 done
# Row 64870 done
# Row 64874 done
# Row 64871 done
# Row 64869 done
# Row 64873 done
# Row 64876 done
# Row 64875 done
# Row 64879 done
# Row 64878 done
# Row 64877 done
# Row 64880 done
# Row 64882 done
# Row 64883 done
# Row 64886 done
# Row 64881 done
# Row 64885 done
# Row 64884 done
# Row 64887 done
# Row 64888 done
# Row 64889 done
# Row 64891 done
# Row 64890 done
# Row 64892 done
# Row 64893 done
# Row 64896 done
# Row 64895 done
# Row 64898 done
# Row 64894 done
# Row 64897 done
# Row 64900 done
# Row 64899 done
# Row 64901 done
# Row 64902 done
# Row 64903 done
# Row 64906 done
# Row 64904 done
# Row 64905 done
# Row 64909 done
# Row 64908 done
# Row 64915 done
# Row 64912 done
# Row 64914 done
# Row 64911 done
# Row 64907 done
# Row 64916 done
# Row 64918 done
# Row 64919 done
# Row 64910 done
# Row 64913 done
# Row 64917 done
# Row 64920 done
# Row 64922 done
# Row 64921 done
# Row 64923 done
# Row 64924 done
# Row 64925 done
# Row 64926 done
# Row 64927 done
# Row 64928 done
# Row 64929 done
# Row 64931 done
# Row 64930 done
# Row 64932 done
# Row 64934 done
# Row 64933 done
# Row 64935 done
# Row 64936 done
# Row 64937 done
# Row 64938 done
# Row 64939 done
# Row 64940 done
# Row 64941 done
# Row 64942 done
# Row 64944 done
# Row 64946 done
# Row 64943 done
# Row 64949 done
# Row 64951 done
# Row 64948 done
# Row 64953 done
# Row 64952 done
# Row 64954 done
# Row 64955 done
# Row 64947 done
# Row 64950 done
# Row 64945 done
# Row 64956 done
# Row 64957 done
# Row 64958 done
# Row 64960 done
# Row 64964 done
# Row 64959 done
# Row 64962 done
# Row 64961 done
# Row 64963 done
# Row 64966 done
# Row 64970 done
# Row 64967 done
# Row 64965 done
# Row 64968 done
# Row 64969 done
# Row 64971 done
# Row 64972 done
# Row 64973 done
# Row 64975 done
# Row 64974 done
# Row 64979 done
# Row 64978 done
# Row 64976 done
# Row 64977 done
# Row 64980 done
# Row 64981 done
# Row 64983 done
# Row 64982 done
# Row 64984 done
# Row 64985 done
# Row 64986 done
# Row 64988 done
# Row 64987 done
# Row 64989 done
# Row 64991 done
# Row 64990 done
# Row 64995 done
# Row 64994 done
# Row 64992 done
# Row 64993 done
# Row 64997 done
# Row 64996 done
# Row 64998 done
# Row 64999 done
# Row 65000 done
# Row 65001 done
# Row 65002 done
# Row 65004 done
# Row 65003 done
# Row 65005 done
# Row 65006 done
# Row 65007 done
# Row 65008 done
# Row 65009 done
# Row 65010 done
# Row 65012 done
# Row 65011 done
# Row 65013 done
# Row 65014 done
# Row 65015 done
# Row 65016 done
# Row 65019 done
# Row 65021 done
# Row 65020 done
# Row 65017 done
# Row 65018 done
# Row 65023 done
# Row 65022 done
# Row 65024 done
# Row 65025 done
# Row 65027 done
# Row 65026 done
# Row 65028 done
# Row 65029 done
# Row 65031 done
# Row 65032 done
# Row 65034 done
# Row 65033 done
# Row 65035 done
# Row 65030 done
# Row 65037 done
# Row 65038 done
# Row 65036 done
# Row 65039 done
# Row 65040 done
# Row 65043 done
# Row 65041 done
# Row 65042 done
# Row 65044 done
# Row 65045 done
# Row 65046 done
# Row 65047 done
# Row 65054 done
# Row 65058 done
# Row 65053 done
# Row 65050 done
# Row 65049 done
# Row 65051 done
# Row 65057 done
# Row 65052 done
# Row 65055 done
# Row 65048 done
# Row 65056 done
# Row 65059 done
# Row 65061 done
# Row 65060 done
# Row 65067 done
# Row 65062 done
# Row 65071 done
# Row 65064 done
# Row 65065 done
# Row 65063 done
# Row 65066 done
# Row 65069 done
# Row 65068 done
# Row 65070 done
# Row 65072 done
# Row 65073 done
# Row 65075 done
# Row 65079 done
# Row 65074 done
# Row 65083 done
# Row 65081 done
# Row 65077 done
# Row 65078 done
# Row 65076 done
# Row 65080 done
# Row 65085 done
# Row 65082 done
# Row 65084 done
# Row 65086 done
# Row 65089 done
# Row 65088 done
# Row 65087 done
# Row 65097 done
# Row 65093 done
# Row 65096 done
# Row 65092 done
# Row 65095 done
# Row 65090 done
# Row 65098 done
# Row 65100 done
# Row 65091 done
# Row 65101 done
# Row 65094 done
# Row 65099 done
# Row 65108 done
# Row 65105 done
# Row 65106 done
# Row 65104 done
# Row 65102 done
# Row 65103 done
# Row 65107 done
# Row 65110 done
# Row 65109 done
# Row 65111 done
# Row 65113 done
# Row 65120 done
# Row 65115 done
# Row 65119 done
# Row 65116 done
# Row 65122 done
# Row 65114 done
# Row 65117 done
# Row 65121 done
# Row 65118 done
# Row 65112 done
# Row 65123 done
# Row 65124 done
# Row 65126 done
# Row 65125 done
# Row 65127 done
# Row 65128 done
# Row 65135 done
# Row 65131 done
# Row 65130 done
# Row 65132 done
# Row 65136 done
# Row 65129 done
# Row 65133 done
# Row 65134 done
# Row 65137 done
# Row 65138 done
# Row 65139 done
# Row 65140 done
# Row 65141 done
# Row 65142 done
# Row 65145 done
# Row 65146 done
# Row 65144 done
# Row 65147 done
# Row 65143 done
# Row 65149 done
# Row 65151 done
# Row 65148 done
# Row 65152 done
# Row 65150 done
# Row 65153 done
# Row 65154 done
# Row 65155 done
# Row 65156 done
# Row 65157 done
# Row 65160 done
# Row 65158 done
# Row 65159 done
# Row 65161 done
# Row 65162 done
# Row 65164 done
# Row 65163 done
# Row 65165 done
# Row 65166 done
# Row 65167 done
# Row 65168 done
# Row 65172 done
# Row 65173 done
# Row 65170 done
# Row 65174 done
# Row 65171 done
# Row 65169 done
#                     preprint_doi             published_doi_x accession_found  \
# 0                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 1                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 2                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 3                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 4                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# ...                          ...                         ...             ...
# 65170  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 65171  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 65172  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 65173  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 65174  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
#
#                                                GSM_links  \
# 0      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# ...                                                  ...
# 65170  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 65171  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 65172  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 65173  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 65174  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                               SRX_links
# 0       https://www.ncbi.nlm.nih.gov/sra?term=SRX631821
# 1       https://www.ncbi.nlm.nih.gov/sra?term=SRX631822
# 2       https://www.ncbi.nlm.nih.gov/sra?term=SRX631823
# 3       https://www.ncbi.nlm.nih.gov/sra?term=SRX631824
# 4       https://www.ncbi.nlm.nih.gov/sra?term=SRX631825
# ...                                                 ...
# 65170  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738885
# 65171  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738886
# 65172  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738887
# 65173  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738888
# 65174  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738889
#
# [65175 rows x 5 columns]
# Warning: total number of rows (65175) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
df1.to_csv("/content/srr_dates_exploded_returned.csv")

# %% [markdown]
# At the very begining, let's fill the nan values in the column "SRX_links" with "SRX not found". In the next step, let's take the whole "srr_dates_exploded_returned.csv" into two parts: the column "SRX_links", there are two categories: one is the with the link-"https://www.ncbi.nlm.nih.gov/sra?term=SRX"; the other is the "SRX not found".

# %%
import pandas as pd
df_3 = pd.read_csv('/content/srr_dates_exploded_returned.csv')
df_3['SRX_links'] = df_3['SRX_links'].fillna('SRX not found')

df_3_new = df_3.loc[df_3['SRX_links']=='SRX not found']
df_3_new.to_csv('/content/SRR_dates_equals_to_GSE_published_dates_new.csv')

# %%
df_2 = df_3.loc[~(df_3['SRX_links']=='SRX not found')]
df_2.to_csv('/content/srr_dates_need_to_be_extracted.csv')

# %% [markdown]
# # **Extract all the SRR dates**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

def extract_SRR_dates(SRX_url):
    response = requests.get(SRX_url)
    if response.status_code == 200:
        content = response.content
        soup = BeautifulSoup(content, "html.parser")
        count = 0
        th_elems = soup.find_all('th')
        for th_elem in th_elems:
            if 'Published' in th_elem.text:
                td_elems = soup.find_all('td')
                for i, td_elem in enumerate(td_elems, start=1):
                    if td_elem.get('align') == 'right':
                        count += 1
                        if count == 3:
                           SRR_published_dates = td_elems[i].text
                return SRR_published_dates
        return "Published section not found"
    else:
        return "Failed to fetch the page"

def process_row(row):
    SRX_url = row['SRX_links']
    return extract_SRR_dates(SRX_url)

df2 = pd.read_csv("/content/srr_dates_need_to_be_extracted.csv")

# Prepare a dictionary to hold our results
results = {}

# Use ThreadPoolExecutor to parallelize the extraction
with ThreadPoolExecutor(max_workers=12) as executor:
    # Submit tasks to the executor
    future_to_row = {executor.submit(process_row, row): index for index, row in df2.iterrows()}

    # Collect the results as they are completed
    for future in as_completed(future_to_row):
        index = future_to_row[future]
        try:
            results[index] = future.result()
        except Exception as exc:
            print(f'Generated an exception: {exc}')
        else:
            print(f'Row {index} done')

    # Update the DataFrame with the results
for index, SRR_published_dates in results.items():
    # Convert the list of links to a string representation if you want to store it in a single cell
    # You can choose a separator that suits your needs; here, I use a comma.
    df2.at[index, 'SRR_dates'] = SRR_published_dates
df2
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Row 49759 done
# Row 49760 done
# Row 49761 done
# Row 49762 done
# Row 49765 done
# Row 49764 done
# Row 49766 done
# Row 49763 done
# Row 49768 done
# Row 49769 done
# Row 49767 done
# Row 49770 done
# Row 49771 done
# Row 49774 done
# Row 49772 done
# Row 49776 done
# Row 49773 done
# Row 49778 done
# Row 49777 done
# Row 49775 done
# Row 49780 done
# Row 49781 done
# Row 49784 done
# Row 49779 done
# Row 49783 done
# Row 49782 done
# Row 49789 done
# Row 49788 done
# Row 49786 done
# Row 49787 done
# Row 49790 done
# Row 49785 done
# Row 49791 done
# Row 49794 done
# Row 49792 done
# Row 49796 done
# Row 49793 done
# Row 49795 done
# Row 49797 done
# Row 49798 done
# Row 49800 done
# Row 49799 done
# Row 49802 done
# Row 49801 done
# Row 49803 done
# Row 49805 done
# Row 49806 done
# Row 49807 done
# Row 49808 done
# Row 49804 done
# Row 49809 done
# Row 49810 done
# Row 49811 done
# Row 49813 done
# Row 49812 done
# Row 49814 done
# Row 49815 done
# Row 49820 done
# Row 49819 done
# Row 49816 done
# Row 49817 done
# Row 49818 done
# Row 49821 done
# Row 49823 done
# Row 49822 done
# Row 49825 done
# Row 49826 done
# Row 49824 done
# Row 49827 done
# Row 49828 done
# Row 49829 done
# Row 49832 done
# Row 49833 done
# Row 49831 done
# Row 49830 done
# Row 49837 done
# Row 49835 done
# Row 49834 done
# Row 49838 done
# Row 49836 done
# Row 49839 done
# Row 49840 done
# Row 49841 done
# Row 49842 done
# Row 49843 done
# Row 49845 done
# Row 49844 done
# Row 49846 done
# Row 49849 done
# Row 49847 done
# Row 49850 done
# Row 49851 done
# Row 49848 done
# Row 49852 done
# Row 49853 done
# Row 49855 done
# Row 49854 done
# Row 49856 done
# Row 49858 done
# Row 49857 done
# Row 49863 done
# Row 49859 done
# Row 49864 done
# Row 49861 done
# Row 49862 done
# Row 49865 done
# Row 49860 done
# Row 49866 done
# Row 49867 done
# Row 49868 done
# Row 49869 done
# Row 49870 done
# Row 49872 done
# Row 49871 done
# Row 49874 done
# Row 49875 done
# Row 49877 done
# Row 49873 done
# Row 49879 done
# Row 49882 done
# Row 49876 done
# Row 49881 done
# Row 49878 done
# Row 49880 done
# Row 49883 done
# Row 49884 done
# Row 49885 done
# Row 49886 done
# Row 49887 done
# Row 49890 done
# Row 49889 done
# Row 49894 done
# Row 49893 done
# Row 49888 done
# Row 49892 done
# Row 49891 done
# Row 49895 done
# Row 49896 done
# Row 49897 done
# Row 49899 done
# Row 49900 done
# Row 49898 done
# Row 49901 done
# Row 49902 done
# Row 49903 done
# Row 49904 done
# Row 49905 done
# Row 49906 done
# Row 49909 done
# Row 49908 done
# Row 49907 done
# Row 49911 done
# Row 49912 done
# Row 49910 done
# Row 49913 done
# Row 49915 done
# Row 49914 done
# Row 49916 done
# Row 49917 done
# Row 49919 done
# Row 49918 done
# Row 49920 done
# Row 49922 done
# Row 49923 done
# Row 49924 done
# Row 49926 done
# Row 49927 done
# Row 49921 done
# Row 49925 done
# Row 49928 done
# Row 49930 done
# Row 49929 done
# Row 49931 done
# Row 49934 done
# Row 49933 done
# Row 49932 done
# Row 49937 done
# Row 49938 done
# Row 49936 done
# Row 49935 done
# Row 49945 done
# Row 49939 done
# Row 49941 done
# Row 49940 done
# Row 49944 done
# Row 49942 done
# Row 49943 done
# Row 49946 done
# Row 49949 done
# Row 49948 done
# Row 49950 done
# Row 49947 done
# Row 49954 done
# Row 49952 done
# Row 49955 done
# Row 49956 done
# Row 49951 done
# Row 49957 done
# Row 49953 done
# Row 49958 done
# Row 49960 done
# Row 49961 done
# Row 49959 done
# Row 49962 done
# Row 49963 done
# Row 49964 done
# Row 49965 done
# Row 49969 done
# Row 49966 done
# Row 49968 done
# Row 49967 done
# Row 49970 done
# Row 49971 done
# Row 49972 done
# Row 49973 done
# Row 49976 done
# Row 49975 done
# Row 49974 done
# Row 49977 done
# Row 49980 done
# Row 49979 done
# Row 49981 done
# Row 49983 done
# Row 49978 done
# Row 49982 done
# Row 49984 done
# Row 49985 done
# Row 49989 done
# Row 49988 done
# Row 49987 done
# Row 49986 done
# Row 49990 done
# Row 49991 done
# Row 49992 done
# Row 49993 done
# Row 49995 done
# Row 49997 done
# Row 49994 done
# Row 49996 done
# Row 49999 done
# Row 49998 done
# Row 50000 done
# Row 50001 done
# Row 50002 done
# Row 50003 done
# Row 50004 done
# Row 50005 done
# Row 50006 done
# Row 50008 done
# Row 50010 done
# Row 50009 done
# Row 50007 done
# Row 50013 done
# Row 50011 done
# Row 50014 done
# Row 50016 done
# Row 50012 done
# Row 50017 done
# Row 50015 done
# Row 50018 done
# Row 50019 done
# Row 50020 done
# Row 50022 done
# Row 50021 done
# Row 50024 done
# Row 50027 done
# Row 50026 done
# Row 50029 done
# Row 50028 done
# Row 50025 done
# Row 50023 done
# Row 50030 done
# Row 50031 done
# Row 50032 done
# Row 50033 done
# Row 50034 done
# Row 50035 done
# Row 50036 done
# Row 50037 done
# Row 50038 done
# Row 50039 done
# Row 50040 done
# Row 50042 done
# Row 50044 done
# Row 50046 done
# Row 50043 done
# Row 50041 done
# Row 50045 done
# Row 50047 done
# Row 50049 done
# Row 50048 done
# Row 50051 done
# Row 50050 done
# Row 50052 done
# Row 50056 done
# Row 50053 done
# Row 50057 done
# Row 50059 done
# Row 50054 done
# Row 50055 done
# Row 50058 done
# Row 50060 done
# Row 50062 done
# Row 50061 done
# Row 50063 done
# Row 50064 done
# Row 50069 done
# Row 50065 done
# Row 50066 done
# Row 50067 done
# Row 50068 done
# Row 50071 done
# Row 50070 done
# Row 50072 done
# Row 50073 done
# Row 50074 done
# Row 50075 done
# Row 50076 done
# Row 50077 done
# Row 50078 done
# Row 50079 done
# Row 50080 done
# Row 50081 done
# Row 50085 done
# Row 50082 done
# Row 50084 done
# Row 50087 done
# Row 50083 done
# Row 50086 done
# Row 50088 done
# Row 50089 done
# Row 50090 done
# Row 50091 done
# Row 50092 done
# Row 50093 done
# Row 50094 done
# Row 50095 done
# Row 50096 done
# Row 50099 done
# Row 50098 done
# Row 50097 done
# Row 50102 done
# Row 50100 done
# Row 50104 done
# Row 50103 done
# Row 50101 done
# Row 50105 done
# Row 50106 done
# Row 50107 done
# Row 50108 done
# Row 50109 done
# Row 50110 done
# Row 50111 done
# Row 50117 done
# Row 50113 done
# Row 50112 done
# Row 50119 done
# Row 50116 done
# Row 50115 done
# Row 50114 done
# Row 50118 done
# Row 50122 done
# Row 50121 done
# Row 50123 done
# Row 50120 done
# Row 50124 done
# Row 50127 done
# Row 50130 done
# Row 50128 done
# Row 50126 done
# Row 50131 done
# Row 50129 done
# Row 50125 done
# Row 50133 done
# Row 50134 done
# Row 50132 done
# Row 50135 done
# Row 50136 done
# Row 50137 done
# Row 50142 done
# Row 50138 done
# Row 50141 done
# Row 50140 done
# Row 50143 done
# Row 50139 done
# Row 50146 done
# Row 50145 done
# Row 50147 done
# Row 50144 done
# Row 50148 done
# Row 50149 done
# Row 50150 done
# Row 50152 done
# Row 50151 done
# Row 50153 done
# Row 50154 done
# Row 50157 done
# Row 50155 done
# Row 50160 done
# Row 50158 done
# Row 50161 done
# Row 50162 done
# Row 50156 done
# Row 50159 done
# Row 50164 done
# Row 50163 done
# Row 50165 done
# Row 50166 done
# Row 50167 done
# Row 50168 done
# Row 50172 done
# Row 50169 done
# Row 50170 done
# Row 50171 done
# Row 50173 done
# Row 50174 done
# Row 50177 done
# Row 50178 done
# Row 50176 done
# Row 50175 done
# Row 50179 done
# Row 50180 done
# Row 50182 done
# Row 50181 done
# Row 50184 done
# Row 50185 done
# Row 50183 done
# Row 50186 done
# Row 50190 done
# Row 50192 done
# Row 50189 done
# Row 50187 done
# Row 50191 done
# Row 50188 done
# Row 50194 done
# Row 50193 done
# Row 50195 done
# Row 50196 done
# Row 50198 done
# Row 50197 done
# Row 50199 done
# Row 50202 done
# Row 50203 done
# Row 50200 done
# Row 50201 done
# Row 50204 done
# Row 50206 done
# Row 50205 done
# Row 50207 done
# Row 50208 done
# Row 50209 done
# Row 50210 done
# Row 50211 done
# Row 50212 done
# Row 50216 done
# Row 50214 done
# Row 50215 done
# Row 50217 done
# Row 50213 done
# Row 50218 done
# Row 50220 done
# Row 50219 done
# Row 50221 done
# Row 50222 done
# Row 50223 done
# Row 50226 done
# Row 50224 done
# Row 50229 done
# Row 50230 done
# Row 50232 done
# Row 50228 done
# Row 50225 done
# Row 50231 done
# Row 50227 done
# Row 50233 done
# Row 50234 done
# Row 50235 done
# Row 50236 done
# Row 50237 done
# Row 50240 done
# Row 50238 done
# Row 50241 done
# Row 50247 done
# Row 50246 done
# Row 50244 done
# Row 50245 done
# Row 50243 done
# Row 50239 done
# Row 50248 done
# Row 50242 done
# Row 50249 done
# Row 50250 done
# Row 50251 done
# Row 50252 done
# Row 50255 done
# Row 50256 done
# Row 50253 done
# Row 50257 done
# Row 50254 done
# Row 50261 done
# Row 50260 done
# Row 50262 done
# Row 50259 done
# Row 50263 done
# Row 50258 done
# Row 50265 done
# Row 50264 done
# Row 50268 done
# Row 50266 done
# Row 50267 done
# Row 50269 done
# Row 50276 done
# Row 50271 done
# Row 50270 done
# Row 50277 done
# Row 50272 done
# Row 50273 done
# Row 50274 done
# Row 50275 done
# Row 50279 done
# Row 50280 done
# Row 50278 done
# Row 50281 done
# Row 50282 done
# Row 50283 done
# Row 50284 done
# Row 50288 done
# Row 50286 done
# Row 50285 done
# Row 50289 done
# Row 50287 done
# Row 50292 done
# Row 50291 done
# Row 50290 done
# Row 50293 done
# Row 50294 done
# Row 50296 done
# Row 50295 done
# Row 50298 done
# Row 50297 done
# Row 50301 done
# Row 50300 done
# Row 50299 done
# Row 50302 done
# Row 50305 done
# Row 50304 done
# Row 50303 done
# Row 50307 done
# Row 50308 done
# Row 50306 done
# Row 50309 done
# Row 50310 done
# Row 50311 done
# Row 50313 done
# Row 50312 done
# Row 50316 done
# Row 50319 done
# Row 50314 done
# Row 50315 done
# Row 50320 done
# Row 50318 done
# Row 50317 done
# Row 50322 done
# Row 50323 done
# Row 50321 done
# Row 50324 done
# Row 50325 done
# Row 50326 done
# Row 50327 done
# Row 50328 done
# Row 50329 done
# Row 50330 done
# Row 50333 done
# Row 50331 done
# Row 50332 done
# Row 50335 done
# Row 50336 done
# Row 50337 done
# Row 50334 done
# Row 50339 done
# Row 50338 done
# Row 50340 done
# Row 50341 done
# Row 50342 done
# Row 50343 done
# Row 50344 done
# Row 50345 done
# Row 50346 done
# Row 50349 done
# Row 50347 done
# Row 50354 done
# Row 50355 done
# Row 50351 done
# Row 50350 done
# Row 50348 done
# Row 50353 done
# Row 50352 done
# Row 50357 done
# Row 50356 done
# Row 50358 done
# Row 50361 done
# Row 50364 done
# Row 50368 done
# Row 50369 done
# Row 50359 done
# Row 50367 done
# Row 50366 done
# Row 50362 done
# Row 50360 done
# Row 50365 done
# Row 50363 done
# Row 50370 done
# Row 50371 done
# Row 50372 done
# Row 50373 done
# Row 50374 done
# Row 50378 done
# Row 50375 done
# Row 50377 done
# Row 50376 done
# Row 50381 done
# Row 50379 done
# Row 50380 done
# Row 50382 done
# Row 50383 done
# Row 50384 done
# Row 50385 done
# Row 50386 done
# Row 50387 done
# Row 50388 done
# Row 50391 done
# Row 50389 done
# Row 50395 done
# Row 50396 done
# Row 50392 done
# Row 50394 done
# Row 50390 done
# Row 50397 done
# Row 50393 done
# Row 50398 done
# Row 50399 done
# Row 50400 done
# Row 50401 done
# Row 50402 done
# Row 50403 done
# Row 50406 done
# Row 50405 done
# Row 50404 done
# Row 50407 done
# Row 50409 done
# Row 50410 done
# Row 50408 done
# Row 50412 done
# Row 50411 done
# Row 50413 done
# Row 50414 done
# Row 50415 done
# Row 50416 done
# Row 50417 done
# Row 50418 done
# Row 50419 done
# Row 50424 done
# Row 50422 done
# Row 50421 done
# Row 50423 done
# Row 50420 done
# Row 50427 done
# Row 50426 done
# Row 50428 done
# Row 50425 done
# Row 50429 done
# Row 50430 done
# Row 50431 done
# Row 50432 done
# Row 50433 done
# Row 50434 done
# Row 50435 done
# Row 50437 done
# Row 50442 done
# Row 50438 done
# Row 50436 done
# Row 50441 done
# Row 50439 done
# Row 50440 done
# Row 50443 done
# Row 50445 done
# Row 50444 done
# Row 50446 done
# Row 50447 done
# Row 50448 done
# Row 50453 done
# Row 50454 done
# Row 50449 done
# Row 50451 done
# Row 50450 done
# Row 50452 done
# Row 50455 done
# Row 50459 done
# Row 50458 done
# Row 50456 done
# Row 50460 done
# Row 50457 done
# Row 50461 done
# Row 50462 done
# Row 50463 done
# Row 50465 done
# Row 50464 done
# Row 50466 done
# Row 50467 done
# Row 50469 done
# Row 50468 done
# Row 50470 done
# Row 50472 done
# Row 50471 done
# Row 50474 done
# Row 50473 done
# Row 50475 done
# Row 50476 done
# Row 50477 done
# Row 50479 done
# Row 50480 done
# Row 50483 done
# Row 50484 done
# Row 50478 done
# Row 50487 done
# Row 50486 done
# Row 50482 done
# Row 50485 done
# Row 50481 done
# Row 50488 done
# Row 50489 done
# Row 50490 done
# Row 50491 done
# Row 50493 done
# Row 50492 done
# Row 50494 done
# Row 50496 done
# Row 50495 done
# Row 50497 done
# Row 50500 done
# Row 50499 done
# Row 50498 done
# Row 50501 done
# Row 50502 done
# Row 50503 done
# Row 50504 done
# Row 50506 done
# Row 50505 done
# Row 50507 done
# Row 50511 done
# Row 50509 done
# Row 50512 done
# Row 50513 done
# Row 50508 done
# Row 50510 done
# Row 50514 done
# Row 50515 done
# Row 50518 done
# Row 50516 done
# Row 50517 done
# Row 50519 done
# Row 50525 done
# Row 50520 done
# Row 50522 done
# Row 50524 done
# Row 50523 done
# Row 50521 done
# Row 50526 done
# Row 50529 done
# Row 50530 done
# Row 50528 done
# Row 50527 done
# Row 50531 done
# Row 50532 done
# Row 50534 done
# Row 50533 done
# Row 50536 done
# Row 50535 done
# Row 50538 done
# Row 50537 done
# Row 50540 done
# Row 50542 done
# Row 50543 done
# Row 50539 done
# Row 50544 done
# Row 50541 done
# Row 50546 done
# Row 50545 done
# Row 50547 done
# Row 50548 done
# Row 50549 done
# Row 50550 done
# Row 50551 done
# Row 50552 done
# Row 50556 done
# Row 50553 done
# Row 50554 done
# Row 50555 done
# Row 50558 done
# Row 50557 done
# Row 50560 done
# Row 50559 done
# Row 50562 done
# Row 50561 done
# Row 50563 done
# Row 50566 done
# Row 50568 done
# Row 50567 done
# Row 50564 done
# Row 50565 done
# Row 50569 done
# Row 50570 done
# Row 50571 done
# Row 50572 done
# Row 50574 done
# Row 50573 done
# Row 50575 done
# Row 50576 done
# Row 50579 done
# Row 50580 done
# Row 50577 done
# Row 50578 done
# Row 50581 done
# Row 50582 done
# Row 50583 done
# Row 50587 done
# Row 50586 done
# Row 50585 done
# Row 50588 done
# Row 50584 done
# Row 50594 done
# Row 50593 done
# Row 50591 done
# Row 50592 done
# Row 50590 done
# Row 50589 done
# Row 50595 done
# Row 50598 done
# Row 50597 done
# Row 50599 done
# Row 50600 done
# Row 50596 done
# Row 50601 done
# Row 50602 done
# Row 50603 done
# Row 50605 done
# Row 50604 done
# Row 50606 done
# Row 50607 done
# Row 50609 done
# Row 50611 done
# Row 50612 done
# Row 50608 done
# Row 50610 done
# Row 50614 done
# Row 50615 done
# Row 50613 done
# Row 50618 done
# Row 50616 done
# Row 50617 done
# Row 50619 done
# Row 50620 done
# Row 50622 done
# Row 50621 done
# Row 50623 done
# Row 50624 done
# Row 50625 done
# Row 50627 done
# Row 50630 done
# Row 50626 done
# Row 50629 done
# Row 50628 done
# Row 50631 done
# Row 50632 done
# Row 50634 done
# Row 50633 done
# Row 50635 done
# Row 50636 done
# Row 50637 done
# Row 50638 done
# Row 50639 done
# Row 50641 done
# Row 50640 done
# Row 50643 done
# Row 50642 done
# Row 50646 done
# Row 50647 done
# Row 50644 done
# Row 50648 done
# Row 50645 done
# Row 50649 done
# Row 50650 done
# Row 50651 done
# Row 50652 done
# Row 50653 done
# Row 50654 done
# Row 50655 done
# Row 50656 done
# Row 50658 done
# Row 50660 done
# Row 50657 done
# Row 50659 done
# Row 50661 done
# Row 50662 done
# Row 50665 done
# Row 50664 done
# Row 50666 done
# Row 50663 done
# Row 50667 done
# Row 50670 done
# Row 50671 done
# Row 50668 done
# Row 50672 done
# Row 50669 done
# Row 50675 done
# Row 50673 done
# Row 50674 done
# Row 50677 done
# Row 50678 done
# Row 50676 done
# Row 50680 done
# Row 50679 done
# Row 50683 done
# Row 50685 done
# Row 50686 done
# Row 50687 done
# Row 50681 done
# Row 50690 done
# Row 50689 done
# Row 50688 done
# Row 50684 done
# Row 50691 done
# Row 50692 done
# Row 50693 done
# Row 50694 done
# Row 50696 done
# Row 50697 done
# Row 50695 done
# Row 50698 done
# Row 50699 done
# Row 50700 done
# Row 50701 done
# Row 50682 done
# Row 50703 done
# Row 50702 done
# Row 50704 done
# Row 50705 done
# Row 50707 done
# Row 50706 done
# Row 50708 done
# Row 50709 done
# Row 50710 done
# Row 50711 done
# Row 50713 done
# Row 50714 done
# Row 50720 done
# Row 50715 done
# Row 50712 done
# Row 50716 done
# Row 50719 done
# Row 50718 done
# Row 50717 done
# Row 50722 done
# Row 50721 done
# Row 50723 done
# Row 50724 done
# Row 50725 done
# Row 50727 done
# Row 50726 done
# Row 50732 done
# Row 50734 done
# Row 50729 done
# Row 50735 done
# Row 50731 done
# Row 50728 done
# Row 50733 done
# Row 50737 done
# Row 50730 done
# Row 50736 done
# Row 50739 done
# Row 50738 done
# Row 50740 done
# Row 50741 done
# Row 50744 done
# Row 50743 done
# Row 50747 done
# Row 50745 done
# Row 50748 done
# Row 50749 done
# Row 50742 done
# Row 50746 done
# Row 50750 done
# Row 50754 done
# Row 50752 done
# Row 50753 done
# Row 50751 done
# Row 50756 done
# Row 50755 done
# Row 50762 done
# Row 50763 done
# Row 50765 done
# Row 50764 done
# Row 50759 done
# Row 50758 done
# Row 50766 done
# Row 50760 done
# Row 50761 done
# Row 50757 done
# Row 50767 done
# Row 50768 done
# Row 50769 done
# Row 50770 done
# Row 50773 done
# Row 50776 done
# Row 50778 done
# Row 50775 done
# Row 50771 done
# Row 50772 done
# Row 50774 done
# Row 50780 done
# Row 50777 done
# Row 50779 done
# Row 50781 done
# Row 50782 done
# Row 50783 done
# Row 50785 done
# Row 50787 done
# Row 50789 done
# Row 50790 done
# Row 50786 done
# Row 50791 done
# Row 50784 done
# Row 50792 done
# Row 50788 done
# Row 50793 done
# Row 50794 done
# Row 50795 done
# Row 50796 done
# Row 50797 done
# Row 50798 done
# Row 50799 done
# Row 50803 done
# Row 50801 done
# Row 50800 done
# Row 50807 done
# Row 50802 done
# Row 50808 done
# Row 50806 done
# Row 50805 done
# Row 50804 done
# Row 50809 done
# Row 50810 done
# Row 50811 done
# Row 50812 done
# Row 50816 done
# Row 50815 done
# Row 50821 done
# Row 50813 done
# Row 50820 done
# Row 50817 done
# Row 50814 done
# Row 50818 done
# Row 50819 done
# Row 50822 done
# Row 50823 done
# Row 50824 done
# Row 50825 done
# Row 50826 done
# Row 50827 done
# Row 50832 done
# Row 50831 done
# Row 50830 done
# Row 50837 done
# Row 50836 done
# Row 50828 done
# Row 50835 done
# Row 50829 done
# Row 50834 done
# Row 50833 done
# Row 50838 done
# Row 50839 done
# Row 50840 done
# Row 50843 done
# Row 50847 done
# Row 50845 done
# Row 50848 done
# Row 50849 done
# Row 50844 done
# Row 50850 done
# Row 50851 done
# Row 50846 done
# Row 50842 done
# Row 50841 done
# Row 50852 done
# Row 50853 done
# Row 50854 done
# Row 50855 done
# Row 50856 done
# Row 50857 done
# Row 50858 done
# Row 50860 done
# Row 50863 done
# Row 50861 done
# Row 50864 done
# Row 50865 done
# Row 50862 done
# Row 50859 done
# Row 50866 done
# Row 50867 done
# Row 50868 done
# Row 50869 done
# Row 50870 done
# Row 50871 done
# Row 50877 done
# Row 50873 done
# Row 50874 done
# Row 50876 done
# Row 50872 done
# Row 50875 done
# Row 50879 done
# Row 50878 done
# Row 50882 done
# Row 50881 done
# Row 50880 done
# Row 50883 done
# Row 50884 done
# Row 50885 done
# Row 50890 done
# Row 50891 done
# Row 50887 done
# Row 50888 done
# Row 50886 done
# Row 50892 done
# Row 50889 done
# Row 50894 done
# Row 50896 done
# Row 50893 done
# Row 50895 done
# Row 50897 done
# Row 50898 done
# Row 50899 done
# Row 50900 done
# Row 50901 done
# Row 50905 done
# Row 50902 done
# Row 50904 done
# Row 50909 done
# Row 50903 done
# Row 50906 done
# Row 50907 done
# Row 50908 done
# Row 50911 done
# Row 50910 done
# Row 50912 done
# Row 50913 done
# Row 50914 done
# Row 50915 done
# Row 50916 done
# Row 50917 done
# Row 50922 done
# Row 50918 done
# Row 50921 done
# Row 50923 done
# Row 50919 done
# Row 50920 done
# Row 50925 done
# Row 50924 done
# Row 50926 done
# Row 50927 done
# Row 50928 done
# Row 50931 done
# Row 50930 done
# Row 50929 done
# Row 50932 done
# Row 50933 done
# Row 50937 done
# Row 50934 done
# Row 50938 done
# Row 50936 done
# Row 50935 done
# Row 50939 done
# Row 50940 done
# Row 50941 done
# Row 50942 done
# Row 50943 done
# Row 50944 done
# Row 50945 done
# Row 50947 done
# Row 50946 done
# Row 50948 done
# Row 50952 done
# Row 50949 done
# Row 50951 done
# Row 50950 done
# Row 50953 done
# Row 50956 done
# Row 50954 done
# Row 50955 done
# Row 50957 done
# Row 50958 done
# Row 50959 done
# Row 50960 done
# Row 50961 done
# Row 50964 done
# Row 50963 done
# Row 50965 done
# Row 50962 done
# Row 50968 done
# Row 50969 done
# Row 50967 done
# Row 50966 done
# Row 50972 done
# Row 50971 done
# Row 50970 done
# Row 50973 done
# Row 50974 done
# Row 50975 done
# Row 50976 done
# Row 50977 done
# Row 50978 done
# Row 50979 done
# Row 50984 done
# Row 50980 done
# Row 50981 done
# Row 50983 done
# Row 50985 done
# Row 50982 done
# Row 50989 done
# Row 50987 done
# Row 50990 done
# Row 50988 done
# Row 50991 done
# Row 50986 done
# Row 50993 done
# Row 50992 done
# Row 50996 done
# Row 50999 done
# Row 50998 done
# Row 50995 done
# Row 50997 done
# Row 50994 done
# Row 51000 done
# Row 51003 done
# Row 51002 done
# Row 51001 done
# Row 51004 done
# Row 51009 done
# Row 51007 done
# Row 51005 done
# Row 51008 done
# Row 51010 done
# Row 51011 done
# Row 51006 done
# Row 51016 done
# Row 51012 done
# Row 51015 done
# Row 51014 done
# Row 51013 done
# Row 51017 done
# Row 51018 done
# Row 51019 done
# Row 51020 done
# Row 51023 done
# Row 51022 done
# Row 51021 done
# Row 51025 done
# Row 51027 done
# Row 51026 done
# Row 51028 done
# Row 51024 done
# Row 51029 done
# Row 51030 done
# Row 51031 done
# Row 51035 done
# Row 51032 done
# Row 51034 done
# Row 51033 done
# Row 51036 done
# Row 51040 done
# Row 51038 done
# Row 51037 done
# Row 51041 done
# Row 51039 done
# Row 51042 done
# Row 51043 done
# Row 51044 done
# Row 51045 done
# Row 51047 done
# Row 51046 done
# Row 51048 done
# Row 51054 done
# Row 51055 done
# Row 51053 done
# Row 51056 done
# Row 51051 done
# Row 51049 done
# Row 51052 done
# Row 51059 done
# Row 51057 done
# Row 51050 done
# Row 51060 done
# Row 51058 done
# Row 51061 done
# Row 51062 done
# Row 51063 done
# Row 51064 done
# Row 51065 done
# Row 51068 done
# Row 51067 done
# Row 51066 done
# Row 51076 done
# Row 51069 done
# Row 51075 done
# Row 51074 done
# Row 51070 done
# Row 51071 done
# Row 51072 done
# Row 51073 done
# Row 51077 done
# Row 51079 done
# Row 51078 done
# Row 51080 done
# Row 51081 done
# Row 51087 done
# Row 51085 done
# Row 51084 done
# Row 51083 done
# Row 51086 done
# Row 51088 done
# Row 51082 done
# Row 51089 done
# Row 51090 done
# Row 51091 done
# Row 51092 done
# Row 51093 done
# Row 51094 done
# Row 51096 done
# Row 51095 done
# Row 51097 done
# Row 51098 done
# Row 51099 done
# Row 51100 done
# Row 51101 done
# Row 51102 done
# Row 51104 done
# Row 51103 done
# Row 51105 done
# Row 51106 done
# Row 51107 done
# Row 51108 done
# Row 51113 done
# Row 51109 done
# Row 51110 done
# Row 51111 done
# Row 51112 done
# Row 51115 done
# Row 51120 done
# Row 51117 done
# Row 51114 done
# Row 51116 done
# Row 51119 done
# Row 51118 done
# Row 51121 done
# Row 51122 done
# Row 51123 done
# Row 51124 done
# Row 51127 done
# Row 51129 done
# Row 51132 done
# Row 51128 done
# Row 51125 done
# Row 51130 done
# Row 51126 done
# Row 51131 done
# Row 51134 done
# Row 51135 done
# Row 51133 done
# Row 51136 done
# Row 51137 done
# Row 51138 done
# Row 51139 done
# Row 51140 done
# Row 51141 done
# Row 51142 done
# Row 51144 done
# Row 51147 done
# Row 51146 done
# Row 51148 done
# Row 51149 done
# Row 51150 done
# Row 51145 done
# Row 51151 done
# Row 51143 done
# Row 51152 done
# Row 51154 done
# Row 51153 done
# Row 51155 done
# Row 51162 done
# Row 51160 done
# Row 51157 done
# Row 51159 done
# Row 51158 done
# Row 51161 done
# Row 51156 done
# Row 51163 done
# Row 51165 done
# Row 51164 done
# Row 51166 done
# Row 51167 done
# Row 51168 done
# Row 51169 done
# Row 51172 done
# Row 51170 done
# Row 51178 done
# Row 51174 done
# Row 51177 done
# Row 51173 done
# Row 51176 done
# Row 51175 done
# Row 51180 done
# Row 51179 done
# Row 51171 done
# Row 51181 done
# Row 51182 done
# Row 51183 done
# Row 51185 done
# Row 51186 done
# Row 51189 done
# Row 51184 done
# Row 51190 done
# Row 51191 done
# Row 51192 done
# Row 51187 done
# Row 51195 done
# Row 51188 done
# Row 51193 done
# Row 51194 done
# Row 51196 done
# Row 51197 done
# Row 51199 done
# Row 51198 done
# Row 51203 done
# Row 51204 done
# Row 51200 done
# Row 51208 done
# Row 51202 done
# Row 51205 done
# Row 51207 done
# Row 51201 done
# Row 51209 done
# Row 51206 done
# Row 51210 done
# Row 51211 done
# Row 51213 done
# Row 51212 done
# Row 51214 done
# Row 51219 done
# Row 51215 done
# Row 51221 done
# Row 51216 done
# Row 51222 done
# Row 51220 done
# Row 51217 done
# Row 51218 done
# Row 51225 done
# Row 51226 done
# Row 51224 done
# Row 51223 done
# Row 51227 done
# Row 51228 done
# Row 51229 done
# Row 51230 done
# Row 51234 done
# Row 51232 done
# Row 51233 done
# Row 51238 done
# Row 51231 done
# Row 51236 done
# Row 51237 done
# Row 51239 done
# Row 51235 done
# Row 51240 done
# Row 51241 done
# Row 51242 done
# Row 51243 done
# Row 51244 done
# Row 51245 done
# Row 51246 done
# Row 51248 done
# Row 51251 done
# Row 51250 done
# Row 51252 done
# Row 51254 done
# Row 51247 done
# Row 51253 done
# Row 51255 done
# Row 51249 done
# Row 51256 done
# Row 51257 done
# Row 51258 done
# Row 51259 done
# Row 51260 done
# Row 51262 done
# Row 51266 done
# Row 51265 done
# Row 51264 done
# Row 51261 done
# Row 51263 done
# Row 51267 done
# Row 51269 done
# Row 51268 done
# Row 51270 done
# Row 51271 done
# Row 51272 done
# Row 51273 done
# Row 51274 done
# Row 51275 done
# Row 51276 done
# Row 51278 done
# Row 51277 done
# Row 51280 done
# Row 51279 done
# Row 51284 done
# Row 51281 done
# Row 51283 done
# Row 51282 done
# Row 51286 done
# Row 51285 done
# Row 51287 done
# Row 51288 done
# Row 51289 done
# Row 51292 done
# Row 51291 done
# Row 51294 done
# Row 51290 done
# Row 51295 done
# Row 51296 done
# Row 51293 done
# Row 51297 done
# Row 51301 done
# Row 51298 done
# Row 51299 done
# Row 51300 done
# Row 51302 done
# Row 51304 done
# Row 51305 done
# Row 51303 done
# Row 51307 done
# Row 51306 done
# Row 51310 done
# Row 51309 done
# Row 51313 done
# Row 51308 done
# Row 51312 done
# Row 51311 done
# Row 51314 done
# Row 51315 done
# Row 51316 done
# Row 51317 done
# Row 51318 done
# Row 51319 done
# Row 51320 done
# Row 51321 done
# Row 51323 done
# Row 51326 done
# Row 51325 done
# Row 51324 done
# Row 51322 done
# Row 51329 done
# Row 51327 done
# Row 51328 done
# Row 51332 done
# Row 51331 done
# Row 51330 done
# Row 51333 done
# Row 51334 done
# Row 51335 done
# Row 51336 done
# Row 51337 done
# Row 51339 done
# Row 51340 done
# Row 51338 done
# Row 51341 done
# Row 51343 done
# Row 51342 done
# Row 51345 done
# Row 51344 done
# Row 51346 done
# Row 51347 done
# Row 51348 done
# Row 51349 done
# Row 51351 done
# Row 51350 done
# Row 51352 done
# Row 51353 done
# Row 51354 done
# Row 51358 done
# Row 51355 done
# Row 51357 done
# Row 51359 done
# Row 51356 done
# Row 51361 done
# Row 51360 done
# Row 51362 done
# Row 51363 done
# Row 51365 done
# Row 51364 done
# Row 51366 done
# Row 51367 done
# Row 51368 done
# Row 51370 done
# Row 51369 done
# Row 51372 done
# Row 51373 done
# Row 51371 done
# Row 51374 done
# Row 51378 done
# Row 51376 done
# Row 51375 done
# Row 51377 done
# Row 51379 done
# Row 51380 done
# Row 51381 done
# Row 51382 done
# Row 51388 done
# Row 51384 done
# Row 51390 done
# Row 51389 done
# Row 51385 done
# Row 51383 done
# Row 51386 done
# Row 51387 done
# Row 51393 done
# Row 51392 done
# Row 51391 done
# Row 51394 done
# Row 51395 done
# Row 51396 done
# Row 51400 done
# Row 51398 done
# Row 51399 done
# Row 51401 done
# Row 51403 done
# Row 51402 done
# Row 51405 done
# Row 51404 done
# Row 51406 done
# Row 51397 done
# Row 51407 done
# Row 51408 done
# Row 51410 done
# Row 51409 done
# Row 51411 done
# Row 51412 done
# Row 51417 done
# Row 51413 done
# Row 51414 done
# Row 51418 done
# Row 51416 done
# Row 51419 done
# Row 51420 done
# Row 51415 done
# Row 51421 done
# Row 51422 done
# Row 51423 done
# Row 51424 done
# Row 51425 done
# Row 51426 done
# Row 51430 done
# Row 51429 done
# Row 51431 done
# Row 51428 done
# Row 51427 done
# Row 51432 done
# Row 51433 done
# Row 51435 done
# Row 51434 done
# Row 51436 done
# Row 51437 done
# Row 51438 done
# Row 51439 done
# Row 51440 done
# Row 51441 done
# Row 51442 done
# Row 51443 done
# Row 51445 done
# Row 51447 done
# Row 51444 done
# Row 51446 done
# Row 51449 done
# Row 51451 done
# Row 51448 done
# Row 51450 done
# Row 51452 done
# Row 51453 done
# Row 51455 done
# Row 51454 done
# Row 51457 done
# Row 51458 done
# Row 51460 done
# Row 51456 done
# Row 51464 done
# Row 51461 done
# Row 51463 done
# Row 51459 done
# Row 51462 done
# Row 51465 done
# Row 51467 done
# Row 51466 done
# Row 51468 done
# Row 51472 done
# Row 51470 done
# Row 51469 done
# Row 51476 done
# Row 51475 done
# Row 51471 done
# Row 51473 done
# Row 51479 done
# Row 51477 done
# Row 51478 done
# Row 51474 done
# Row 51480 done
# Row 51481 done
# Row 51482 done
# Row 51483 done
# Row 51484 done
# Row 51485 done
# Row 51487 done
# Row 51488 done
# Row 51486 done
# Row 51489 done
# Row 51491 done
# Row 51490 done
# Row 51492 done
# Row 51494 done
# Row 51493 done
# Row 51495 done
# Row 51496 done
# Row 51497 done
# Row 51505 done
# Row 51501 done
# Row 51504 done
# Row 51498 done
# Row 51503 done
# Row 51502 done
# Row 51499 done
# Row 51508 done
# Row 51500 done
# Row 51506 done
# Row 51507 done
# Row 51509 done
# Row 51510 done
# Row 51511 done
# Row 51515 done
# Row 51512 done
# Row 51514 done
# Row 51513 done
# Row 51518 done
# Row 51517 done
# Row 51516 done
# Row 51519 done
# Row 51520 done
# Row 51522 done
# Row 51521 done
# Row 51524 done
# Row 51523 done
# Row 51527 done
# Row 51525 done
# Row 51526 done
# Row 51531 done
# Row 51528 done
# Row 51529 done
# Row 51534 done
# Row 51530 done
# Row 51533 done
# Row 51532 done
# Row 51535 done
# Row 51536 done
# Row 51537 done
# Row 51538 done
# Row 51543 done
# Row 51540 done
# Row 51539 done
# Row 51547 done
# Row 51545 done
# Row 51544 done
# Row 51541 done
# Row 51546 done
# Row 51542 done
# Row 51550 done
# Row 51549 done
# Row 51548 done
# Row 51551 done
# Row 51554 done
# Row 51552 done
# Row 51559 done
# Row 51553 done
# Row 51555 done
# Row 51558 done
# Row 51556 done
# Row 51557 done
# Row 51561 done
# Row 51560 done
# Row 51562 done
# Row 51563 done
# Row 51564 done
# Row 51565 done
# Row 51566 done
# Row 51568 done
# Row 51567 done
# Row 51569 done
# Row 51570 done
# Row 51571 done
# Row 51575 done
# Row 51573 done
# Row 51574 done
# Row 51572 done
# Row 51576 done
# Row 51577 done
# Row 51578 done
# Row 51580 done
# Row 51579 done
# Row 51582 done
# Row 51583 done
# Row 51581 done
# Row 51586 done
# Row 51588 done
# Row 51585 done
# Row 51584 done
# Row 51587 done
# Row 51589 done
# Row 51590 done
# Row 51592 done
# Row 51591 done
# Row 51593 done
# Row 51594 done
# Row 51595 done
# Row 51597 done
# Row 51596 done
# Row 51601 done
# Row 51602 done
# Row 51600 done
# Row 51603 done
# Row 51599 done
# Row 51604 done
# Row 51598 done
# Row 51605 done
# Row 51606 done
# Row 51607 done
# Row 51609 done
# Row 51608 done
# Row 51612 done
# Row 51611 done
# Row 51610 done
# Row 51613 done
# Row 51614 done
# Row 51616 done
# Row 51619 done
# Row 51618 done
# Row 51620 done
# Row 51621 done
# Row 51617 done
# Row 51615 done
# Row 51624 done
# Row 51622 done
# Row 51626 done
# Row 51623 done
# Row 51625 done
# Row 51628 done
# Row 51627 done
# Row 51630 done
# Row 51629 done
# Row 51631 done
# Row 51632 done
# Row 51633 done
# Row 51638 done
# Row 51634 done
# Row 51635 done
# Row 51637 done
# Row 51636 done
# Row 51640 done
# Row 51639 done
# Row 51641 done
# Row 51643 done
# Row 51644 done
# Row 51642 done
# Row 51645 done
# Row 51647 done
# Row 51646 done
# Row 51649 done
# Row 51648 done
# Row 51650 done
# Row 51651 done
# Row 51652 done
# Row 51653 done
# Row 51656 done
# Row 51657 done
# Row 51654 done
# Row 51655 done
# Row 51658 done
# Row 51659 done
# Row 51661 done
# Row 51663 done
# Row 51662 done
# Row 51664 done
# Row 51660 done
# Row 51665 done
# Row 51666 done
# Row 51668 done
# Row 51669 done
# Row 51667 done
# Row 51671 done
# Row 51670 done
# Row 51672 done
# Row 51673 done
# Row 51676 done
# Row 51675 done
# Row 51674 done
# Row 51677 done
# Row 51679 done
# Row 51678 done
# Row 51680 done
# Row 51682 done
# Row 51681 done
# Row 51684 done
# Row 51685 done
# Row 51683 done
# Row 51686 done
# Row 51688 done
# Row 51687 done
# Row 51689 done
# Row 51690 done
# Row 51692 done
# Row 51691 done
# Row 51694 done
# Row 51693 done
# Row 51695 done
# Row 51696 done
# Row 51697 done
# Row 51701 done
# Row 51700 done
# Row 51699 done
# Row 51702 done
# Row 51698 done
# Row 51703 done
# Row 51706 done
# Row 51705 done
# Row 51707 done
# Row 51704 done
# Row 51708 done
# Row 51709 done
# Row 51710 done
# Row 51712 done
# Row 51713 done
# Row 51714 done
# Row 51711 done
# Row 51716 done
# Row 51715 done
# Row 51718 done
# Row 51720 done
# Row 51717 done
# Row 51719 done
# Row 51721 done
# Row 51722 done
# Row 51724 done
# Row 51723 done
# Row 51725 done
# Row 51727 done
# Row 51732 done
# Row 51726 done
# Row 51729 done
# Row 51730 done
# Row 51733 done
# Row 51731 done
# Row 51728 done
# Row 51735 done
# Row 51736 done
# Row 51734 done
# Row 51737 done
# Row 51739 done
# Row 51738 done
# Row 51741 done
# Row 51743 done
# Row 51740 done
# Row 51742 done
# Row 51745 done
# Row 51744 done
# Row 51746 done
# Row 51747 done
# Row 51749 done
# Row 51748 done
# Row 51750 done
# Row 51751 done
# Row 51752 done
# Row 51753 done
# Row 51754 done
# Row 51755 done
# Row 51756 done
# Row 51758 done
# Row 51760 done
# Row 51761 done
# Row 51757 done
# Row 51759 done
# Row 51762 done
# Row 51763 done
# Row 51765 done
# Row 51764 done
# Row 51766 done
# Row 51767 done
# Row 51768 done
# Row 51769 done
# Row 51773 done
# Row 51772 done
# Row 51770 done
# Row 51775 done
# Row 51774 done
# Row 51771 done
# Row 51776 done
# Row 51779 done
# Row 51778 done
# Row 51780 done
# Row 51777 done
# Row 51783 done
# Row 51781 done
# Row 51782 done
# Row 51786 done
# Row 51787 done
# Row 51785 done
# Row 51784 done
# Row 51788 done
# Row 51789 done
# Row 51792 done
# Row 51790 done
# Row 51794 done
# Row 51793 done
# Row 51791 done
# Row 51795 done
# Row 51796 done
# Row 51800 done
# Row 51798 done
# Row 51799 done
# Row 51797 done
# Row 51801 done
# Row 51802 done
# Row 51803 done
# Row 51805 done
# Row 51804 done
# Row 51807 done
# Row 51806 done
# Row 51808 done
# Row 51810 done
# Row 51809 done
# Row 51813 done
# Row 51811 done
# Row 51812 done
# Row 51814 done
# Row 51815 done
# Row 51816 done
# Row 51818 done
# Row 51817 done
# Row 51819 done
# Row 51820 done
# Row 51822 done
# Row 51821 done
# Row 51826 done
# Row 51827 done
# Row 51823 done
# Row 51825 done
# Row 51824 done
# Row 51828 done
# Row 51829 done
# Row 51831 done
# Row 51830 done
# Row 51833 done
# Row 51832 done
# Row 51835 done
# Row 51838 done
# Row 51834 done
# Row 51837 done
# Row 51839 done
# Row 51836 done
# Row 51841 done
# Row 51842 done
# Row 51840 done
# Row 51843 done
# Row 51846 done
# Row 51844 done
# Row 51845 done
# Row 51847 done
# Row 51848 done
# Row 51849 done
# Row 51850 done
# Row 51851 done
# Row 51853 done
# Row 51852 done
# Row 51854 done
# Row 51856 done
# Row 51855 done
# Row 51857 done
# Row 51859 done
# Row 51858 done
# Row 51863 done
# Row 51862 done
# Row 51861 done
# Row 51860 done
# Row 51865 done
# Row 51864 done
# Row 51866 done
# Row 51868 done
# Row 51867 done
# Row 51870 done
# Row 51869 done
# Row 51874 done
# Row 51873 done
# Row 51871 done
# Row 51875 done
# Row 51872 done
# Row 51876 done
# Row 51877 done
# Row 51878 done
# Row 51879 done
# Row 51880 done
# Row 51881 done
# Row 51883 done
# Row 51887 done
# Row 51884 done
# Row 51885 done
# Row 51886 done
# Row 51893 done
# Row 51888 done
# Row 51889 done
# Row 51892 done
# Row 51882 done
# Row 51890 done
# Row 51891 done
# Row 51894 done
# Row 51895 done
# Row 51896 done
# Row 51897 done
# Row 51898 done
# Row 51902 done
# Row 51901 done
# Row 51900 done
# Row 51899 done
# Row 51903 done
# Row 51905 done
# Row 51904 done
# Row 51906 done
# Row 51907 done
# Row 51908 done
# Row 51909 done
# Row 51910 done
# Row 51911 done
# Row 51916 done
# Row 51912 done
# Row 51914 done
# Row 51913 done
# Row 51917 done
# Row 51920 done
# Row 51919 done
# Row 51922 done
# Row 51921 done
# Row 51918 done
# Row 51915 done
# Row 51923 done
# Row 51924 done
# Row 51925 done
# Row 51927 done
# Row 51926 done
# Row 51928 done
# Row 51933 done
# Row 51930 done
# Row 51932 done
# Row 51934 done
# Row 51929 done
# Row 51931 done
# Row 51935 done
# Row 51939 done
# Row 51940 done
# Row 51936 done
# Row 51937 done
# Row 51938 done
# Row 51947 done
# Row 51941 done
# Row 51943 done
# Row 51942 done
# Row 51944 done
# Row 51946 done
# Row 51945 done
# Row 51948 done
# Row 51949 done
# Row 51951 done
# Row 51950 done
# Row 51952 done
# Row 51953 done
# Row 51955 done
# Row 51959 done
# Row 51958 done
# Row 51956 done
# Row 51954 done
# Row 51957 done
# Row 51961 done
# Row 51960 done
# Row 51963 done
# Row 51964 done
# Row 51962 done
# Row 51965 done
# Row 51967 done
# Row 51966 done
# Row 51969 done
# Row 51968 done
# Row 51970 done
# Row 51971 done
# Row 51974 done
# Row 51973 done
# Row 51975 done
# Row 51972 done
# Row 51976 done
# Row 51977 done
# Row 51978 done
# Row 51979 done
# Row 51981 done
# Row 51980 done
# Row 51982 done
# Row 51983 done
# Row 51984 done
# Row 51985 done
# Row 51986 done
# Row 51987 done
# Row 51988 done
# Row 51990 done
# Row 51989 done
# Row 51992 done
# Row 51991 done
# Row 51995 done
# Row 51994 done
# Row 51993 done
# Row 51996 done
# Row 51997 done
# Row 52002 done
# Row 52000 done
# Row 52001 done
# Row 51998 done
# Row 51999 done
# Row 52003 done
# Row 52004 done
# Row 52006 done
# Row 52007 done
# Row 52005 done
# Row 52008 done
# Row 52009 done
# Row 52010 done
# Row 52011 done
# Row 52018 done
# Row 52014 done
# Row 52016 done
# Row 52012 done
# Row 52013 done
# Row 52017 done
# Row 52015 done
# Row 52019 done
# Row 52021 done
# Row 52022 done
# Row 52020 done
# Row 52024 done
# Row 52025 done
# Row 52026 done
# Row 52030 done
# Row 52033 done
# Row 52028 done
# Row 52027 done
# Row 52023 done
# Row 52034 done
# Row 52031 done
# Row 52029 done
# Row 52032 done
# Row 52035 done
# Row 52037 done
# Row 52036 done
# Row 52038 done
# Row 52040 done
# Row 52039 done
# Row 52044 done
# Row 52041 done
# Row 52042 done
# Row 52046 done
# Row 52045 done
# Row 52043 done
# Row 52047 done
# Row 52048 done
# Row 52049 done
# Row 52050 done
# Row 52051 done
# Row 52052 done
# Row 52054 done
# Row 52053 done
# Row 52056 done
# Row 52057 done
# Row 52058 done
# Row 52060 done
# Row 52055 done
# Row 52059 done
# Row 52064 done
# Row 52063 done
# Row 52062 done
# Row 52061 done
# Row 52065 done
# Row 52066 done
# Row 52068 done
# Row 52067 done
# Row 52069 done
# Row 52070 done
# Row 52072 done
# Row 52071 done
# Row 52075 done
# Row 52073 done
# Row 52074 done
# Row 52076 done
# Row 52077 done
# Row 52078 done
# Row 52079 done
# Row 52080 done
# Row 52081 done
# Row 52082 done
# Row 52083 done
# Row 52084 done
# Row 52085 done
# Row 52087 done
# Row 52086 done
# Row 52088 done
# Row 52089 done
# Row 52092 done
# Row 52091 done
# Row 52094 done
# Row 52090 done
# Row 52093 done
# Row 52095 done
# Row 52097 done
# Row 52096 done
# Row 52099 done
# Row 52098 done
# Row 52104 done
# Row 52103 done
# Row 52101 done
# Row 52102 done
# Row 52100 done
# Row 52106 done
# Row 52107 done
# Row 52105 done
# Row 52109 done
# Row 52108 done
# Row 52110 done
# Row 52111 done
# Row 52112 done
# Row 52113 done
# Row 52114 done
# Row 52115 done
# Row 52120 done
# Row 52116 done
# Row 52118 done
# Row 52122 done
# Row 52121 done
# Row 52123 done
# Row 52119 done
# Row 52117 done
# Row 52125 done
# Row 52126 done
# Row 52124 done
# Row 52128 done
# Row 52133 done
# Row 52130 done
# Row 52127 done
# Row 52129 done
# Row 52135 done
# Row 52132 done
# Row 52131 done
# Row 52137 done
# Row 52134 done
# Row 52136 done
# Row 52138 done
# Row 52140 done
# Row 52139 done
# Row 52141 done
# Row 52142 done
# Row 52144 done
# Row 52145 done
# Row 52147 done
# Row 52143 done
# Row 52148 done
# Row 52151 done
# Row 52152 done
# Row 52150 done
# Row 52149 done
# Row 52153 done
# Row 52146 done
# Row 52154 done
# Row 52155 done
# Row 52157 done
# Row 52156 done
# Row 52158 done
# Row 52159 done
# Row 52160 done
# Row 52162 done
# Row 52163 done
# Row 52161 done
# Row 52164 done
# Row 52165 done
# Row 52166 done
# Row 52167 done
# Row 52168 done
# Row 52170 done
# Row 52171 done
# Row 52169 done
# Row 52174 done
# Row 52179 done
# Row 52178 done
# Row 52173 done
# Row 52176 done
# Row 52175 done
# Row 52177 done
# Row 52180 done
# Row 52172 done
# Row 52183 done
# Row 52182 done
# Row 52181 done
# Row 52184 done
# Row 52185 done
# Row 52187 done
# Row 52188 done
# Row 52186 done
# Row 52190 done
# Row 52189 done
# Row 52194 done
# Row 52191 done
# Row 52193 done
# Row 52192 done
# Row 52196 done
# Row 52197 done
# Row 52195 done
# Row 52198 done
# Row 52201 done
# Row 52199 done
# Row 52200 done
# Row 52204 done
# Row 52203 done
# Row 52206 done
# Row 52207 done
# Row 52202 done
# Row 52205 done
# Row 52208 done
# Row 52209 done
# Row 52210 done
# Row 52211 done
# Row 52212 done
# Row 52213 done
# Row 52215 done
# Row 52214 done
# Row 52216 done
# Row 52217 done
# Row 52218 done
# Row 52220 done
# Row 52222 done
# Row 52219 done
# Row 52221 done
# Row 52225 done
# Row 52224 done
# Row 52223 done
# Row 52226 done
# Row 52227 done
# Row 52228 done
# Row 52229 done
# Row 52231 done
# Row 52230 done
# Row 52232 done
# Row 52235 done
# Row 52234 done
# Row 52233 done
# Row 52236 done
# Row 52238 done
# Row 52237 done
# Row 52239 done
# Row 52240 done
# Row 52241 done
# Row 52242 done
# Row 52243 done
# Row 52245 done
# Row 52248 done
# Row 52247 done
# Row 52249 done
# Row 52246 done
# Row 52244 done
# Row 52250 done
# Row 52254 done
# Row 52255 done
# Row 52253 done
# Row 52252 done
# Row 52251 done
# Row 52257 done
# Row 52258 done
# Row 52261 done
# Row 52256 done
# Row 52259 done
# Row 52260 done
# Row 52262 done
# Row 52265 done
# Row 52267 done
# Row 52266 done
# Row 52264 done
# Row 52263 done
# Row 52268 done
# Row 52269 done
# Row 52273 done
# Row 52270 done
# Row 52272 done
# Row 52271 done
# Row 52274 done
# Row 52275 done
# Row 52276 done
# Row 52279 done
# Row 52280 done
# Row 52277 done
# Row 52278 done
# Row 52282 done
# Row 52281 done
# Row 52283 done
# Row 52285 done
# Row 52284 done
# Row 52286 done
# Row 52287 done
# Row 52290 done
# Row 52288 done
# Row 52289 done
# Row 52292 done
# Row 52291 done
# Row 52293 done
# Row 52295 done
# Row 52297 done
# Row 52298 done
# Row 52296 done
# Row 52294 done
# Row 52300 done
# Row 52299 done
# Row 52301 done
# Row 52303 done
# Row 52305 done
# Row 52302 done
# Row 52304 done
# Row 52308 done
# Row 52306 done
# Row 52310 done
# Row 52309 done
# Row 52311 done
# Row 52312 done
# Row 52307 done
# Row 52313 done
# Row 52314 done
# Row 52316 done
# Row 52315 done
# Row 52317 done
# Row 52320 done
# Row 52319 done
# Row 52326 done
# Row 52318 done
# Row 52322 done
# Row 52323 done
# Row 52325 done
# Row 52328 done
# Row 52321 done
# Row 52324 done
# Row 52327 done
# Row 52329 done
# Row 52330 done
# Row 52331 done
# Row 52334 done
# Row 52336 done
# Row 52341 done
# Row 52338 done
# Row 52332 done
# Row 52335 done
# Row 52333 done
# Row 52340 done
# Row 52339 done
# Row 52337 done
# Row 52342 done
# Row 52343 done
# Row 52346 done
# Row 52345 done
# Row 52349 done
# Row 52350 done
# Row 52347 done
# Row 52348 done
# Row 52354 done
# Row 52353 done
# Row 52351 done
# Row 52352 done
# Row 52344 done
# Row 52355 done
# Row 52356 done
# Row 52357 done
# Row 52359 done
# Row 52358 done
# Row 52360 done
# Row 52362 done
# Row 52361 done
# Row 52364 done
# Row 52365 done
# Row 52366 done
# Row 52363 done
# Row 52369 done
# Row 52367 done
# Row 52368 done
# Row 52370 done
# Row 52371 done
# Row 52373 done
# Row 52378 done
# Row 52380 done
# Row 52379 done
# Row 52377 done
# Row 52375 done
# Row 52376 done
# Row 52381 done
# Row 52372 done
# Row 52382 done
# Row 52374 done
# Row 52383 done
# Row 52384 done
# Row 52385 done
# Row 52391 done
# Row 52389 done
# Row 52387 done
# Row 52392 done
# Row 52390 done
# Row 52393 done
# Row 52386 done
# Row 52396 done
# Row 52394 done
# Row 52395 done
# Row 52388 done
# Row 52397 done
# Row 52398 done
# Row 52399 done
# Row 52400 done
# Row 52401 done
# Row 52404 done
# Row 52402 done
# Row 52403 done
# Row 52406 done
# Row 52405 done
# Row 52408 done
# Row 52409 done
# Row 52407 done
# Row 52410 done
# Row 52411 done
# Row 52412 done
# Row 52413 done
# Row 52419 done
# Row 52422 done
# Row 52415 done
# Row 52416 done
# Row 52417 done
# Row 52420 done
# Row 52421 done
# Row 52425 done
# Row 52418 done
# Row 52414 done
# Row 52423 done
# Row 52424 done
# Row 52426 done
# Row 52427 done
# Row 52428 done
# Row 52430 done
# Row 52431 done
# Row 52434 done
# Row 52437 done
# Row 52432 done
# Row 52436 done
# Row 52429 done
# Row 52433 done
# Row 52435 done
# Row 52439 done
# Row 52438 done
# Row 52440 done
# Row 52441 done
# Row 52443 done
# Row 52442 done
# Row 52445 done
# Row 52446 done
# Row 52444 done
# Row 52447 done
# Row 52448 done
# Row 52453 done
# Row 52450 done
# Row 52451 done
# Row 52449 done
# Row 52452 done
# Row 52454 done
# Row 52456 done
# Row 52455 done
# Row 52457 done
# Row 52458 done
# Row 52462 done
# Row 52461 done
# Row 52463 done
# Row 52460 done
# Row 52459 done
# Row 52464 done
# Row 52465 done
# Row 52466 done
# Row 52467 done
# Row 52468 done
# Row 52469 done
# Row 52470 done
# Row 52471 done
# Row 52473 done
# Row 52472 done
# Row 52474 done
# Row 52477 done
# Row 52480 done
# Row 52479 done
# Row 52475 done
# Row 52476 done
# Row 52481 done
# Row 52478 done
# Row 52482 done
# Row 52483 done
# Row 52484 done
# Row 52486 done
# Row 52485 done
# Row 52490 done
# Row 52487 done
# Row 52493 done
# Row 52489 done
# Row 52488 done
# Row 52494 done
# Row 52492 done
# Row 52491 done
# Row 52495 done
# Row 52496 done
# Row 52497 done
# Row 52498 done
# Row 52499 done
# Row 52501 done
# Row 52507 done
# Row 52502 done
# Row 52503 done
# Row 52504 done
# Row 52506 done
# Row 52500 done
# Row 52505 done
# Row 52508 done
# Row 52509 done
# Row 52510 done
# Row 52511 done
# Row 52512 done
# Row 52513 done
# Row 52514 done
# Row 52515 done
# Row 52516 done
# Row 52519 done
# Row 52518 done
# Row 52517 done
# Row 52521 done
# Row 52522 done
# Row 52520 done
# Row 52525 done
# Row 52524 done
# Row 52526 done
# Row 52523 done
# Row 52527 done
# Row 52528 done
# Row 52529 done
# Row 52530 done
# Row 52533 done
# Row 52532 done
# Row 52531 done
# Row 52534 done
# Row 52535 done
# Row 52538 done
# Row 52540 done
# Row 52537 done
# Row 52536 done
# Row 52539 done
# Row 52541 done
# Row 52542 done
# Row 52543 done
# Row 52544 done
# Row 52545 done
# Row 52546 done
# Row 52547 done
# Row 52548 done
# Row 52549 done
# Row 52550 done
# Row 52551 done
# Row 52553 done
# Row 52554 done
# Row 52555 done
# Row 52552 done
# Row 52558 done
# Row 52557 done
# Row 52556 done
# Row 52559 done
# Row 52560 done
# Row 52561 done
# Row 52563 done
# Row 52562 done
# Row 52564 done
# Row 52566 done
# Row 52570 done
# Row 52569 done
# Row 52568 done
# Row 52565 done
# Row 52567 done
# Row 52572 done
# Row 52573 done
# Row 52571 done
# Row 52574 done
# Row 52575 done
# Row 52576 done
# Row 52577 done
# Row 52579 done
# Row 52578 done
# Row 52584 done
# Row 52580 done
# Row 52582 done
# Row 52587 done
# Row 52585 done
# Row 52581 done
# Row 52589 done
# Row 52588 done
# Row 52586 done
# Row 52590 done
# Row 52591 done
# Row 52592 done
# Row 52593 done
# Row 52594 done
# Row 52595 done
# Row 52599 done
# Row 52597 done
# Row 52598 done
# Row 52596 done
# Row 52600 done
# Row 52601 done
# Row 52602 done
# Row 52603 done
# Row 52604 done
# Row 52605 done
# Row 52606 done
# Row 52607 done
# Row 52608 done
# Row 52613 done
# Row 52612 done
# Row 52610 done
# Row 52609 done
# Row 52583 done
# Row 52611 done
# Row 52615 done
# Row 52614 done
# Row 52616 done
# Row 52617 done
# Row 52618 done
# Row 52619 done
# Row 52620 done
# Row 52621 done
# Row 52622 done
# Row 52624 done
# Row 52625 done
# Row 52623 done
# Row 52627 done
# Row 52628 done
# Row 52629 done
# Row 52626 done
# Row 52630 done
# Row 52631 done
# Row 52632 done
# Row 52633 done
# Row 52634 done
# Row 52635 done
# Row 52636 done
# Row 52637 done
# Row 52647 done
# Row 52641 done
# Row 52638 done
# Row 52642 done
# Row 52646 done
# Row 52643 done
# Row 52645 done
# Row 52644 done
# Row 52640 done
# Row 52639 done
# Row 52648 done
# Row 52649 done
# Row 52653 done
# Row 52652 done
# Row 52651 done
# Row 52650 done
# Row 52655 done
# Row 52654 done
# Row 52657 done
# Row 52658 done
# Row 52656 done
# Row 52661 done
# Row 52660 done
# Row 52659 done
# Row 52662 done
# Row 52663 done
# Row 52664 done
# Row 52665 done
# Row 52667 done
# Row 52669 done
# Row 52666 done
# Row 52670 done
# Row 52668 done
# Row 52671 done
# Row 52674 done
# Row 52672 done
# Row 52676 done
# Row 52675 done
# Row 52673 done
# Row 52677 done
# Row 52678 done
# Row 52680 done
# Row 52679 done
# Row 52681 done
# Row 52682 done
# Row 52683 done
# Row 52684 done
# Row 52686 done
# Row 52688 done
# Row 52690 done
# Row 52685 done
# Row 52689 done
# Row 52687 done
# Row 52691 done
# Row 52693 done
# Row 52692 done
# Row 52694 done
# Row 52695 done
# Row 52700 done
# Row 52699 done
# Row 52701 done
# Row 52697 done
# Row 52696 done
# Row 52702 done
# Row 52698 done
# Row 52704 done
# Row 52703 done
# Row 52705 done
# Row 52706 done
# Row 52707 done
# Row 52708 done
# Row 52709 done
# Row 52710 done
# Row 52711 done
# Row 52713 done
# Row 52712 done
# Row 52715 done
# Row 52716 done
# Row 52717 done
# Row 52714 done
# Row 52719 done
# Row 52718 done
# Row 52720 done
# Row 52721 done
# Row 52722 done
# Row 52723 done
# Row 52724 done
# Row 52726 done
# Row 52725 done
# Row 52727 done
# Row 52728 done
# Row 52729 done
# Row 52730 done
# Row 52731 done
# Row 52734 done
# Row 52733 done
# Row 52732 done
# Row 52735 done
# Row 52738 done
# Row 52736 done
# Row 52737 done
# Row 52739 done
# Row 52740 done
# Row 52741 done
# Row 52743 done
# Row 52745 done
# Row 52742 done
# Row 52746 done
# Row 52747 done
# Row 52744 done
# Row 52748 done
# Row 52749 done
# Row 52750 done
# Row 52751 done
# Row 52752 done
# Row 52753 done
# Row 52754 done
# Row 52758 done
# Row 52755 done
# Row 52759 done
# Row 52757 done
# Row 52756 done
# Row 52763 done
# Row 52762 done
# Row 52760 done
# Row 52761 done
# Row 52764 done
# Row 52765 done
# Row 52766 done
# Row 52768 done
# Row 52770 done
# Row 52767 done
# Row 52769 done
# Row 52771 done
# Row 52772 done
# Row 52773 done
# Row 52775 done
# Row 52776 done
# Row 52774 done
# Row 52777 done
# Row 52778 done
# Row 52779 done
# Row 52780 done
# Row 52783 done
# Row 52782 done
# Row 52781 done
# Row 52786 done
# Row 52784 done
# Row 52785 done
# Row 52787 done
# Row 52790 done
# Row 52788 done
# Row 52789 done
# Row 52791 done
# Row 52793 done
# Row 52794 done
# Row 52792 done
# Row 52799 done
# Row 52795 done
# Row 52798 done
# Row 52797 done
# Row 52796 done
# Row 52804 done
# Row 52801 done
# Row 52805 done
# Row 52806 done
# Row 52800 done
# Row 52803 done
# Row 52802 done
# Row 52807 done
# Row 52809 done
# Row 52815 done
# Row 52811 done
# Row 52812 done
# Row 52810 done
# Row 52817 done
# Row 52818 done
# Row 52813 done
# Row 52816 done
# Row 52819 done
# Row 52808 done
# Row 52814 done
# Row 52820 done
# Row 52821 done
# Row 52822 done
# Row 52823 done
# Row 52824 done
# Row 52825 done
# Row 52827 done
# Row 52826 done
# Row 52828 done
# Row 52829 done
# Row 52831 done
# Row 52833 done
# Row 52832 done
# Row 52830 done
# Row 52834 done
# Row 52835 done
# Row 52836 done
# Row 52837 done
# Row 52839 done
# Row 52840 done
# Row 52838 done
# Row 52844 done
# Row 52842 done
# Row 52845 done
# Row 52841 done
# Row 52846 done
# Row 52843 done
# Row 52848 done
# Row 52847 done
# Row 52849 done
# Row 52852 done
# Row 52850 done
# Row 52851 done
# Row 52853 done
# Row 52854 done
# Row 52857 done
# Row 52855 done
# Row 52858 done
# Row 52856 done
# Row 52859 done
# Row 52860 done
# Row 52861 done
# Row 52862 done
# Row 52864 done
# Row 52863 done
# Row 52865 done
# Row 52866 done
# Row 52868 done
# Row 52869 done
# Row 52867 done
# Row 52871 done
# Row 52872 done
# Row 52873 done
# Row 52870 done
# Row 52875 done
# Row 52874 done
# Row 52876 done
# Row 52877 done
# Row 52878 done
# Row 52879 done
# Row 52880 done
# Row 52881 done
# Row 52885 done
# Row 52882 done
# Row 52886 done
# Row 52889 done
# Row 52883 done
# Row 52884 done
# Row 52890 done
# Row 52887 done
# Row 52891 done
# Row 52893 done
# Row 52892 done
# Row 52888 done
# Row 52895 done
# Row 52894 done
# Row 52898 done
# Row 52897 done
# Row 52896 done
# Row 52899 done
# Row 52900 done
# Row 52902 done
# Row 52905 done
# Row 52904 done
# Row 52906 done
# Row 52901 done
# Row 52907 done
# Row 52903 done
# Row 52908 done
# Row 52909 done
# Row 52910 done
# Row 52912 done
# Row 52911 done
# Row 52913 done
# Row 52914 done
# Row 52916 done
# Row 52919 done
# Row 52917 done
# Row 52915 done
# Row 52918 done
# Row 52921 done
# Row 52922 done
# Row 52923 done
# Row 52920 done
# Row 52924 done
# Row 52925 done
# Row 52928 done
# Row 52929 done
# Row 52927 done
# Row 52926 done
# Row 52930 done
# Row 52931 done
# Row 52936 done
# Row 52937 done
# Row 52935 done
# Row 52932 done
# Row 52933 done
# Row 52934 done
# Row 52938 done
# Row 52940 done
# Row 52939 done
# Row 52941 done
# Row 52943 done
# Row 52942 done
# Row 52946 done
# Row 52945 done
# Row 52947 done
# Row 52949 done
# Row 52948 done
# Row 52944 done
# Row 52950 done
# Row 52951 done
# Row 52953 done
# Row 52952 done
# Row 52954 done
# Row 52956 done
# Row 52960 done
# ...
# Row 53866 done
# Row 53865 done
# Row 53864 done
# Row 53869 done
# Row 53868 done
# Row 53861 done
# Row 53867 done
# Row 53871 done
# Row 53870 done
# Row 53872 done
# Row 53873 done
# Row 53878 done
# Row 53876 done
# Row 53885 done
# Row 53884 done
# Row 53875 done
# Row 53883 done
# Row 53881 done
# Row 53874 done
# Row 53882 done
# Row 53877 done
# Row 53879 done
# Row 53880 done
# Row 53887 done
# Row 53886 done
# Row 53891 done
# Row 53888 done
# Row 53893 done
# Row 53897 done
# Row 53890 done
# Row 53892 done
# Row 53895 done
# Row 53894 done
# Row 53889 done
# Row 53898 done
# Row 53896 done
# Row 53899 done
# Row 53900 done
# Row 53901 done
# Row 53902 done
# Row 53908 done
# Row 53906 done
# Row 53905 done
# Row 53910 done
# Row 53903 done
# Row 53907 done
# Row 53909 done
# Row 53904 done
# Row 53911 done
# Row 53912 done
# Row 53913 done
# Row 53914 done
# Row 53915 done
# Row 53916 done
# Row 53921 done
# Row 53917 done
# Row 53919 done
# Row 53922 done
# Row 53925 done
# Row 53918 done
# Row 53923 done
# Row 53920 done
# Row 53924 done
# Row 53926 done
# Row 53927 done
# Row 53928 done
# Row 53929 done
# Row 53930 done
# Row 53931 done
# Row 53933 done
# Row 53932 done
# Row 53937 done
# Row 53934 done
# Row 53935 done
# Row 53936 done
# Row 53938 done
# Row 53939 done
# Row 53940 done
# Row 53941 done
# Row 53942 done
# Row 53943 done
# Row 53946 done
# Row 53945 done
# Row 53944 done
# Row 53947 done
# Row 53954 done
# Row 53950 done
# Row 53952 done
# Row 53953 done
# Row 53949 done
# Row 53955 done
# Row 53948 done
# Row 53951 done
# Row 53956 done
# Row 53958 done
# Row 53963 done
# Row 53962 done
# Row 53960 done
# Row 53964 done
# Row 53957 done
# Row 53966 done
# Row 53961 done
# Row 53967 done
# Row 53959 done
# Row 53965 done
# Row 53968 done
# Row 53969 done
# Row 53972 done
# Row 53971 done
# Row 53973 done
# Row 53970 done
# Row 53976 done
# Row 53975 done
# Row 53974 done
# Row 53978 done
# Row 53977 done
# Row 53980 done
# Row 53981 done
# Row 53979 done
# Row 53982 done
# Row 53985 done
# Row 53983 done
# Row 53984 done
# Row 53991 done
# Row 53988 done
# Row 53993 done
# Row 53986 done
# Row 53992 done
# Row 53990 done
# Row 53989 done
# Row 53994 done
# Row 53987 done
# Row 53995 done
# Row 53996 done
# Row 53997 done
# Row 53998 done
# Row 54000 done
# Row 53999 done
# Row 54003 done
# Row 54001 done
# Row 54002 done
# Row 54005 done
# Row 54006 done
# Row 54009 done
# Row 54004 done
# Row 54007 done
# Row 54008 done
# Row 54010 done
# Row 54011 done
# Row 54012 done
# Row 54014 done
# Row 54016 done
# Row 54017 done
# Row 54015 done
# Row 54021 done
# Row 54019 done
# Row 54020 done
# Row 54018 done
# Row 54013 done
# Row 54022 done
# Row 54024 done
# Row 54023 done
# Row 54025 done
# Row 54026 done
# Row 54027 done
# Row 54029 done
# Row 54028 done
# Row 54030 done
# Row 54035 done
# Row 54031 done
# Row 54034 done
# Row 54032 done
# Row 54036 done
# Row 54033 done
# Row 54038 done
# Row 54037 done
# Row 54039 done
# Row 54040 done
# Row 54041 done
# Row 54042 done
# Row 54045 done
# Row 54050 done
# Row 54044 done
# Row 54051 done
# Row 54047 done
# Row 54046 done
# Row 54043 done
# Row 54048 done
# Row 54049 done
# Row 54052 done
# Row 54053 done
# Row 54054 done
# Row 54055 done
# Row 54056 done
# Row 54057 done
# Row 54061 done
# Row 54059 done
# Row 54058 done
# Row 54060 done
# Row 54062 done
# Row 54063 done
# Row 54064 done
# Row 54066 done
# Row 54065 done
# Row 54068 done
# Row 54067 done
# Row 54069 done
# Row 54070 done
# Row 54073 done
# Row 54072 done
# Row 54075 done
# Row 54071 done
# Row 54074 done
# Row 54076 done
# Row 54078 done
# Row 54080 done
# Row 54079 done
# Row 54077 done
# Row 54081 done
# Row 54082 done
# Row 54083 done
# Row 54084 done
# Row 54085 done
# Row 54086 done
# Row 54087 done
# Row 54089 done
# Row 54093 done
# Row 54094 done
# Row 54091 done
# Row 54092 done
# Row 54088 done
# Row 54090 done
# Row 54095 done
# Row 54100 done
# Row 54096 done
# Row 54097 done
# Row 54098 done
# Row 54099 done
# Row 54101 done
# Row 54102 done
# Row 54103 done
# Row 54104 done
# Row 54105 done
# Row 54106 done
# Row 54107 done
# Row 54112 done
# Row 54110 done
# Row 54111 done
# Row 54108 done
# Row 54109 done
# Row 54113 done
# Row 54116 done
# Row 54115 done
# Row 54117 done
# Row 54114 done
# Row 54119 done
# Row 54118 done
# Row 54120 done
# Row 54124 done
# Row 54123 done
# Row 54121 done
# Row 54122 done
# Row 54125 done
# Row 54128 done
# Row 54129 done
# Row 54127 done
# Row 54130 done
# Row 54131 done
# Row 54126 done
# Row 54132 done
# Row 54133 done
# Row 54134 done
# Row 54135 done
# Row 54137 done
# Row 54136 done
# Row 54138 done
# Row 54140 done
# Row 54139 done
# Row 54141 done
# Row 54143 done
# Row 54142 done
# Row 54145 done
# Row 54144 done
# Row 54147 done
# Row 54146 done
# Row 54149 done
# Row 54148 done
# Row 54150 done
# Row 54151 done
# Row 54153 done
# Row 54154 done
# Row 54152 done
# Row 54155 done
# Row 54157 done
# Row 54156 done
# Row 54158 done
# Row 54161 done
# Row 54159 done
# Row 54160 done
# Row 54162 done
# Row 54163 done
# Row 54164 done
# Row 54167 done
# Row 54166 done
# Row 54165 done
# Row 54168 done
# Row 54174 done
# Row 54170 done
# Row 54175 done
# Row 54169 done
# Row 54173 done
# Row 54171 done
# Row 54172 done
# Row 54176 done
# Row 54177 done
# Row 54178 done
# Row 54179 done
# Row 54180 done
# Row 54181 done
# Row 54184 done
# Row 54185 done
# Row 54182 done
# Row 54183 done
# Row 54186 done
# Row 54187 done
# Row 54188 done
# Row 54189 done
# Row 54190 done
# Row 54191 done
# Row 54192 done
# Row 54193 done
# Row 54194 done
# Row 54195 done
# Row 54199 done
# Row 54198 done
# Row 54202 done
# Row 54197 done
# Row 54196 done
# Row 54200 done
# Row 54201 done
# Row 54203 done
# Row 54204 done
# Row 54205 done
# Row 54206 done
# Row 54207 done
# Row 54208 done
# Row 54209 done
# Row 54210 done
# Row 54212 done
# Row 54211 done
# Row 54215 done
# Row 54214 done
# Row 54213 done
# Row 54216 done
# Row 54217 done
# Row 54218 done
# Row 54220 done
# Row 54219 done
# Row 54221 done
# Row 54222 done
# Row 54223 done
# Row 54224 done
# Row 54226 done
# Row 54225 done
# Row 54227 done
# Row 54228 done
# Row 54230 done
# Row 54229 done
# Row 54232 done
# Row 54233 done
# Row 54234 done
# Row 54231 done
# Row 54236 done
# Row 54235 done
# Row 54238 done
# Row 54237 done
# Row 54239 done
# Row 54240 done
# Row 54241 done
# Row 54242 done
# Row 54244 done
# Row 54243 done
# Row 54246 done
# Row 54245 done
# Row 54247 done
# Row 54248 done
# Row 54250 done
# Row 54249 done
# Row 54251 done
# Row 54252 done
# Row 54253 done
# Row 54254 done
# Row 54255 done
# Row 54256 done
# Row 54258 done
# Row 54257 done
# Row 54263 done
# Row 54261 done
# Row 54264 done
# Row 54262 done
# Row 54260 done
# Row 54259 done
# Row 54267 done
# Row 54266 done
# Row 54265 done
# Row 54268 done
# Row 54269 done
# Row 54270 done
# Row 54271 done
# Row 54274 done
# Row 54272 done
# Row 54275 done
# Row 54273 done
# Row 54276 done
# Row 54278 done
# Row 54277 done
# Row 54281 done
# Row 54282 done
# Row 54279 done
# Row 54280 done
# Row 54283 done
# Row 54284 done
# Row 54285 done
# Row 54286 done
# Row 54287 done
# Row 54288 done
# Row 54293 done
# Row 54292 done
# Row 54295 done
# Row 54296 done
# Row 54294 done
# Row 54290 done
# Row 54289 done
# Row 54291 done
# Row 54298 done
# Row 54297 done
# Row 54299 done
# Row 54301 done
# Row 54300 done
# Row 54302 done
# Row 54303 done
# Row 54304 done
# Row 54307 done
# Row 54308 done
# Row 54311 done
# Row 54305 done
# Row 54309 done
# Row 54306 done
# Row 54310 done
# Row 54312 done
# Row 54313 done
# Row 54314 done
# Row 54316 done
# Row 54315 done
# Row 54318 done
# Row 54322 done
# Row 54317 done
# Row 54323 done
# Row 54319 done
# Row 54325 done
# Row 54321 done
# Row 54324 done
# Row 54320 done
# Row 54326 done
# Row 54328 done
# Row 54327 done
# Row 54329 done
# Row 54330 done
# Row 54337 done
# Row 54334 done
# Row 54333 done
# Row 54336 done
# Row 54332 done
# Row 54335 done
# Row 54331 done
# Row 54338 done
# Row 54340 done
# Row 54339 done
# Row 54341 done
# Row 54342 done
# Row 54343 done
# Row 54344 done
# Row 54349 done
# Row 54348 done
# Row 54350 done
# Row 54346 done
# Row 54347 done
# Row 54345 done
# Row 54351 done
# Row 54352 done
# Row 54353 done
# Row 54354 done
# Row 54355 done
# Row 54356 done
# Row 54357 done
# Row 54360 done
# Row 54359 done
# Row 54358 done
# Row 54361 done
# Row 54362 done
# Row 54367 done
# Row 54366 done
# Row 54364 done
# Row 54363 done
# Row 54368 done
# Row 54365 done
# Row 54369 done
# Row 54370 done
# Row 54372 done
# Row 54371 done
# Row 54374 done
# Row 54373 done
# Row 54375 done
# Row 54381 done
# Row 54380 done
# Row 54379 done
# Row 54377 done
# Row 54376 done
# Row 54378 done
# Row 54382 done
# Row 54385 done
# Row 54384 done
# Row 54383 done
# Row 54386 done
# Row 54387 done
# Row 54391 done
# Row 54388 done
# Row 54390 done
# Row 54393 done
# Row 54389 done
# Row 54392 done
# Row 54394 done
# Row 54395 done
# Row 54397 done
# Row 54396 done
# Row 54398 done
# Row 54399 done
# Row 54400 done
# Row 54401 done
# Row 54402 done
# Row 54404 done
# Row 54403 done
# Row 54410 done
# Row 54405 done
# Row 54408 done
# Row 54409 done
# Row 54412 done
# Row 54407 done
# Row 54411 done
# Row 54406 done
# Row 54413 done
# Row 54414 done
# Row 54415 done
# Row 54416 done
# Row 54420 done
# Row 54418 done
# Row 54417 done
# Row 54424 done
# Row 54419 done
# Row 54422 done
# Row 54423 done
# Row 54425 done
# Row 54421 done
# Row 54426 done
# Row 54427 done
# Row 54428 done
# Row 54429 done
# Row 54430 done
# Row 54431 done
# Row 54433 done
# Row 54437 done
# Row 54436 done
# Row 54435 done
# Row 54440 done
# Row 54432 done
# Row 54439 done
# Row 54441 done
# Row 54434 done
# Row 54438 done
# Row 54442 done
# Row 54443 done
# Row 54444 done
# Row 54445 done
# Row 54448 done
# Row 54446 done
# Row 54447 done
# Row 54450 done
# Row 54449 done
# Row 54453 done
# Row 54452 done
# Row 54454 done
# Row 54451 done
# Row 54455 done
# Row 54457 done
# Row 54456 done
# Row 54458 done
# Row 54459 done
# Row 54460 done
# Row 54462 done
# Row 54461 done
# Row 54463 done
# Row 54466 done
# Row 54467 done
# Row 54464 done
# Row 54465 done
# Row 54468 done
# Row 54469 done
# Row 54470 done
# Row 54471 done
# Row 54472 done
# Row 54473 done
# Row 54474 done
# Row 54475 done
# Row 54477 done
# Row 54476 done
# Row 54478 done
# Row 54479 done
# Row 54481 done
# Row 54480 done
# Row 54485 done
# Row 54482 done
# Row 54483 done
# Row 54486 done
# Row 54484 done
# Row 54487 done
# Row 54489 done
# Row 54488 done
# Row 54493 done
# Row 54490 done
# Row 54492 done
# Row 54491 done
# Row 54494 done
# Row 54497 done
# Row 54496 done
# Row 54498 done
# Row 54495 done
# Row 54499 done
# Row 54500 done
# Row 54501 done
# Row 54503 done
# Row 54502 done
# Row 54504 done
# Row 54506 done
# Row 54505 done
# Row 54508 done
# Row 54507 done
# Row 54509 done
# Row 54510 done
# Row 54512 done
# Row 54511 done
# Row 54513 done
# Row 54514 done
# Row 54515 done
# Row 54516 done
# Row 54518 done
# Row 54517 done
# Row 54519 done
# Row 54520 done
# Row 54524 done
# Row 54522 done
# Row 54521 done
# Row 54526 done
# Row 54523 done
# Row 54525 done
# Row 54528 done
# Row 54527 done
# Row 54529 done
# Row 54530 done
# Row 54531 done
# Row 54532 done
# Row 54533 done
# Row 54534 done
# Row 54537 done
# Row 54535 done
# Row 54536 done
# Row 54538 done
# Row 54540 done
# Row 54539 done
# Row 54541 done
# Row 54542 done
# Row 54543 done
# Row 54544 done
# Row 54545 done
# Row 54546 done
# Row 54547 done
# Row 54551 done
# Row 54548 done
# Row 54553 done
# Row 54554 done
# Row 54552 done
# Row 54555 done
# Row 54549 done
# Row 54556 done
# Row 54557 done
# Row 54550 done
# Row 54559 done
# Row 54558 done
# Row 54561 done
# Row 54560 done
# Row 54562 done
# Row 54564 done
# Row 54563 done
# Row 54565 done
# Row 54569 done
# Row 54566 done
# Row 54571 done
# Row 54570 done
# Row 54568 done
# Row 54567 done
# Row 54574 done
# Row 54573 done
# Row 54572 done
# Row 54575 done
# Row 54576 done
# Row 54577 done
# Row 54578 done
# Row 54579 done
# Row 54580 done
# Row 54581 done
# Row 54583 done
# Row 54585 done
# Row 54588 done
# Row 54584 done
# Row 54590 done
# Row 54587 done
# Row 54589 done
# Row 54582 done
# Row 54586 done
# Row 54591 done
# Row 54593 done
# Row 54594 done
# Row 54592 done
# Row 54596 done
# Row 54595 done
# Row 54601 done
# Row 54597 done
# Row 54599 done
# Row 54600 done
# Row 54603 done
# Row 54598 done
# Row 54602 done
# Row 54606 done
# Row 54605 done
# Row 54604 done
# Row 54607 done
# Row 54608 done
# Row 54609 done
# Row 54610 done
# Row 54614 done
# Row 54613 done
# Row 54612 done
# Row 54611 done
# Row 54618 done
# Row 54616 done
# Row 54617 done
# Row 54615 done
# Row 54619 done
# Row 54620 done
# Row 54621 done
# Row 54622 done
# Row 54623 done
# Row 54624 done
# Row 54625 done
# Row 54626 done
# Row 54629 done
# Row 54630 done
# Row 54627 done
# Row 54633 done
# Row 54635 done
# Row 54628 done
# Row 54632 done
# Row 54634 done
# Row 54631 done
# Row 54636 done
# Row 54638 done
# Row 54637 done
# Row 54641 done
# Row 54648 done
# Row 54644 done
# Row 54640 done
# Row 54646 done
# Row 54647 done
# Row 54643 done
# Row 54649 done
# Row 54639 done
# Row 54645 done
# Row 54642 done
# Row 54650 done
# Row 54651 done
# Row 54653 done
# Row 54652 done
# Row 54655 done
# Row 54654 done
# Row 54656 done
# Row 54662 done
# Row 54657 done
# Row 54661 done
# Row 54660 done
# Row 54658 done
# Row 54659 done
# Row 54663 done
# Row 54664 done
# Row 54665 done
# Row 54666 done
# Row 54667 done
# Row 54668 done
# Row 54669 done
# Row 54670 done
# Row 54671 done
# Row 54674 done
# Row 54673 done
# Row 54672 done
# Row 54676 done
# Row 54675 done
# Row 54677 done
# Row 54678 done
# Row 54679 done
# Row 54680 done
# Row 54682 done
# Row 54681 done
# Row 54684 done
# Row 54683 done
# Row 54685 done
# Row 54686 done
# Row 54688 done
# Row 54687 done
# Row 54689 done
# Row 54690 done
# Row 54692 done
# Row 54691 done
# Row 54693 done
# Row 54694 done
# Row 54695 done
# Row 54696 done
# Row 54697 done
# Row 54698 done
# Row 54700 done
# Row 54704 done
# Row 54705 done
# Row 54699 done
# Row 54701 done
# Row 54702 done
# Row 54706 done
# Row 54703 done
# Row 54708 done
# Row 54707 done
# Row 54710 done
# Row 54709 done
# Row 54711 done
# Row 54715 done
# Row 54713 done
# Row 54712 done
# Row 54718 done
# Row 54720 done
# Row 54716 done
# Row 54719 done
# Row 54721 done
# Row 54714 done
# Row 54717 done
# Row 54723 done
# Row 54722 done
# Row 54724 done
# Row 54725 done
# Row 54727 done
# Row 54726 done
# Row 54728 done
# Row 54729 done
# Row 54734 done
# Row 54730 done
# Row 54733 done
# Row 54731 done
# Row 54732 done
# Row 54735 done
# Row 54736 done
# Row 54737 done
# Row 54738 done
# Row 54739 done
# Row 54740 done
# Row 54741 done
# Row 54743 done
# Row 54742 done
# Row 54745 done
# Row 54744 done
# Row 54747 done
# Row 54746 done
# Row 54750 done
# Row 54748 done
# Row 54749 done
# Row 54753 done
# Row 54752 done
# Row 54751 done
# Row 54754 done
# Row 54755 done
# Row 54756 done
# Row 54757 done
# Row 54758 done
#                     preprint_doi             published_doi_x accession_found  \
# 0                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 1                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 2                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 3                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# 4                 10.1101/001107       10.1101/gr.181016.114        GSE58871
# ...                          ...                         ...             ...
# 54754  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 54755  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 54756  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 54757  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
# 54758  10.1101/2020.12.30.424817  10.1186/s13059-021-02453-5       GSE163896
#
#                                                GSM_links  \
# 0      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4      https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# ...                                                  ...
# 54754  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 54755  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 54756  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 54757  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 54758  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                               SRX_links   SRR_dates
# 0       https://www.ncbi.nlm.nih.gov/sra?term=SRX631821  2014-09-23
# 1       https://www.ncbi.nlm.nih.gov/sra?term=SRX631822  2014-09-23
# 2       https://www.ncbi.nlm.nih.gov/sra?term=SRX631823  2014-09-23
# 3       https://www.ncbi.nlm.nih.gov/sra?term=SRX631824  2014-09-23
# 4       https://www.ncbi.nlm.nih.gov/sra?term=SRX631825  2014-09-23
# ...                                                 ...         ...
# 54754  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738885  2021-07-17
# 54755  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738886  2021-07-17
# 54756  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738887  2021-07-17
# 54757  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738888  2021-07-17
# 54758  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738889  2021-07-17
#
# [54759 rows x 6 columns]

# %%
df2.to_csv('/content/extracted_SRR_dates.csv')

# %% [markdown]
# # **Extract GSE ID public date**

# %% [markdown]
# ## Extract GSE ID public date for code-based found GSE IDs

# %% [markdown]
# ## The following GSE IDs do not associate with sequencing data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

def extract_GSE_dates(GSE_url):
    # Send an HTTP GET request to the URL
    response = requests.get(GSE_url)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Get the content of the response
        content = response.content
        # Create a BeautifulSoup object and specify the parser
        soup = BeautifulSoup(content, "html.parser")
        tr_elems = soup.find_all('tr')
        published_dates = []
        for tr_elem in tr_elems:
            if tr_elem.get('valign') == 'top' and 'Status' in tr_elem.text:
                td_elems = tr_elem.find_all('td')  # Find td elements within this tr element
                date_text = td_elems[1].text.strip()  # Get the text from the second td element
                GSE_dates = date_text

        published_dates = GSE_dates[10:22]
        return published_dates

def process_row(row):
    accession = row['accession_found']
    GSE_url = f'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc={accession}'
    return extract_GSE_dates(GSE_url)

# Read the DataFrame
df2 = pd.read_csv("/content/SRR_dates_equals_to_GSE_published_dates_new.csv")

# Prepare a dictionary to hold our results
results = {}

# Use ThreadPoolExecutor to parallelize the extraction
with ThreadPoolExecutor(max_workers=12) as executor:
    # Submit tasks to the executor
    future_to_row = {executor.submit(process_row, row): index for index, row in df2.iterrows()}

    # Collect the results as they are completed
    for future in as_completed(future_to_row):
        index = future_to_row[future]
        try:
            results[index] = future.result()
        except Exception as exc:
            print(f'Generated an exception: {exc}')
        else:
            print(f'Row {index} done')

    # Update the DataFrame with the results
for index, published_dates in results.items():
    df2.at[index, 'GSE_dates'] = published_dates
df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-61cdfe7903cd> in <cell line: 32>()
#      30
#      31 # Read the DataFrame
# ---> 32 df2 = pd.read_csv("/content/SRR_dates_equals_to_GSE_published_dates_new.csv")
#      33
#      34 # Prepare a dictionary to hold our results
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/SRR_dates_equals_to_GSE_published_dates_new.csv'

# %%
df2.to_csv("/content/extracted_gse_dates.csv")

# %% [markdown]
# ## The following GSE IDs associate with sequencing data(stored in accession ID begin with SRR)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

def extract_GSE_dates(GSE_url):
    # Send an HTTP GET request to the URL
    response = requests.get(GSE_url)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Get the content of the response
        content = response.content
        # Create a BeautifulSoup object and specify the parser
        soup = BeautifulSoup(content, "html.parser")
        tr_elems = soup.find_all('tr')
        published_dates = []
        for tr_elem in tr_elems:
            if tr_elem.get('valign') == 'top' and 'Status' in tr_elem.text:
                td_elems = tr_elem.find_all('td')  # Find td elements within this tr element
                date_text = td_elems[1].text.strip()  # Get the text from the second td element
                GSE_dates = date_text

        published_dates = GSE_dates[10:22]
        return published_dates

def process_row(row):
    accession = row['accession_found']
    GSE_url = f'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc={accession}'
    return extract_GSE_dates(GSE_url)

# Read the DataFrame
df3 = pd.read_csv("/content/extracted_SRR_dates_final.csv")

# Prepare a dictionary to hold our results
results = {}

# Use ThreadPoolExecutor to parallelize the extraction
with ThreadPoolExecutor(max_workers=12) as executor:
    # Submit tasks to the executor
    future_to_row = {executor.submit(process_row, row): index for index, row in df3.iterrows()}

    # Collect the results as they are completed
    for future in as_completed(future_to_row):
        index = future_to_row[future]
        try:
            results[index] = future.result()
        except Exception as exc:
            print(f'Generated an exception: {exc}')
        else:
            print(f'Row {index} done')

    # Update the DataFrame with the results
for index, published_dates in results.items():
    df3.at[index, 'GSE_dates'] = published_dates
df3
# Out:
# Row 3 done
# Row 2 done
# Row 4 done
# Row 9 done
# Row 10 done
# Row 7 done
# Row 0 done
# Row 5 done
# Row 8 done
# Row 6 done
# Row 1 done
# Row 11 done
# Row 12 done
# Row 13 done
# Row 14 done
# Row 22 done
# Row 15 done
# Row 21 done
# Row 19 done
# Row 16 done
# Row 25 done
# Row 23 done
# Row 18 done
# Row 20 done
# Row 24 done
# Row 17 done
# Row 27 done
# Row 26 done
# Row 28 done
# Row 30 done
# Row 31 done
# Row 32 done
# Row 29 done
# Row 36 done
# Row 35 done
# Row 33 done
# Row 37 done
# Row 39 done
# Row 40 done
# Row 34 done
# Row 41 done
# Row 42 done
# Row 43 done
# Row 44 done
# Row 47 done
# Row 48 done
# Row 46 done
# Row 38 done
# Row 45 done
# Row 52 done
# Row 54 done
# Row 51 done
# Row 50 done
# Row 49 done
# Row 59 done
# Row 56 done
# Row 55 done
# Row 57 done
# Row 63 done
# Row 61 done
# Row 65 done
# Row 64 done
# Row 62 done
# Row 66 done
# Row 60 done
# Row 67 done
# Row 68 done
# Row 69 done
# Row 71 done
# Row 72 done
# Row 73 done
# Row 53 done
# Row 70 done
# Row 75 done
# Row 79 done
# Row 58 done
# Row 76 done
# Row 77 done
# Row 80 done
# Row 74 done
# Row 78 done
# Row 81 done
# Row 83 done
# Row 86 done
# Row 82 done
# Row 84 done
# Row 87 done
# Row 93 done
# Row 94 done
# Row 85 done
# Row 89 done
# Row 92 done
# Row 96 done
# Row 88 done
# Row 97 done
# Row 95 done
# Row 90 done
# Row 91 done
# Row 99 done
# Row 98 done
# Row 101 done
# Row 100 done
# Row 103 done
# Row 102 done
# Row 104 done
# Row 105 done
# Row 108 done
# Row 111 done
# Row 110 done
# Row 106 done
# Row 107 done
# Row 109 done
# Row 113 done
# Row 116 done
# Row 115 done
# Row 112 done
# Row 117 done
# Row 114 done
# Row 118 done
# Row 119 done
# Row 121 done
# Row 123 done
# Row 120 done
# Row 122 done
# Row 126 done
# Row 129 done
# Row 130 done
# Row 127 done
# Row 125 done
# Row 128 done
# Row 124 done
# Row 132 done
# Row 131 done
# Row 133 done
# Row 138 done
# Row 136 done
# Row 140 done
# Row 142 done
# Row 134 done
# Row 135 done
# Row 137 done
# Row 139 done
# Row 143 done
# Row 144 done
# Row 145 done
# Row 147 done
# Row 150 done
# Row 148 done
# Row 146 done
# Row 151 done
# Row 152 done
# Row 149 done
# Row 153 done
# Row 157 done
# Row 155 done
# Row 156 done
# Row 141 done
# Row 154 done
# Row 162 done
# Row 161 done
# Row 160 done
# Row 158 done
# Row 159 done
# Row 163 done
# Row 165 done
# Row 168 done
# Row 167 done
# Row 166 done
# Row 170 done
# Row 164 done
# Row 171 done
# Row 174 done
# Row 175 done
# Row 172 done
# Row 179 done
# Row 173 done
# Row 177 done
# Row 178 done
# Row 176 done
# Row 169 done
# Row 181 done
# Row 182 done
# Row 180 done
# Row 183 done
# Row 185 done
# Row 188 done
# Row 189 done
# Row 184 done
# Row 187 done
# Row 186 done
# Row 190 done
# Row 194 done
# Row 193 done
# Row 192 done
# Row 191 done
# Row 197 done
# Row 195 done
# Row 196 done
# Row 201 done
# Row 199 done
# Row 198 done
# Row 200 done
# Row 204 done
# Row 202 done
# Row 203 done
# Row 205 done
# Row 207 done
# Row 206 done
# Row 209 done
# Row 208 done
# Row 211 done
# Row 214 done
# Row 215 done
# Row 213 done
# Row 212 done
# Row 216 done
# Row 210 done
# Row 218 done
# Row 217 done
# Row 219 done
# Row 221 done
# Row 220 done
# Row 222 done
# Row 225 done
# Row 227 done
# Row 230 done
# Row 228 done
# Row 224 done
# Row 231 done
# Row 229 done
# Row 226 done
# Row 232 done
# Row 223 done
# Row 236 done
# Row 235 done
# Row 233 done
# Row 234 done
# Row 237 done
# Row 238 done
# Row 240 done
# Row 242 done
# Row 241 done
# Row 248 done
# Row 246 done
# Row 250 done
# Row 245 done
# Row 249 done
# Row 243 done
# Row 247 done
# Row 239 done
# Row 244 done
# Row 251 done
# Row 253 done
# Row 252 done
# Row 255 done
# Row 254 done
# Row 257 done
# Row 256 done
# Row 263 done
# Row 264 done
# Row 266 done
# Row 265 done
# Row 259 done
# Row 261 done
# Row 267 done
# Row 260 done
# Row 262 done
# Row 268 done
# Row 258 done
# Row 269 done
# Row 271 done
# Row 272 done
# Row 270 done
# Row 274 done
# Row 273 done
# Row 275 done
# Row 279 done
# Row 277 done
# Row 276 done
# Row 280 done
# Row 278 done
# Row 282 done
# Row 281 done
# Row 283 done
# Row 284 done
# Row 286 done
# Row 285 done
# Row 287 done
# Row 290 done
# Row 289 done
# Row 291 done
# Row 288 done
# Row 292 done
# Row 293 done
# Row 294 done
# Row 295 done
# Row 296 done
# Row 298 done
# Row 299 done
# Row 300 done
# Row 297 done
# Row 301 done
# Row 304 done
# Row 306 done
# Row 302 done
# Row 307 done
# Row 309 done
# Row 308 done
# Row 305 done
# Row 303 done
# Row 310 done
# Row 316 done
# Row 314 done
# Row 315 done
# Row 311 done
# Row 320 done
# Row 322 done
# Row 319 done
# Row 313 done
# Row 323 done
# Row 318 done
# Row 325 done
# Row 317 done
# Row 321 done
# Row 312 done
# Row 324 done
# Row 326 done
# Row 328 done
# Row 330 done
# Row 327 done
# Row 332 done
# Row 331 done
# Row 335 done
# Row 329 done
# Row 333 done
# Row 334 done
# Row 337 done
# Row 339 done
# Row 342 done
# Row 336 done
# Row 340 done
# Row 343 done
# Row 344 done
# Row 341 done
# Row 347 done
# Row 346 done
# Row 349 done
# Row 345 done
# Row 348 done
# Row 354 done
# Row 353 done
# Row 351 done
# Row 352 done
# Row 350 done
# Row 357 done
# Row 355 done
# Row 358 done
# Row 338 done
# Row 356 done
# Row 361 done
# Row 359 done
# Row 360 done
# Row 362 done
# Row 363 done
# Row 364 done
# Row 366 done
# Row 365 done
# Row 371 done
# Row 373 done
# Row 369 done
# Row 370 done
# Row 367 done
# Row 368 done
# Row 377 done
# Row 375 done
# Row 378 done
# Row 374 done
# Row 376 done
# Row 379 done
# Row 372 done
# Row 381 done
# Row 380 done
# Row 388 done
# Row 384 done
# Row 386 done
# Row 383 done
# Row 391 done
# Row 387 done
# Row 382 done
# Row 390 done
# Row 392 done
# Row 393 done
# Row 389 done
# Row 394 done
# Row 395 done
# Row 396 done
# Row 400 done
# Row 404 done
# Row 398 done
# Row 407 done
# Row 401 done
# Row 403 done
# Row 399 done
# Row 402 done
# Row 406 done
# Row 408 done
# Row 397 done
# Row 410 done
# Row 385 done
# Row 405 done
# Row 412 done
# Row 409 done
# Row 413 done
# Row 411 done
# Row 417 done
# Row 420 done
# Row 421 done
# Row 422 done
# Row 416 done
# Row 423 done
# Row 424 done
# Row 419 done
# Row 426 done
# Row 415 done
# Row 425 done
# Row 428 done
# Row 427 done
# Row 431 done
# Row 429 done
# Row 432 done
# Row 430 done
# Row 433 done
# Row 434 done
# Row 436 done
# Row 437 done
# Row 446 done
# Row 443 done
# Row 440 done
# Row 438 done
# Row 442 done
# Row 444 done
# Row 445 done
# Row 435 done
# Row 447 done
# Row 439 done
# Row 448 done
# Row 441 done
# Row 451 done
# Row 452 done
# Row 456 done
# Row 449 done
# Row 454 done
# Row 460 done
# Row 453 done
# Row 459 done
# Row 457 done
# Row 455 done
# Row 450 done
# Row 461 done
# Row 458 done
# Row 462 done
# Row 465 done
# Row 463 done
# Row 464 done
# Row 470 done
# Row 469 done
# Row 473 done
# Row 471 done
# Row 468 done
# Row 474 done
# Row 466 done
# Row 475 done
# Row 476 done
# Row 467 done
# Row 480 done
# Row 477 done
# Row 472 done
# Row 482 done
# Row 479 done
# Row 481 done
# Row 485 done
# Row 484 done
# Row 483 done
# Row 486 done
# Row 488 done
# Row 478 done
# Row 492 done
# Row 494 done
# Row 489 done
# Row 491 done
# Row 495 done
# Row 493 done
# Row 497 done
# Row 487 done
# Row 499 done
# Row 496 done
# Row 490 done
# Row 498 done
# Row 502 done
# Row 501 done
# Row 500 done
# Row 503 done
# Row 505 done
# Row 504 done
# Row 507 done
# Row 510 done
# Row 506 done
# Row 508 done
# Row 509 done
# Row 511 done
# Row 512 done
# Row 513 done
# Row 515 done
# Row 516 done
# Row 514 done
# Row 523 done
# Row 517 done
# Row 521 done
# Row 518 done
# Row 519 done
# Row 526 done
# Row 525 done
# Row 520 done
# Row 524 done
# Row 522 done
# Row 527 done
# Row 528 done
# Row 530 done
# Row 532 done
# Row 529 done
# Row 533 done
# Row 531 done
# Row 537 done
# Row 540 done
# Row 535 done
# Row 536 done
# Row 539 done
# Row 541 done
# Row 542 done
# Row 534 done
# Row 546 done
# Row 538 done
# Row 543 done
# Row 544 done
# Row 547 done
# Row 548 done
# Row 549 done
# Row 550 done
# Row 545 done
# Row 551 done
# Row 553 done
# Row 552 done
# Row 555 done
# Row 556 done
# Row 560 done
# Row 554 done
# Row 557 done
# Row 559 done
# Row 562 done
# Row 561 done
# Row 558 done
# Row 567 done
# Row 564 done
# Row 568 done
# Row 566 done
# Row 565 done
# Row 563 done
# Row 574 done
# Row 573 done
# Row 571 done
# Row 570 done
# Row 569 done
# Row 579 done
# Row 576 done
# Row 578 done
# Row 572 done
# Row 577 done
# Row 575 done
# Row 582 done
# Row 583 done
# Row 581 done
# Row 584 done
# Row 580 done
# Row 588 done
# Row 587 done
# Row 592 done
# Row 591 done
# Row 585 done
# Row 586 done
# Row 590 done
# Row 589 done
# Row 596 done
# Row 594 done
# Row 593 done
# Row 595 done
# Row 597 done
# Row 598 done
# Row 601 done
# Row 600 done
# Row 603 done
# Row 604 done
# Row 599 done
# Row 607 done
# Row 602 done
# Row 608 done
# Row 605 done
# Row 610 done
# Row 609 done
# Row 606 done
# Row 612 done
# Row 611 done
# Row 613 done
# Row 614 done
# Row 615 done
# Row 617 done
# Row 618 done
# Row 620 done
# Row 616 done
# Row 622 done
# Row 621 done
# Row 619 done
# Row 624 done
# Row 626 done
# Row 623 done
# Row 627 done
# Row 625 done
# Row 631 done
# Row 629 done
# Row 630 done
# Row 633 done
# Row 632 done
# Row 636 done
# Row 634 done
# Row 639 done
# Row 628 done
# Row 637 done
# Row 638 done
# Row 635 done
# Row 640 done
# Row 641 done
# Row 643 done
# Row 642 done
# Row 646 done
# Row 644 done
# Row 645 done
# Row 647 done
# Row 653 done
# Row 651 done
# Row 648 done
# Row 650 done
# Row 649 done
# Row 655 done
# Row 654 done
# Row 656 done
# Row 658 done
# Row 659 done
# Row 661 done
# Row 665 done
# Row 664 done
# Row 663 done
# Row 667 done
# Row 668 done
# Row 660 done
# Row 657 done
# Row 670 done
# Row 662 done
# Row 669 done
# Row 666 done
# Row 652 done
# Row 672 done
# Row 673 done
# Row 675 done
# Row 676 done
# Row 677 done
# Row 671 done
# Row 681 done
# Row 680 done
# Row 678 done
# Row 682 done
# Row 679 done
# Row 683 done
# Row 685 done
# Row 686 done
# Row 688 done
# Row 687 done
# Row 684 done
# Row 689 done
# Row 690 done
# Row 693 done
# Row 694 done
# Row 692 done
# Row 695 done
# Row 697 done
# Row 699 done
# Row 698 done
# Row 700 done
# Row 703 done
# Row 705 done
# Row 708 done
# Row 706 done
# Row 707 done
# Row 702 done
# Row 710 done
# Row 711 done
# Row 712 done
# Row 674 done
# Row 714 done
# Row 715 done
# Row 713 done
# Row 717 done
# Row 716 done
# Row 691 done
# Row 719 done
# Row 718 done
# Row 722 done
# Row 721 done
# Row 696 done
# Row 723 done
# Row 701 done
# Row 724 done
# Row 704 done
# Row 726 done
# Row 725 done
# Row 728 done
# Row 727 done
# Row 709 done
# Row 730 done
# Row 731 done
# Row 732 done
# Row 729 done
# Row 720 done
# Row 734 done
# Row 736 done
# Row 738 done
# Row 733 done
# Row 735 done
# Row 739 done
# Row 742 done
# Row 737 done
# Row 741 done
# Row 740 done
# Row 744 done
# Row 746 done
# Row 747 done
# Row 748 done
# Row 745 done
# Row 749 done
# Row 743 done
# Row 753 done
# Row 752 done
# Row 754 done
# Row 751 done
# Row 750 done
# Row 758 done
# Row 757 done
# Row 759 done
# Row 755 done
# Row 760 done
# Row 761 done
# Row 765 done
# Row 764 done
# Row 763 done
# Row 766 done
# Row 762 done
# Row 767 done
# Row 756 done
# Row 769 done
# Row 768 done
# Row 771 done
# Row 773 done
# Row 775 done
# Row 772 done
# Row 770 done
# Row 776 done
# Row 774 done
# Row 778 done
# Row 780 done
# Row 782 done
# Row 777 done
# Row 779 done
# Row 783 done
# Row 786 done
# Row 787 done
# Row 785 done
# Row 788 done
# Row 789 done
# Row 784 done
# Row 781 done
# Row 791 done
# Row 790 done
# Row 794 done
# Row 793 done
# Row 795 done
# Row 792 done
# Row 796 done
# Row 799 done
# Row 797 done
# Row 800 done
# Row 801 done
# Row 798 done
# Row 804 done
# Row 808 done
# Row 803 done
# Row 806 done
# Row 802 done
# Row 807 done
# Row 805 done
# Row 809 done
# Row 810 done
# Row 812 done
# Row 811 done
# Row 814 done
# Row 813 done
# Row 818 done
# Row 819 done
# Row 815 done
# Row 817 done
# Row 820 done
# Row 816 done
# Row 821 done
# Row 822 done
# Row 826 done
# Row 825 done
# Row 823 done
# Row 831 done
# Row 830 done
# Row 829 done
# Row 827 done
# Row 832 done
# Row 824 done
# Row 828 done
# Row 834 done
# Row 836 done
# Row 838 done
# Row 833 done
# Row 835 done
# Row 839 done
# Row 842 done
# Row 841 done
# Row 837 done
# Row 843 done
# Row 844 done
# Row 840 done
# Row 845 done
# Row 847 done
# Row 848 done
# Row 851 done
# Row 852 done
# Row 849 done
# Row 854 done
# Row 853 done
# Row 850 done
# Row 846 done
# Row 856 done
# Row 859 done
# Row 857 done
# Row 858 done
# Row 862 done
# Row 855 done
# Row 860 done
# Row 867 done
# Row 863 done
# Row 866 done
# Row 865 done
# Row 868 done
# Row 861 done
# Row 864 done
# Row 869 done
# Row 871 done
# Row 872 done
# Row 873 done
# Row 875 done
# Row 874 done
# Row 876 done
# Row 880 done
# Row 877 done
# Row 882 done
# Row 881 done
# Row 870 done
# Row 883 done
# Row 878 done
# Row 879 done
# Row 885 done
# Row 884 done
# Row 887 done
# Row 886 done
# Row 888 done
# Row 889 done
# Row 890 done
# Row 892 done
# Row 893 done
# Row 896 done
# Row 894 done
# Row 898 done
# Row 899 done
# Row 895 done
# Row 897 done
# Row 891 done
# Row 900 done
# Row 901 done
# Row 903 done
# Row 905 done
# Row 906 done
# Row 902 done
# Row 904 done
# Row 907 done
# Row 913 done
# Row 911 done
# Row 909 done
# Row 910 done
# Row 912 done
# Row 914 done
# Row 908 done
# Row 918 done
# Row 916 done
# Row 915 done
# Row 917 done
# Row 920 done
# Row 923 done
# Row 921 done
# Row 926 done
# Row 922 done
# Row 924 done
# Row 929 done
# Row 930 done
# Row 928 done
# Row 919 done
# Row 925 done
# Row 927 done
# Row 933 done
# Row 931 done
# Row 934 done
# Row 932 done
# Row 936 done
# Row 935 done
# Row 939 done
# Row 938 done
# Row 942 done
# Row 941 done
# Row 940 done
# Row 937 done
# Row 943 done
# Row 946 done
# Row 948 done
# Row 945 done
# Row 944 done
# Row 947 done
# Row 949 done
# Row 950 done
# Row 953 done
# Row 954 done
# Row 956 done
# Row 952 done
# Row 951 done
# Row 957 done
# Row 959 done
# Row 955 done
# Row 958 done
# Row 961 done
# Row 962 done
# Row 963 done
# Row 960 done
# Row 965 done
# Row 964 done
# Row 966 done
# Row 967 done
# Row 969 done
# Row 968 done
# Row 970 done
# Row 971 done
# Row 975 done
# Row 974 done
# Row 972 done
# Row 973 done
# Row 976 done
# Row 979 done
# Row 978 done
# Row 977 done
# Row 981 done
# Row 980 done
# Row 983 done
# Row 987 done
# Row 984 done
# Row 985 done
# Row 990 done
# Row 993 done
# Row 988 done
# Row 986 done
# Row 992 done
# Row 982 done
# Row 991 done
# Row 996 done
# Row 995 done
# Row 989 done
# Row 997 done
# Row 994 done
# Row 1003 done
# Row 1001 done
# Row 1000 done
# Row 999 done
# Row 1004 done
# Row 1009 done
# Row 998 done
# Row 1005 done
# Row 1002 done
# Row 1010 done
# Row 1007 done
# Row 1006 done
# Row 1012 done
# Row 1008 done
# Row 1011 done
# Row 1013 done
# Row 1015 done
# Row 1014 done
# Row 1018 done
# Row 1017 done
# Row 1016 done
# Row 1021 done
# Row 1023 done
# Row 1020 done
# Row 1025 done
# Row 1019 done
# Row 1028 done
# Row 1022 done
# Row 1030 done
# Row 1024 done
# Row 1026 done
# Row 1029 done
# Row 1027 done
# Row 1031 done
# Row 1033 done
# Row 1036 done
# Row 1032 done
# Row 1035 done
# Row 1037 done
# Row 1039 done
# Row 1042 done
# Row 1034 done
# Row 1041 done
# Row 1038 done
# Row 1040 done
# Row 1045 done
# Row 1043 done
# Row 1047 done
# Row 1044 done
# Row 1052 done
# Row 1050 done
# Row 1054 done
# Row 1051 done
# Row 1048 done
# Row 1049 done
# Row 1053 done
# Row 1046 done
# Row 1056 done
# Row 1058 done
# Row 1055 done
# Row 1057 done
# Row 1061 done
# Row 1060 done
# Row 1064 done
# Row 1063 done
# Row 1059 done
# Row 1065 done
# Row 1062 done
# Row 1070 done
# Row 1067 done
# Row 1068 done
# Row 1069 done
# Row 1066 done
# Row 1071 done
# Row 1078 done
# Row 1080 done
# Row 1072 done
# Row 1082 done
# Row 1081 done
# Row 1075 done
# Row 1079 done
# Row 1076 done
# Row 1073 done
# Row 1083 done
# Row 1084 done
# Row 1074 done
# Row 1086 done
# Row 1077 done
# Row 1085 done
# Row 1087 done
# Row 1088 done
# Row 1090 done
# Row 1089 done
# Row 1091 done
# Row 1097 done
# Row 1092 done
# Row 1093 done
# Row 1096 done
# Row 1098 done
# Row 1102 done
# Row 1101 done
# Row 1094 done
# Row 1099 done
# Row 1095 done
# Row 1103 done
# Row 1106 done
# Row 1105 done
# Row 1104 done
# Row 1100 done
# Row 1107 done
# Row 1109 done
# Row 1108 done
# Row 1112 done
# Row 1110 done
# Row 1113 done
# Row 1111 done
# Row 1114 done
# Row 1115 done
# Row 1116 done
# Row 1119 done
# Row 1117 done
# Row 1118 done
# Row 1120 done
# Row 1122 done
# Row 1124 done
# Row 1123 done
# Row 1127 done
# Row 1126 done
# Row 1121 done
# Row 1125 done
# Row 1131 done
# Row 1133 done
# Row 1128 done
# Row 1130 done
# Row 1132 done
# Row 1129 done
# Row 1134 done
# Row 1135 done
# Row 1136 done
# Row 1137 done
# Row 1138 done
# Row 1139 done
# Row 1140 done
# Row 1142 done
# Row 1145 done
# Row 1143 done
# Row 1146 done
# Row 1144 done
# Row 1141 done
# Row 1150 done
# Row 1148 done
# Row 1149 done
# Row 1152 done
# Row 1151 done
# Row 1147 done
# Row 1153 done
# Row 1155 done
# Row 1154 done
# Row 1157 done
# Row 1159 done
# Row 1158 done
# Row 1156 done
# Row 1160 done
# Row 1161 done
# Row 1162 done
# Row 1163 done
# Row 1165 done
# Row 1168 done
# Row 1167 done
# Row 1164 done
# Row 1171 done
# Row 1166 done
# Row 1169 done
# Row 1174 done
# Row 1170 done
# Row 1175 done
# Row 1172 done
# Row 1173 done
# Row 1177 done
# Row 1179 done
# Row 1181 done
# Row 1178 done
# Row 1182 done
# Row 1184 done
# Row 1186 done
# Row 1176 done
# Row 1180 done
# Row 1188 done
# Row 1187 done
# Row 1191 done
# Row 1185 done
# Row 1192 done
# Row 1183 done
# Row 1189 done
# Row 1190 done
# Row 1194 done
# Row 1195 done
# Row 1193 done
# Row 1197 done
# Row 1196 done
# Row 1199 done
# Row 1198 done
# Row 1203 done
# Row 1207 done
# Row 1206 done
# Row 1205 done
# Row 1200 done
# Row 1201 done
# Row 1204 done
# Row 1202 done
# Row 1211 done
# Row 1212 done
# Row 1210 done
# Row 1209 done
# Row 1208 done
# Row 1213 done
# Row 1214 done
# Row 1216 done
# Row 1215 done
# Row 1221 done
# Row 1222 done
# Row 1224 done
# Row 1223 done
# Row 1220 done
# Row 1228 done
# Row 1227 done
# Row 1219 done
# Row 1217 done
# Row 1218 done
# Row 1226 done
# Row 1230 done
# Row 1231 done
# Row 1232 done
# Row 1225 done
# Row 1233 done
# Row 1229 done
#                    preprint_doi               published_doi_x accession_found  \
# 0                10.1101/001107         10.1101/gr.181016.114        GSE58871
# 1                10.1101/006171  10.1371/journal.pgen.1004663        GSE57483
# 2                10.1101/006270           10.7554/eLife.03915        GSE58423
# 3                10.1101/008136  10.1371/journal.pgen.1005118        GSE57608
# 4                10.1101/012757         10.1534/g3.115.019497        GSE63488
# ...                         ...                           ...             ...
# 1229  10.1101/2020.12.28.424586    10.1172/jci.insight.147280       GSE163649
# 1230  10.1101/2020.12.29.424680     10.3389/fnins.2021.671249       GSE160992
# 1231  10.1101/2020.12.30.424365           10.7554/eLife.70514       GSE163775
# 1232  10.1101/2020.12.30.424776        10.15252/msb.202110207       GSE158319
# 1233  10.1101/2020.12.30.424817    10.1186/s13059-021-02453-5       GSE163896
#
#                                               GSM_links  \
# 0     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 2     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 3     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 4     https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# ...                                                 ...
# 1229  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1230  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1231  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1232  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# 1233  https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
#
#                                              SRX_links  \
# 0      https://www.ncbi.nlm.nih.gov/sra?term=SRX631821
# 1      https://www.ncbi.nlm.nih.gov/sra?term=SRX539569
# 2      https://www.ncbi.nlm.nih.gov/sra?term=SRX591752
# 3      https://www.ncbi.nlm.nih.gov/sra?term=SRX541132
# 4      https://www.ncbi.nlm.nih.gov/sra?term=SRX763987
# ...                                                ...
# 1229  https://www.ncbi.nlm.nih.gov/sra?term=SRX9711745
# 1230  https://www.ncbi.nlm.nih.gov/sra?term=SRX9450936
# 1231  https://www.ncbi.nlm.nih.gov/sra?term=SRX9724367
# 1232  https://www.ncbi.nlm.nih.gov/sra?term=SRX9164576
# 1233  https://www.ncbi.nlm.nih.gov/sra?term=SRX9738872
#
#                           SRR_dates     GSE_dates
# 0                         9/23/2014  Sep 23, 2014
# 1                         7/22/2015  May 09, 2014
# 2     7/22/2015,6/15/2014,7/20/2014  Jun 13, 2014
# 3                         7/22/2015  Apr 17, 2015
# 4                        12/17/2014  Dec 17, 2014
# ...                             ...           ...
# 1229                     12/25/2020  Dec 22, 2020
# 1230                      5/13/2021  May 11, 2021
# 1231                      10/9/2021  Oct 07, 2021
# 1232                      11/1/2020  Oct 31, 2020
# 1233                      7/17/2021  Jul 09, 2021
#
# [1234 rows x 7 columns]

# %%
df3.to_csv("/content/SRR_and_GSE_dates.csv")

# %% [markdown]
# ## Extract GSE ID public date for manual check based GSE IDs

# %% [markdown]
# ### Concatenate all GSE IDs into a large file, including those associating with as well as not associating with sequencing data

# %%
import pandas as pd
df_in_both_do_not_have_sequencing_data = pd.read_csv("do_not_have_sequencing_data_in_both.csv",index_col=None)
df_only_in_pub_do_not_have_sequencing_data = pd.read_csv("do_not_have_sequencing_data_only_in_pub.csv",index_col=None)

df_in_both_do_not_have_sequencing_data.rename(columns={'primary_GSE_in_both': 'accession_found'}, inplace=True)
df_only_in_pub_do_not_have_sequencing_data.rename(columns={'primary_GSE_only_in_pub': 'accession_found'}, inplace=True)

df_in_both_do_not_have_sequencing_data['Sharing Scenario']= 'GSE IDs in both'
df_only_in_pub_do_not_have_sequencing_data['Sharing Scenario']= 'GSE IDs only in pub'

df_do_not_have = pd.concat([df_in_both_do_not_have_sequencing_data, df_only_in_pub_do_not_have_sequencing_data])
df_do_not_have['Method to obtain data'] = 'Manual check'
df_do_not_have['Associating Sequence data'] = 'None'
df_do_not_have.drop(columns=['Unnamed: 0'], inplace=True)
df_do_not_have
# Out:
#                    preprint_doi               publication_doi accession_found  \
# 0     10.1101/2021.10.27.466206  10.1016/j.envres.2022.112890       GSE183071
# 1                10.1101/465716     10.1016/j.gpb.2018.11.003       GSE121231
# 2                10.1101/815068     10.1016/j.neo.2020.08.002       GSE138737
# 3                10.1101/391763     10.1038/s41419-018-1096-6       GSE114345
# 4                10.1101/546952    10.1038/s41467-020-15188-x       GSE121947
# ..                          ...                           ...             ...
# 29               10.1101/503409           10.7554/eLife.44642       GSE124201
# 30    10.1101/2020.06.22.165225  10.1371/journal.pbio.3000849       GSE154770
# 31    10.1101/2020.06.22.165225  10.1371/journal.pbio.3000849       GSE154768
# 32    10.1101/2020.06.22.165225  10.1371/journal.pbio.3000849       GSE154769
# 33  10.1101/2020.07.30.20165241    10.1038/s41467-020-20139-7       GSE159788
#
#    bioproject_ID     Sharing Scenario Method to obtain data  \
# 0    PRJNA761110      GSE IDs in both          Manual check
# 1    PRJNA761110      GSE IDs in both          Manual check
# 2    PRJNA576925      GSE IDs in both          Manual check
# 3    PRJNA471056      GSE IDs in both          Manual check
# 4    PRJNA499112      GSE IDs in both          Manual check
# ..           ...                  ...                   ...
# 29   PRJNA510984  GSE IDs only in pub          Manual check
# 30   PRJNA647399  GSE IDs only in pub          Manual check
# 31   PRJNA647400  GSE IDs only in pub          Manual check
# 32   PRJNA647401  GSE IDs only in pub          Manual check
# 33   PRJNA670503  GSE IDs only in pub          Manual check
#
#    Associating Sequence data
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...
# 29                      None
# 30                      None
# 31                      None
# 32                      None
# 33                      None
#
# [130 rows x 7 columns]

# %% [markdown]
# ### Deal with the 990 GSE IDs that associate with sequencing data

# %%
import pandas as pd
df_990_have_sequencing_data = pd.read_csv("final_990_GSE_IDs_from_manual_check_with_metadata.csv",index_col=None)
df_990_have_sequencing_data.drop(columns=['Unnamed: 0','Unnamed: 0.1','Unnamed: 0.2','SRR_published_dates','Library_Strategy','Library_Source','Scientific_Name','statistics'], inplace=True)
df_990_have_sequencing_data['Method to obtain data'] = 'Manual check'
df_990_have_sequencing_data['Associating Sequence data'] = 'Yes'

# %%
df_990_have_sequencing_data
# Out:
#                   preprint_doi               publication_doi accession_found  \
# 0               10.1101/459289     10.1007/s13238-019-0650-z        GSE55600
# 1               10.1101/425348  10.1016/j.celrep.2019.03.108       GSE115929
# 2               10.1101/393876  10.1016/j.celrep.2019.07.084       GSE133660
# 3               10.1101/624957  10.1016/j.celrep.2019.08.089       GSE125523
# 4               10.1101/600932  10.1016/j.celrep.2019.09.017       GSE120520
# ..                         ...                           ...             ...
# 985  10.1101/2020.03.08.982769           10.7554/eLife.56523       GSE144919
# 986  10.1101/2020.03.08.982769           10.7554/eLife.56523       GSE144920
# 987  10.1101/2021.05.06.442900           10.7554/eLife.69843       GSE186004
# 988  10.1101/2021.06.15.448594       10.3390/cancers13174250       GSE153595
# 989             10.1101/574509  10.1016/j.celrep.2019.09.066       GSE122649
#
#     bioproject_ID     Sharing Scenario Method to obtain data  \
# 0     PRJNA240203      GSE IDs in both          Manual check
# 1     PRJNA476539      GSE IDs in both          Manual check
# 2     PRJNA552100      GSE IDs in both          Manual check
# 3     PRJNA516680      GSE IDs in both          Manual check
# 4     PRJNA493256      GSE IDs in both          Manual check
# ..            ...                  ...                   ...
# 985   PRJNA605337  GSE IDs only in pub          Manual check
# 986   PRJNA605338  GSE IDs only in pub          Manual check
# 987   PRJNA771684  GSE IDs only in pub          Manual check
# 988   PRJNA643285  GSE IDs only in pub          Manual check
# 989   PRJNA505842  GSE IDs only in pub          Manual check
#
#     Associating Sequence data
# 0                         Yes
# 1                         Yes
# 2                         Yes
# 3                         Yes
# 4                         Yes
# ..                        ...
# 985                       Yes
# 986                       Yes
# 987                       Yes
# 988                       Yes
# 989                       Yes
#
# [990 rows x 7 columns]

# %% [markdown]
# ### Concatenate

# %%
df_need_to_obtain_GSE_public_date_from_manual = pd.concat([df_990_have_sequencing_data,df_do_not_have])
df_need_to_obtain_GSE_public_date_from_manual.to_csv("whole_df_need_to_obtain_GSE_public_date_from_manual.csv")

# %%
print(len(df_need_to_obtain_GSE_public_date_from_manual))
# Out:
# 1120

# %% [markdown]
# ### Extract

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

def extract_GSE_dates(GSE_url):
    # Send an HTTP GET request to the URL
    response = requests.get(GSE_url)
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Get the content of the response
        content = response.content
        # Create a BeautifulSoup object and specify the parser
        soup = BeautifulSoup(content, "html.parser")
        tr_elems = soup.find_all('tr')
        published_dates = []
        for tr_elem in tr_elems:
            if tr_elem.get('valign') == 'top' and 'Status' in tr_elem.text:
                td_elems = tr_elem.find_all('td')  # Find td elements within this tr element
                date_text = td_elems[1].text.strip()  # Get the text from the second td element
                GSE_dates = date_text

        published_dates = GSE_dates[10:22]
        return published_dates

def process_row(row):
    accession = row['accession_found']
    GSE_url = f'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc={accession}'
    return extract_GSE_dates(GSE_url)

# Read the DataFrame
df_whole = pd.read_csv("whole_df_need_to_obtain_GSE_public_date_from_manual.csv")

# Prepare a dictionary to hold our results
results = {}

# Use ThreadPoolExecutor to parallelize the extraction
with ThreadPoolExecutor(max_workers=12) as executor:
    # Submit tasks to the executor
    future_to_row = {executor.submit(process_row, row): index for index, row in df_whole.iterrows()}

    # Collect the results as they are completed
    for future in as_completed(future_to_row):
        index = future_to_row[future]
        try:
            results[index] = future.result()
        except Exception as exc:
            print(f'Generated an exception: {exc}')
        else:
            print(f'Row {index} done')

    # Update the DataFrame with the results
for index, published_dates in results.items():
    df_whole.at[index, 'GSE_dates'] = published_dates
df_whole
# Out:
# Row 0 done
# Row 6 done
# Row 2 done
# Row 9 done
# Row 4 done
# Row 11 done
# Row 1 done
# Row 3 done
# Row 7 done
# Row 12 done
# Row 8 done
# Row 5 done
# Row 14 done
# Row 13 done
# Row 10 done
# Row 15 done
# Row 18 done
# Row 20 done
# Row 17 done
# Row 22 done
# Row 19 done
# Row 16 done
# Row 26 done
# Row 21 done
# Row 24 done
# Row 25 done
# Row 27 done
# Row 23 done
# Row 31 done
# Row 30 done
# Row 28 done
# Row 29 done
# Row 35 done
# Row 32 done
# Row 36 done
# Row 37 done
# Row 38 done
# Row 39 done
# Row 43 done
# Row 44 done
# Row 41 done
# Row 40 done
# Row 42 done
# Row 46 done
# Row 45 done
# Row 48 done
# Row 47 done
# Row 33 done
# Row 49 done
# Row 34 done
# Row 50 done
# Row 51 done
# Row 53 done
# Row 55 done
# Row 56 done
# Row 58 done
# Row 61 done
# Row 52 done
# Row 62 done
# Row 54 done
# Row 63 done
# Row 57 done
# Row 60 done
# Row 59 done
# Row 64 done
# Row 65 done
# Row 67 done
# Row 66 done
# Row 68 done
# Row 73 done
# Row 71 done
# Row 74 done
# Row 76 done
# Row 77 done
# Row 72 done
# Row 69 done
# Row 75 done
# Row 79 done
# Row 78 done
# Row 80 done
# Row 81 done
# Row 83 done
# Row 84 done
# Row 86 done
# Row 87 done
# Row 70 done
# Row 82 done
# Row 85 done
# Row 90 done
# Row 91 done
# Row 92 done
# Row 89 done
# Row 88 done
# Row 95 done
# Row 97 done
# Row 93 done
# Row 98 done
# Row 96 done
# Row 94 done
# Row 100 done
# Row 99 done
# Row 103 done
# Row 102 done
# Row 104 done
# Row 101 done
# Row 108 done
# Row 105 done
# Row 106 done
# Row 107 done
# Row 109 done
# Row 111 done
# Row 110 done
# Row 112 done
# Row 113 done
# Row 119 done
# Row 115 done
# Row 116 done
# Row 117 done
# Row 124 done
# Row 120 done
# Row 121 done
# Row 122 done
# Row 126 done
# Row 127 done
# Row 123 done
# Row 128 done
# Row 114 done
# Row 125 done
# Row 131 done
# Row 130 done
# Row 129 done
# Row 135 done
# Row 133 done
# Row 118 done
# Row 132 done
# Row 137 done
# Row 134 done
# Row 136 done
# Row 138 done
# Row 140 done
# Row 139 done
# Row 141 done
# Row 146 done
# Row 143 done
# Row 147 done
# Row 145 done
# Row 142 done
# Row 148 done
# Row 144 done
# Row 150 done
# Row 151 done
# Row 149 done
# Row 152 done
# Row 154 done
# Row 153 done
# Row 156 done
# Row 157 done
# Row 158 done
# Row 159 done
# Row 163 done
# Row 162 done
# Row 164 done
# Row 161 done
# Row 155 done
# Row 169 done
# Row 167 done
# Row 168 done
# Row 166 done
# Row 170 done
# Row 165 done
# Row 160 done
# Row 172 done
# Row 174 done
# Row 175 done
# Row 178 done
# Row 181 done
# Row 177 done
# Row 171 done
# Row 180 done
# Row 173 done
# Row 179 done
# Row 183 done
# Row 182 done
# Row 184 done
# Row 185 done
# Row 186 done
# Row 176 done
# Row 189 done
# Row 187 done
# Row 192 done
# Row 190 done
# Row 188 done
# Row 191 done
# Row 193 done
# Row 197 done
# Row 194 done
# Row 196 done
# Row 195 done
# Row 199 done
# Row 198 done
# Row 202 done
# Row 204 done
# Row 208 done
# Row 205 done
# Row 200 done
# Row 209 done
# Row 206 done
# Row 207 done
# Row 201 done
# Row 203 done
# Row 210 done
# Row 212 done
# Row 213 done
# Row 211 done
# Row 217 done
# Row 216 done
# Row 219 done
# Row 220 done
# Row 214 done
# Row 221 done
# Row 224 done
# Row 223 done
# Row 218 done
# Row 226 done
# Row 215 done
# Row 227 done
# Row 228 done
# Row 231 done
# Row 225 done
# Row 222 done
# Row 229 done
# Row 230 done
# Row 235 done
# Row 233 done
# Row 232 done
# Row 236 done
# Row 238 done
# Row 241 done
# Row 239 done
# Row 237 done
# Row 243 done
# Row 240 done
# Row 234 done
# Row 247 done
# Row 248 done
# Row 246 done
# Row 244 done
# Row 245 done
# Row 249 done
# Row 251 done
# Row 252 done
# Row 250 done
# Row 254 done
# Row 258 done
# Row 242 done
# Row 255 done
# Row 253 done
# Row 256 done
# Row 259 done
# Row 262 done
# Row 257 done
# Row 266 done
# Row 264 done
# Row 268 done
# Row 261 done
# Row 260 done
# Row 267 done
# Row 269 done
# Row 271 done
# Row 270 done
# Row 263 done
# Row 272 done
# Row 265 done
# Row 273 done
# Row 274 done
# Row 275 done
# Row 277 done
# Row 279 done
# Row 278 done
# Row 276 done
# Row 281 done
# Row 283 done
# Row 284 done
# Row 285 done
# Row 286 done
# Row 288 done
# Row 280 done
# Row 287 done
# Row 282 done
# Row 290 done
# Row 291 done
# Row 289 done
# Row 294 done
# Row 293 done
# Row 292 done
# Row 295 done
# Row 296 done
# Row 298 done
# Row 299 done
# Row 297 done
# Row 302 done
# Row 303 done
# Row 300 done
# Row 301 done
# Row 304 done
# Row 305 done
# Row 307 done
# Row 309 done
# Row 308 done
# Row 313 done
# Row 310 done
# Row 312 done
# Row 315 done
# Row 314 done
# Row 317 done
# Row 318 done
# Row 311 done
# Row 306 done
# Row 316 done
# Row 319 done
# Row 322 done
# Row 324 done
# Row 320 done
# Row 321 done
# Row 325 done
# Row 326 done
# Row 328 done
# Row 330 done
# Row 327 done
# Row 332 done
# Row 329 done
# Row 323 done
# Row 335 done
# Row 331 done
# Row 336 done
# Row 333 done
# Row 334 done
# Row 337 done
# Row 338 done
# Row 343 done
# Row 342 done
# Row 341 done
# Row 340 done
# Row 339 done
# Row 346 done
# Row 349 done
# Row 347 done
# Row 348 done
# Row 352 done
# Row 345 done
# Row 344 done
# Row 350 done
# Row 351 done
# Row 353 done
# Row 354 done
# Row 358 done
# Row 357 done
# Row 360 done
# Row 361 done
# Row 359 done
# Row 355 done
# Row 356 done
# Row 363 done
# Row 367 done
# Row 365 done
# Row 364 done
# Row 370 done
# Row 368 done
# Row 366 done
# Row 362 done
# Row 375 done
# Row 373 done
# Row 369 done
# Row 376 done
# Row 372 done
# Row 371 done
# Row 374 done
# Row 378 done
# Row 377 done
# Row 379 done
# Row 380 done
# Row 381 done
# Row 382 done
# Row 383 done
# Row 384 done
# Row 386 done
# Row 385 done
# Row 387 done
# Row 388 done
# Row 389 done
# Row 392 done
# Row 391 done
# Row 393 done
# Row 394 done
# Row 390 done
# Row 395 done
# Row 396 done
# Row 397 done
# Row 400 done
# Row 399 done
# Row 402 done
# Row 398 done
# Row 404 done
# Row 401 done
# Row 403 done
# Row 406 done
# Row 407 done
# Row 405 done
# Row 408 done
# Row 409 done
# Row 412 done
# Row 414 done
# Row 413 done
# Row 411 done
# Row 410 done
# Row 416 done
# Row 415 done
# Row 417 done
# Row 420 done
# Row 418 done
# Row 419 done
# Row 421 done
# Row 426 done
# Row 427 done
# Row 425 done
# Row 423 done
# Row 429 done
# Row 422 done
# Row 424 done
# Row 431 done
# Row 428 done
# Row 430 done
# Row 432 done
# Row 433 done
# Row 434 done
# Row 436 done
# Row 435 done
# Row 438 done
# Row 437 done
# Row 441 done
# Row 440 done
# Row 439 done
# Row 447 done
# Row 443 done
# Row 446 done
# Row 448 done
# Row 450 done
# Row 442 done
# Row 445 done
# Row 452 done
# Row 451 done
# Row 453 done
# Row 444 done
# Row 455 done
# Row 449 done
# Row 458 done
# Row 457 done
# Row 454 done
# Row 456 done
# Row 459 done
# Row 461 done
# Row 460 done
# Row 465 done
# Row 466 done
# Row 463 done
# Row 467 done
# Row 468 done
# Row 470 done
# Row 469 done
# Row 464 done
# Row 471 done
# Row 474 done
# Row 472 done
# Row 473 done
# Row 475 done
# Row 477 done
# Row 478 done
# Row 476 done
# Row 480 done
# Row 482 done
# Row 479 done
# Row 481 done
# Row 462 done
# Row 485 done
# Row 483 done
# Row 486 done
# Row 484 done
# Row 489 done
# Row 488 done
# Row 490 done
# Row 487 done
# Row 491 done
# Row 493 done
# Row 492 done
# Row 494 done
# Row 495 done
# Row 496 done
# Row 499 done
# Row 498 done
# Row 500 done
# Row 497 done
# Row 504 done
# Row 503 done
# Row 505 done
# Row 506 done
# Row 502 done
# Row 501 done
# Row 507 done
# Row 508 done
# Row 509 done
# Row 511 done
# Row 513 done
# Row 512 done
# Row 510 done
# Row 514 done
# Row 515 done
# Row 520 done
# Row 517 done
# Row 516 done
# Row 518 done
# Row 519 done
# Row 521 done
# Row 524 done
# Row 525 done
# Row 522 done
# Row 526 done
# Row 523 done
# Row 533 done
# Row 530 done
# Row 529 done
# Row 531 done
# Row 528 done
# Row 532 done
# Row 527 done
# Row 537 done
# Row 534 done
# Row 536 done
# Row 535 done
# Row 538 done
# Row 541 done
# Row 542 done
# Row 543 done
# Row 544 done
# Row 539 done
# Row 545 done
# Row 546 done
# Row 540 done
# Row 548 done
# Row 547 done
# Row 550 done
# Row 551 done
# Row 552 done
# Row 549 done
# Row 560 done
# Row 559 done
# Row 557 done
# Row 555 done
# Row 558 done
# Row 562 done
# Row 553 done
# Row 561 done
# Row 563 done
# Row 567 done
# Row 564 done
# Row 554 done
# Row 565 done
# Row 566 done
# Row 568 done
# Row 556 done
# Row 569 done
# Row 571 done
# Row 572 done
# Row 570 done
# Row 574 done
# Row 573 done
# Row 577 done
# Row 578 done
# Row 581 done
# Row 576 done
# Row 575 done
# Row 580 done
# Row 583 done
# Row 584 done
# Row 582 done
# Row 585 done
# Row 587 done
# Row 586 done
# Row 589 done
# Row 590 done
# Row 579 done
# Row 588 done
# Row 591 done
# Row 593 done
# Row 598 done
# Row 595 done
# Row 597 done
# Row 599 done
# Row 592 done
# Row 602 done
# Row 596 done
# Row 601 done
# Row 600 done
# Row 594 done
# Row 608 done
# Row 604 done
# Row 611 done
# Row 606 done
# Row 609 done
# Row 603 done
# Row 605 done
# Row 612 done
# Row 613 done
# Row 610 done
# Row 614 done
# Row 607 done
# Row 617 done
# Row 615 done
# Row 616 done
# Row 618 done
# Row 619 done
# Row 623 done
# Row 622 done
# Row 621 done
# Row 620 done
# Row 624 done
# Row 625 done
# Row 627 done
# Row 630 done
# Row 628 done
# Row 626 done
# Row 629 done
# Row 633 done
# Row 631 done
# Row 632 done
# Row 636 done
# Row 637 done
# Row 638 done
# Row 639 done
# Row 640 done
# Row 641 done
# Row 645 done
# Row 646 done
# Row 635 done
# Row 634 done
# Row 642 done
# Row 650 done
# Row 648 done
# Row 647 done
# Row 643 done
# Row 652 done
# Row 653 done
# Row 649 done
# Row 651 done
# Row 654 done
# Row 655 done
# Row 657 done
# Row 656 done
# Row 644 done
# Row 658 done
# Row 659 done
# Row 660 done
# Row 663 done
# Row 661 done
# Row 662 done
# Row 664 done
# Row 665 done
# Row 666 done
# Row 667 done
# Row 668 done
# Row 669 done
# Row 670 done
# Row 671 done
# Row 672 done
# Row 673 done
# Row 677 done
# Row 679 done
# Row 676 done
# Row 681 done
# Row 678 done
# Row 680 done
# Row 682 done
# Row 684 done
# Row 685 done
# Row 683 done
# Row 689 done
# Row 687 done
# Row 675 done
# Row 686 done
# Row 688 done
# Row 674 done
# Row 695 done
# Row 693 done
# Row 692 done
# Row 690 done
# Row 691 done
# Row 700 done
# Row 694 done
# Row 699 done
# Row 696 done
# Row 698 done
# Row 697 done
# Row 701 done
# Row 702 done
# Row 704 done
# Row 703 done
# Row 705 done
# Row 706 done
# Row 709 done
# Row 710 done
# Row 711 done
# Row 708 done
# Row 714 done
# Row 716 done
# Row 712 done
# Row 715 done
# Row 707 done
# Row 717 done
# Row 713 done
# Row 718 done
# Row 720 done
# Row 719 done
# Row 722 done
# Row 721 done
# Row 724 done
# Row 727 done
# Row 725 done
# Row 728 done
# Row 731 done
# Row 726 done
# Row 729 done
# Row 730 done
# Row 723 done
# Row 735 done
# Row 733 done
# Row 734 done
# Row 736 done
# Row 732 done
# Row 738 done
# Row 746 done
# Row 744 done
# Row 741 done
# Row 740 done
# Row 743 done
# Row 739 done
# Row 747 done
# Row 742 done
# Row 745 done
# Row 748 done
# Row 749 done
# Row 737 done
# Row 751 done
# Row 752 done
# Row 750 done
# Row 756 done
# Row 754 done
# Row 755 done
# Row 753 done
# Row 758 done
# Row 757 done
# Row 761 done
# Row 762 done
# Row 759 done
# Row 760 done
# Row 764 done
# Row 767 done
# Row 766 done
# Row 765 done
# Row 763 done
# Row 768 done
# Row 772 done
# Row 769 done
# Row 773 done
# Row 771 done
# Row 770 done
# Row 774 done
# Row 777 done
# Row 775 done
# Row 780 done
# Row 778 done
# Row 776 done
# Row 779 done
# Row 781 done
# Row 782 done
# Row 784 done
# Row 785 done
# Row 783 done
# Row 786 done
# Row 787 done
# Row 790 done
# Row 792 done
# Row 789 done
# Row 793 done
# Row 788 done
# Row 799 done
# Row 796 done
# Row 801 done
# Row 794 done
# Row 797 done
# Row 802 done
# Row 803 done
# Row 800 done
# Row 791 done
# Row 804 done
# Row 798 done
# Row 795 done
# Row 810 done
# Row 808 done
# Row 807 done
# Row 809 done
# Row 805 done
# Row 806 done
# Row 812 done
# Row 814 done
# Row 811 done
# Row 815 done
# Row 813 done
# Row 817 done
# Row 820 done
# Row 819 done
# Row 818 done
# Row 821 done
# Row 816 done
# Row 824 done
# Row 825 done
# Row 822 done
# Row 827 done
# Row 826 done
# Row 823 done
# Row 829 done
# Row 833 done
# Row 828 done
# Row 830 done
# Row 832 done
# Row 831 done
# Row 834 done
# Row 835 done
# Row 836 done
# Row 840 done
# Row 838 done
# Row 839 done
# Row 837 done
# Row 842 done
# Row 846 done
# Row 847 done
# Row 850 done
# Row 843 done
# Row 851 done
# Row 845 done
# Row 852 done
# Row 841 done
# Row 853 done
# Row 848 done
# Row 854 done
# Row 844 done
# Row 857 done
# Row 855 done
# Row 856 done
# Row 863 done
# Row 858 done
# Row 859 done
# Row 860 done
# Row 865 done
# Row 866 done
# Row 867 done
# Row 862 done
# Row 861 done
# Row 864 done
# Row 868 done
# Row 849 done
# Row 872 done
# Row 870 done
# Row 869 done
# Row 877 done
# Row 876 done
# Row 874 done
# Row 871 done
# Row 878 done
# Row 880 done
# Row 875 done
# Row 873 done
# Row 879 done
# Row 881 done
# Row 885 done
# Row 884 done
# Row 883 done
# Row 886 done
# Row 887 done
# Row 888 done
# Row 889 done
# Row 890 done
# Row 891 done
# Row 893 done
# Row 892 done
# Row 894 done
# Row 882 done
# Row 895 done
# Row 896 done
# Row 897 done
# Row 898 done
# Row 902 done
# Row 901 done
# Row 903 done
# Row 904 done
# Row 900 done
# Row 899 done
# Row 910 done
# Row 907 done
# Row 906 done
# Row 909 done
# Row 911 done
# Row 912 done
# Row 914 done
# Row 908 done
# Row 913 done
# Row 916 done
# Row 905 done
# Row 915 done
# Row 917 done
# Row 918 done
# Row 919 done
# Row 920 done
# Row 921 done
# Row 928 done
# Row 922 done
# Row 924 done
# Row 923 done
# Row 929 done
# Row 926 done
# Row 927 done
# Row 925 done
# Row 933 done
# Row 930 done
# Row 932 done
# Row 931 done
# Row 935 done
# Row 938 done
# Row 937 done
# Row 936 done
# Row 940 done
# Row 939 done
# Row 941 done
# Row 944 done
# Row 945 done
# Row 943 done
# Row 934 done
# Row 942 done
# Row 946 done
# Row 947 done
# Row 951 done
# Row 950 done
# Row 952 done
# Row 948 done
# Row 949 done
# Row 954 done
# Row 959 done
# Row 956 done
# Row 953 done
# Row 960 done
# Row 957 done
# Row 958 done
# Row 955 done
# Row 963 done
# Row 965 done
# Row 961 done
# Row 962 done
# Row 964 done
# Row 966 done
# Row 969 done
# Row 968 done
# Row 967 done
# Row 971 done
# Row 970 done
# Row 972 done
# Row 976 done
# Row 973 done
# Row 975 done
# Row 974 done
# Row 979 done
# Row 977 done
# Row 980 done
# Row 978 done
# Row 981 done
# Row 982 done
# Row 983 done
# Row 984 done
# Row 986 done
# Row 985 done
# Row 988 done
# Row 989 done
# Row 987 done
# Row 992 done
# Row 993 done
# Row 991 done
# Row 990 done
# Row 995 done
# Row 994 done
# Row 998 done
# Row 996 done
# Row 1001 done
# Row 1004 done
# Row 1005 done
# Row 1002 done
# Row 1009 done
# Row 1000 done
# Row 1006 done
# Row 1008 done
# Row 1003 done
# Row 997 done
# Row 1007 done
# Row 1012 done
# Row 1010 done
# Row 1013 done
# Row 999 done
# Row 1016 done
# Row 1014 done
# Row 1011 done
# Row 1018 done
# Row 1015 done
# Row 1019 done
# Row 1017 done
# Row 1023 done
# Row 1021 done
# Row 1024 done
# Row 1022 done
# Row 1029 done
# Row 1028 done
# Row 1030 done
# Row 1020 done
# Row 1037 done
# Row 1032 done
# Row 1033 done
# Row 1035 done
# Row 1036 done
# Row 1034 done
# Row 1038 done
# Row 1026 done
# Row 1039 done
# Row 1025 done
# Row 1027 done
# Row 1031 done
# Row 1041 done
# Row 1040 done
# Row 1043 done
# Row 1045 done
# Row 1047 done
# Row 1042 done
# Row 1044 done
# Row 1050 done
# Row 1053 done
# Row 1046 done
# Row 1051 done
# Row 1052 done
# Row 1049 done
# Row 1048 done
# Row 1054 done
# Row 1056 done
# Row 1057 done
# Row 1055 done
# Row 1058 done
# Generated an exception: local variable 'GSE_dates' referenced before assignment
# Row 1064 done
# Row 1059 done
# Row 1063 done
# Row 1062 done
# Row 1069 done
# Row 1070 done
# Row 1066 done
# Row 1061 done
# Row 1068 done
# Row 1060 done
# Row 1067 done
# Row 1071 done
# Row 1073 done
# Row 1075 done
# Row 1074 done
# Row 1072 done
# Row 1077 done
# Row 1078 done
# Row 1076 done
# Row 1080 done
# Row 1081 done
# Row 1079 done
# Row 1082 done
# Row 1083 done
# Row 1084 done
# Row 1087 done
# Row 1090 done
# Row 1089 done
# Row 1088 done
# Row 1085 done
# Row 1091 done
# Row 1092 done
# Row 1095 done
# Row 1093 done
# Row 1096 done
# Row 1086 done
# Row 1097 done
# Row 1094 done
# Row 1099 done
# Row 1100 done
# Row 1105 done
# Row 1102 done
# Row 1098 done
# Row 1107 done
# Row 1108 done
# Row 1104 done
# Row 1103 done
# Row 1106 done
# Row 1109 done
# Row 1110 done
# Row 1111 done
# Row 1112 done
# Row 1101 done
# Row 1113 done
# Row 1115 done
# Row 1114 done
# Row 1118 done
# Row 1117 done
# Row 1119 done
# Row 1116 done
#       Unnamed: 0                 preprint_doi               publication_doi  \
# 0              0               10.1101/459289     10.1007/s13238-019-0650-z
# 1              1               10.1101/425348  10.1016/j.celrep.2019.03.108
# 2              2               10.1101/393876  10.1016/j.celrep.2019.07.084
# 3              3               10.1101/624957  10.1016/j.celrep.2019.08.089
# 4              4               10.1101/600932  10.1016/j.celrep.2019.09.017
# ...          ...                          ...                           ...
# 1115          29               10.1101/503409           10.7554/eLife.44642
# 1116          30    10.1101/2020.06.22.165225  10.1371/journal.pbio.3000849
# 1117          31    10.1101/2020.06.22.165225  10.1371/journal.pbio.3000849
# 1118          32    10.1101/2020.06.22.165225  10.1371/journal.pbio.3000849
# 1119          33  10.1101/2020.07.30.20165241    10.1038/s41467-020-20139-7
#
#      accession_found bioproject_ID     Sharing Scenario Method to obtain data  \
# 0           GSE55600   PRJNA240203      GSE IDs in both          Manual check
# 1          GSE115929   PRJNA476539      GSE IDs in both          Manual check
# 2          GSE133660   PRJNA552100      GSE IDs in both          Manual check
# 3          GSE125523   PRJNA516680      GSE IDs in both          Manual check
# 4          GSE120520   PRJNA493256      GSE IDs in both          Manual check
# ...              ...           ...                  ...                   ...
# 1115       GSE124201   PRJNA510984  GSE IDs only in pub          Manual check
# 1116       GSE154770   PRJNA647399  GSE IDs only in pub          Manual check
# 1117       GSE154768   PRJNA647400  GSE IDs only in pub          Manual check
# 1118       GSE154769   PRJNA647401  GSE IDs only in pub          Manual check
# 1119       GSE159788   PRJNA670503  GSE IDs only in pub          Manual check
#
#      Associating Sequence data     GSE_dates
# 0                          Yes  Feb 26, 2019
# 1                          Yes  Apr 23, 2019
# 2                          Yes  Jul 02, 2019
# 3                          Yes  Sep 01, 2019
# 4                          Yes  Oct 15, 2019
# ...                        ...           ...
# 1115                       NaN  Dec 03, 2019
# 1116                       NaN  Jul 21, 2020
# 1117                       NaN  Jul 21, 2020
# 1118                       NaN  Jul 21, 2020
# 1119                       NaN  Nov 01, 2020
#
# [1120 rows x 9 columns]

# %%
df_whole.fillna('None', inplace=True)
FP = df_whole.loc[df_whole['GSE_dates']=='None']
FP
# Out:
#       Unnamed: 0    preprint_doi        publication_doi accession_found  \
# 1065          75  10.1101/403543  10.1101/gr.243378.118            None
#
#      bioproject_ID Sharing Scenario Method to obtain data  \
# 1065   PRJNA488283  GSE IDs in both          Manual check
#
#      Associating Sequence data GSE_dates
# 1065                      None      None

# %%
df_whole.drop(index=FP.index, inplace=True)

# %%
print(len(df_whole)) # There are 1120 GSE IDs in total from manual check
# Out:
# 1119

# %%
from datetime import datetime

df_whole['GSE_dates'] = df_whole['GSE_dates'].apply(lambda x: datetime.strptime(x, '%b %d, %Y').strftime('%m/%d/%Y'))

df_whole.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_whole.to_csv("whole_1120_df_with_GSE_public_date_from_manual_check.csv")
